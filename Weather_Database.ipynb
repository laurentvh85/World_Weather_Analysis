# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key
from config import g_key

# %%
#create a random list of coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#coordinates list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add to the cities list.
    if city not in cities:
        cities.append(city)

# %%
cities
# Out:
# ['dikson',
#  'bezenchuk',
#  'sentyabrskiy',
#  'albany',
#  'cabo san lucas',
#  'lata',
#  'kaitangata',
#  'nikolskoye',
#  'punta arenas',
#  'bathsheba',
#  'kapaa',
#  'tasiilaq',
#  'salalah',
#  'hermanus',
#  'edd',
#  'taolanaro',
#  'itaituba',
#  'east london',
#  'port alfred',
#  'atuona',
#  'portland',
#  'iqaluit',
#  'porto novo',
#  'chokurdakh',
#  'humaita',
#  'providencia',
#  'castro',
#  'carnarvon',
#  'mokrous',
#  'rikitea',
#  'birkeland',
#  'dolores',
#  'newburgh',
#  'vaini',
#  'tumannyy',
#  'gigmoto',
#  'cape town',
#  'vila',
#  'nouadhibou',
#  'barentsburg',
#  'khatanga',
#  'vestmannaeyjar',
#  'sobolevo',
#  'khormuj',
#  'clyde river',
#  'tuktoyaktuk',
#  'saleaula',
#  'marzuq',
#  'grand gaube',
#  'kamyshlov',
#  'butaritari',
#  'los llanos de aridane',
#  'college',
#  'dunedin',
#  'sinnamary',
#  'ciudad bolivar',
#  'salinopolis',
#  'halalo',
#  'sao filipe',
#  'egvekinot',
#  'xining',
#  'harper',
#  'bluff',
#  'boa vista',
#  'provideniya',
#  'illoqqortoormiut',
#  'vostok',
#  'mataura',
#  'busselton',
#  'hobart',
#  'kon tum',
#  'alice town',
#  'tiksi',
#  'kindia',
#  'gualaceo',
#  'barrow',
#  'atar',
#  'ushuaia',
#  'kodiak',
#  'santa rosa',
#  'ossora',
#  'thompson',
#  'bredasdorp',
#  'mangrol',
#  'kabo',
#  'vaitupu',
#  'dujuma',
#  'jinchengjiang',
#  'grand baie',
#  'ancud',
#  'mahebourg',
#  'new norfolk',
#  'alashtar',
#  'te anau',
#  'aklavik',
#  'san patricio',
#  'hithadhoo',
#  'qaanaaq',
#  'urumqi',
#  'sorong',
#  'tevriz',
#  'ulladulla',
#  'lagos',
#  'arraial do cabo',
#  'torbay',
#  'puerto ayora',
#  'jamestown',
#  'bethal',
#  'cherskiy',
#  'broome',
#  'asfi',
#  'norman wells',
#  'kroya',
#  'bambous virieux',
#  'hofn',
#  'eskilstuna',
#  'kristiansand',
#  'komarovo',
#  'sault sainte marie',
#  'livingston',
#  'olinda',
#  'katsuura',
#  'namibe',
#  'pareora',
#  'port keats',
#  'cidreira',
#  'imeni poliny osipenko',
#  'nador',
#  'hilo',
#  'hambantota',
#  'mogzon',
#  'dombas',
#  'faanui',
#  'korla',
#  'saint george',
#  'longyearbyen',
#  'biak',
#  'malpe',
#  'chuy',
#  'saskylakh',
#  'avarua',
#  'tuatapere',
#  'porto walter',
#  'srednekolymsk',
#  'alofi',
#  'samalaeulu',
#  'angoram',
#  'mys shmidta',
#  'sheltozero',
#  'talara',
#  'geraldton',
#  'raudeberg',
#  'amderma',
#  'khonuu',
#  'gat',
#  'yemelyanovo',
#  'sofiysk',
#  'tazmalt',
#  'victoria',
#  'port elizabeth',
#  'orsha',
#  'havre-saint-pierre',
#  'jalu',
#  'marsh harbour',
#  'ilulissat',
#  'kruisfontein',
#  'hami',
#  'ribeira grande',
#  'borovskoy',
#  'tilichiki',
#  'tokur',
#  'san antonio',
#  'san quintin',
#  'nelson bay',
#  'corrente',
#  'lorengau',
#  'esperance',
#  'deputatskiy',
#  'souillac',
#  'padang',
#  'puerto escondido',
#  'anshun',
#  'fiumicino',
#  'comodoro rivadavia',
#  'margate',
#  'barawe',
#  'campos altos',
#  'saint-philippe',
#  'cayenne',
#  'vilyuysk',
#  'rungata',
#  'shemordan',
#  'butembo',
#  'airai',
#  'acari',
#  'tasbuget',
#  'malwan',
#  'pozo colorado',
#  'zhigalovo',
#  'belushya guba',
#  'doha',
#  'mount hagen',
#  'maldonado',
#  'maltahohe',
#  'nara',
#  'calama',
#  'kamenka',
#  'grand river south east',
#  'pevek',
#  'naftah',
#  'ponta do sol',
#  'lanquin',
#  'kurilsk',
#  'pasighat',
#  'pasni',
#  'bontang',
#  'keuruu',
#  'lebu',
#  'palmer',
#  'san policarpo',
#  'narsaq',
#  'fukue',
#  'buala',
#  'lompoc',
#  'erenhot',
#  'bethel',
#  'caravelas',
#  'hassan',
#  'lewiston',
#  'yerbogachen',
#  'sumbawa',
#  'kavieng',
#  'tupik',
#  'middelburg',
#  'kapuskasing',
#  'shirokiy',
#  'santa lucia',
#  'cayambe',
#  'asyut',
#  'aflu',
#  'praia',
#  'bayir',
#  'kattivakkam',
#  'sukhumi',
#  'tiznit',
#  'emba',
#  'hendijan',
#  'itarema',
#  'porbandar',
#  'magdagachi',
#  'samusu',
#  'rocha',
#  'rafai',
#  'severo-kurilsk',
#  'nanortalik',
#  'ayan',
#  'bilma',
#  'bengkulu',
#  'ngukurr',
#  'aswan',
#  'olafsvik',
#  'new waterford',
#  'baruun-urt',
#  'republic',
#  'georgetown',
#  'mahibadhoo',
#  'lander',
#  'flinders',
#  'tabiauea',
#  'gimli',
#  'sabha',
#  'santa maria',
#  'zhigansk',
#  'lasa',
#  'mwinilunga',
#  'makasar',
#  'tanete',
#  'katangi',
#  'yellowknife',
#  'kamenskoye',
#  'mitsamiouli',
#  'upernavik',
#  'mach',
#  'tuy hoa',
#  'makakilo city',
#  'bardiyah',
#  'qasigiannguit',
#  'manhattan',
#  'fribourg',
#  'tsihombe',
#  'ovre ardal',
#  'bandarbeyla',
#  'stokmarknes',
#  'ostrovnoy',
#  'necochea',
#  'ranong',
#  'katobu',
#  'mar del plata',
#  'la ronge',
#  'the valley',
#  'suntar',
#  'kaeo',
#  'alihe',
#  'hasaki',
#  'gilbues',
#  'ambon',
#  'zhitikara',
#  'okha',
#  'leningradskiy',
#  'tarauaca',
#  'saleilua',
#  'hashtgerd',
#  'adilabad',
#  'bima',
#  'rusera',
#  'beisfjord',
#  'maningrida',
#  'tatawin',
#  'sayyan',
#  'teahupoo',
#  'faya',
#  'kusk',
#  'pacific grove',
#  'attawapiskat',
#  'boende',
#  'lodja',
#  'mildura',
#  'trincomalee',
#  'sola',
#  'blagoveshchenka',
#  'colares',
#  'ugoofaaru',
#  'saravan',
#  'nenjiang',
#  'lagoa',
#  'uvira',
#  'puerto ayacucho',
#  'resistencia',
#  'kahului',
#  'tocopilla',
#  'belfast',
#  'grindavik',
#  'qianan',
#  'phan thiet',
#  'labutta',
#  'charters towers',
#  'fortuna',
#  'sorland',
#  'methoni',
#  'dubrovnik',
#  'yulara',
#  'itacoatiara',
#  'meulaboh',
#  'high level',
#  'eyl',
#  'bairiki',
#  'talnakh',
#  'columbus',
#  'marcona',
#  'guadalupe y calvo',
#  'cabedelo',
#  'ahipara',
#  'borogontsy',
#  'bafq',
#  'beloha',
#  'mount isa',
#  'zhangjiakou',
#  'pisco',
#  'seminole',
#  'dodge city',
#  'port hardy',
#  'nipawin',
#  'lucea',
#  'kieta',
#  'oneida',
#  'namatanai',
#  'pampas',
#  'porgera',
#  'bay city',
#  'belyy yar',
#  'awjilah',
#  'tahta',
#  'berlevag',
#  'newry',
#  'kalmunai',
#  'palabuhanratu',
#  'rio gallegos',
#  'nishihara',
#  'tiarei',
#  'filiatra',
#  'sitka',
#  'brae',
#  'labuan',
#  'mareeba',
#  'pulandian',
#  'beni',
#  'nerja',
#  'denpasar',
#  'half moon bay',
#  'pushchino',
#  'abha',
#  'pacifica',
#  'luganville',
#  'challapata',
#  'hobyo',
#  'vardo',
#  'mosquera',
#  'henties bay',
#  'madras',
#  'vallenar',
#  'xinyang',
#  'shimanovsk',
#  'lavrentiya',
#  'chagda',
#  'yuncheng',
#  'itoman',
#  'leh',
#  'gzhatsk',
#  'naruto',
#  'port pirie',
#  'poum',
#  'manta',
#  'gundlupet',
#  'rawson',
#  'stoyba',
#  'yurla',
#  'mutis',
#  'nizhneyansk',
#  'sibolga',
#  'mitchell',
#  'romodanovo',
#  'taltal',
#  'waingapu',
#  'sioux lookout',
#  'vrontados',
#  'tura',
#  'chippewa falls',
#  'barbosa ferraz',
#  'halifax',
#  'rioblanco',
#  'acworth',
#  'conde',
#  'ialibu',
#  'votorantim',
#  'luderitz',
#  'beni mazar',
#  'kashi',
#  'oyem',
#  'guiratinga',
#  'sahuaripa',
#  'winnemucca',
#  'saint-pierre',
#  'ballina',
#  'florianopolis',
#  'marsa matruh',
#  'slyudyanka',
#  'okhotsk',
#  'tynda',
#  'thurles',
#  'esmeraldas',
#  'maniitsoq',
#  'yatou',
#  'severobaykalsk',
#  'banjar',
#  'buraydah',
#  'kargasok',
#  'thinadhoo',
#  'bayevo',
#  'eugene',
#  'asbury park',
#  'sisimiut',
#  'haines junction',
#  'laguna',
#  'roald',
#  'upata',
#  'watsa',
#  'aviles',
#  'umm kaddadah',
#  'te karaka',
#  'razole',
#  'soyo',
#  'escanaba',
#  'tabou',
#  'gashua',
#  'nepalganj',
#  'grand centre',
#  'kutum',
#  'port-cartier',
#  'avera',
#  'sfantu gheorghe',
#  'bossangoa',
#  'mayo',
#  'adrar',
#  'yaan',
#  'stornoway',
#  'hefei',
#  'taoudenni',
#  'san borja',
#  'saint-francois',
#  'quatre cocos',
#  'adeje',
#  'hamilton',
#  'omsukchan',
#  'luwuk',
#  'pitimbu',
#  'komsomolskiy',
#  'monor',
#  'nekrasovskoye',
#  'port blair',
#  'picota',
#  'naze',
#  'codrington',
#  'presidente franco',
#  'azimur',
#  'richards bay',
#  'umzimvubu',
#  'tubruq',
#  'sindor',
#  'san jose',
#  'palmas',
#  'oktyabrskoye',
#  'waipawa',
#  'ambilobe',
#  'nantucket',
#  'tekeli',
#  'shache',
#  'springbok',
#  'pangnirtung',
#  'buin',
#  'touros',
#  'lakeside',
#  'huari',
#  'nyurba',
#  'fuerte olimpo',
#  'flin flon',
#  'nioro',
#  'woodward',
#  'mahajanga',
#  'saint-joseph',
#  'westport',
#  'dharchula',
#  'abaza',
#  'nyaunglebin',
#  'nalut',
#  'asau',
#  'tutoia',
#  'paita',
#  'bulgan',
#  'santa ana',
#  'soubre',
#  'elizabeth city',
#  'saint-augustin',
#  'monte patria',
#  'mvuma',
#  'baykit',
#  'hailar',
#  'manicore',
#  'tecoanapa',
#  'ayagoz',
#  'berbera',
#  'duluth',
#  'steinbach',
#  'turukhansk',
#  'chimoio',
#  'iralaya',
#  'rundu',
#  'coquimbo',
#  'greenville',
#  'praia da vitoria',
#  'burnie',
#  'akdepe',
#  'banff',
#  'bonthe',
#  'waddan',
#  'bograd',
#  'riberalta',
#  'weyburn',
#  'bolungarvik',
#  'auki',
#  'bhagalpur',
#  'mragowo',
#  'san cristobal',
#  'novokayakent',
#  'suleja',
#  'vila velha',
#  'gamba',
#  'sur',
#  'sabang',
#  'kavaratti',
#  'kysyl-syr',
#  'danville',
#  'fairbanks',
#  'skagastrond',
#  'longhua',
#  'samarai',
#  'huarmey',
#  'erzin',
#  'shimoda',
#  'general pico',
#  'sinkat',
#  'inirida',
#  'broken hill',
#  'domoni',
#  'gusau',
#  'ust-kuyga',
#  'beitbridge',
#  'reconquista',
#  'kendari',
#  'ha giang',
#  'mount gambier',
#  'kirkcudbright',
#  'ketchikan',
#  'husavik',
#  'antalaha',
#  'axim',
#  'taraza',
#  'umm lajj',
#  'turkistan']

# %%
#URL for Weather API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    
# Loop through all the cities.
for i, city in enumerate(cities):
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
          
        try:
            city_rain = city_weather["rain"]["1h"]
            
        except KeyError:
            city_rain = "0.0"
        try:
            city_snow = city_weather["snow"]["1h"]
                       
        except KeyError:
            city_snow = "0.0"
        
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description,
                          "Country": city_country,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})
        

# If an error is experienced, skip the city.
    except:
        pass

# %%
city_weather = requests.get(city_url)

# %%
city_weather.json()
# Out:
# {'coord': {'lon': 68, 'lat': 43},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 79.5,
#   'feels_like': 66.31,
#   'temp_min': 79.5,
#   'temp_max': 79.5,
#   'pressure': 1010,
#   'humidity': 16,
#   'sea_level': 1010,
#   'grnd_level': 989},
#  'wind': {'speed': 16.44, 'deg': 282},
#  'clouds': {'all': 8},
#  'dt': 1593258422,
#  'sys': {'country': 'KZ', 'sunrise': 1593215447, 'sunset': 1593270671},
#  'timezone': 21600,
#  'id': 1524787,
#  'name': 'South Kazakhstan Region',
#  'cod': 200}

# %%
city_data
# Out:
# [{'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 39.49,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 20.6,
#   'Current Description': 'moderate rain',
#   'Country': 'RU',
#   'Rain (inches)': 2.74,
#   'Snow (inches)': '0.0'},
#  {'City': 'Bezenchuk',
#   'Lat': 52.98,
#   'Lng': 49.43,
#   'Max Temp': 77.54,
#   'Humidity': 66,
#   'Cloudiness': 58,
#   'Wind Speed': 15.3,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.93,
#   'Snow (inches)': '0.0'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 66,
#   'Humidity': 74,
#   'Cloudiness': 95,
#   'Wind Speed': 3.89,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 82.99,
#   'Humidity': 69,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lata',
#   'Lat': 40.16,
#   'Lng': -8.33,
#   'Max Temp': 78.01,
#   'Humidity': 68,
#   'Cloudiness': 94,
#   'Wind Speed': 7.11,
#   'Current Description': 'overcast clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 50,
#   'Humidity': 86,
#   'Cloudiness': 83,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 78.8,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 15.66,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 33.8,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 23.04,
#   'Current Description': 'few clouds',
#   'Country': 'BB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 86,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds',
#   'Country': 'OM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 59,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 15.01,
#   'Current Description': 'light rain',
#   'Country': 'ZA',
#   'Rain (inches)': 0.59,
#   'Snow (inches)': '0.0'},
#  {'City': 'Edd',
#   'Lat': 13.93,
#   'Lng': 41.69,
#   'Max Temp': 95.99,
#   'Humidity': 34,
#   'Cloudiness': 41,
#   'Wind Speed': 16.67,
#   'Current Description': 'scattered clouds',
#   'Country': 'ER',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Itaituba',
#   'Lat': -4.28,
#   'Lng': -55.98,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 42,
#   'Wind Speed': 2.75,
#   'Current Description': 'scattered clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 75.2,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 74.44,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 23.51,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 80.15,
#   'Humidity': 77,
#   'Cloudiness': 12,
#   'Wind Speed': 11.1,
#   'Current Description': 'light rain',
#   'Country': 'PF',
#   'Rain (inches)': 0.11,
#   'Snow (inches)': '0.0'},
#  {'City': 'Portland',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 62.6,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 44.6,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 6.06,
#   'Current Description': 'few clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Porto Novo',
#   'Lat': 6.5,
#   'Lng': 2.6,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'BJ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 50.49,
#   'Humidity': 46,
#   'Cloudiness': 11,
#   'Wind Speed': 15.46,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Humaita',
#   'Lat': -7.51,
#   'Lng': -63.02,
#   'Max Temp': 77.76,
#   'Humidity': 72,
#   'Cloudiness': 5,
#   'Wind Speed': 1.79,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Providencia',
#   'Lat': 28.72,
#   'Lng': -111.58,
#   'Max Temp': 81,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 49.86,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.78,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mokrous',
#   'Lat': 51.23,
#   'Lng': 47.52,
#   'Max Temp': 78.28,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 17.18,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 72.21,
#   'Humidity': 79,
#   'Cloudiness': 15,
#   'Wind Speed': 13.18,
#   'Current Description': 'few clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Birkeland',
#   'Lat': 58.33,
#   'Lng': 8.23,
#   'Max Temp': 77,
#   'Humidity': 50,
#   'Cloudiness': 12,
#   'Wind Speed': 13.87,
#   'Current Description': 'few clouds',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dolores',
#   'Lat': -36.31,
#   'Lng': -57.68,
#   'Max Temp': 39.74,
#   'Humidity': 77,
#   'Cloudiness': 85,
#   'Wind Speed': 4.34,
#   'Current Description': 'overcast clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Newburgh',
#   'Lat': 41.5,
#   'Lng': -74.01,
#   'Max Temp': 70,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Current Description': 'broken clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds',
#   'Country': 'TO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gigmoto',
#   'Lat': 13.78,
#   'Lng': 124.39,
#   'Max Temp': 82.08,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 8.63,
#   'Current Description': 'light rain',
#   'Country': 'PH',
#   'Rain (inches)': 0.8,
#   'Snow (inches)': '0.0'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 60.8,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 28.86,
#   'Current Description': 'heavy intensity rain',
#   'Country': 'ZA',
#   'Rain (inches)': 9.14,
#   'Snow (inches)': '0.0'},
#  {'City': 'Vila',
#   'Lat': 42.03,
#   'Lng': -8.16,
#   'Max Temp': 66,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.93,
#   'Lng': -17.03,
#   'Max Temp': 82.4,
#   'Humidity': 54,
#   'Cloudiness': 6,
#   'Wind Speed': 21.92,
#   'Current Description': 'clear sky',
#   'Country': 'MR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 65.68,
#   'Humidity': 47,
#   'Cloudiness': 57,
#   'Wind Speed': 13.58,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'IS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sobolevo',
#   'Lat': 54.43,
#   'Lng': 31.9,
#   'Max Temp': 78.22,
#   'Humidity': 65,
#   'Cloudiness': 21,
#   'Wind Speed': 10.2,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Clyde River',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 33.37,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 15.32,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.47,
#   'Max Temp': 91.17,
#   'Humidity': 28,
#   'Cloudiness': 96,
#   'Wind Speed': 2.64,
#   'Current Description': 'overcast clouds',
#   'Country': 'YE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.01,
#   'Lng': 57.66,
#   'Max Temp': 77,
#   'Humidity': 70,
#   'Cloudiness': 85,
#   'Wind Speed': 13,
#   'Current Description': 'overcast clouds',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kamyshlov',
#   'Lat': 56.84,
#   'Lng': 62.71,
#   'Max Temp': 61.2,
#   'Humidity': 50,
#   'Cloudiness': 91,
#   'Wind Speed': 4.68,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 82.36,
#   'Humidity': 82,
#   'Cloudiness': 72,
#   'Wind Speed': 18.19,
#   'Current Description': 'light rain',
#   'Country': 'KI',
#   'Rain (inches)': 0.63,
#   'Snow (inches)': '0.0'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 75.2,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds',
#   'Country': 'ES',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'College',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 51.8,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dunedin',
#   'Lat': -45.87,
#   'Lng': 170.5,
#   'Max Temp': 48.99,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 9.15,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sinnamary',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 81.18,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 4.54,
#   'Current Description': 'clear sky',
#   'Country': 'GF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ciudad Bolivar',
#   'Lat': 8.12,
#   'Lng': -63.55,
#   'Max Temp': 79.5,
#   'Humidity': 78,
#   'Cloudiness': 42,
#   'Wind Speed': 9.86,
#   'Current Description': 'scattered clouds',
#   'Country': 'VE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Salinopolis',
#   'Lat': -0.61,
#   'Lng': -47.36,
#   'Max Temp': 80.78,
#   'Humidity': 83,
#   'Cloudiness': 9,
#   'Wind Speed': 8.16,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.67,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 75,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 5.01,
#   'Current Description': 'scattered clouds',
#   'Country': 'CV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Egvekinot',
#   'Lat': 66.32,
#   'Lng': -179.17,
#   'Max Temp': 30.61,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Xining',
#   'Lat': 36.62,
#   'Lng': 101.77,
#   'Max Temp': 69.17,
#   'Humidity': 27,
#   'Cloudiness': 84,
#   'Wind Speed': 8.52,
#   'Current Description': 'broken clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Harper',
#   'Lat': 4.38,
#   'Lng': -7.72,
#   'Max Temp': 78.89,
#   'Humidity': 78,
#   'Cloudiness': 89,
#   'Wind Speed': 12.06,
#   'Current Description': 'overcast clouds',
#   'Country': 'LR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Boa Vista',
#   'Lat': 2.82,
#   'Lng': -60.67,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 41.56,
#   'Humidity': 71,
#   'Cloudiness': 44,
#   'Wind Speed': 22.59,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vostok',
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 50.79,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.59,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 89,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 57.99,
#   'Humidity': 79,
#   'Cloudiness': 47,
#   'Wind Speed': 16.58,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 38,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kon Tum',
#   'Lat': 14.35,
#   'Lng': 108,
#   'Max Temp': 75.16,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Current Description': 'overcast clouds',
#   'Country': 'VN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Alice Town',
#   'Lat': 25.72,
#   'Lng': -79.3,
#   'Max Temp': 82.67,
#   'Humidity': 81,
#   'Cloudiness': 39,
#   'Wind Speed': 15.73,
#   'Current Description': 'scattered clouds',
#   'Country': 'BS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 59.11,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 6.24,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kindia',
#   'Lat': 10.06,
#   'Lng': -12.87,
#   'Max Temp': 85.69,
#   'Humidity': 61,
#   'Cloudiness': 95,
#   'Wind Speed': 3.56,
#   'Current Description': 'overcast clouds',
#   'Country': 'GN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gualaceo',
#   'Lat': -2.9,
#   'Lng': -78.78,
#   'Max Temp': 55.4,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Current Description': 'moderate rain',
#   'Country': 'EC',
#   'Rain (inches)': 1.18,
#   'Snow (inches)': '0.0'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Atar',
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Max Temp': 108.25,
#   'Humidity': 9,
#   'Cloudiness': 14,
#   'Wind Speed': 15.5,
#   'Current Description': 'few clouds',
#   'Country': 'MR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 23.04,
#   'Current Description': 'shower rain',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.31,
#   'Lng': 121.11,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Country': 'PH',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ossora',
#   'Lat': 59.24,
#   'Lng': 163.07,
#   'Max Temp': 54.86,
#   'Humidity': 71,
#   'Cloudiness': 72,
#   'Wind Speed': 1.21,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 53.6,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'mist',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 53,
#   'Wind Speed': 21.92,
#   'Current Description': 'moderate rain',
#   'Country': 'ZA',
#   'Rain (inches)': 1.22,
#   'Snow (inches)': '0.0'},
#  {'City': 'Mangrol',
#   'Lat': 21.12,
#   'Lng': 70.12,
#   'Max Temp': 88.88,
#   'Humidity': 66,
#   'Cloudiness': 98,
#   'Wind Speed': 11.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kabo',
#   'Lat': 7.7,
#   'Lng': 18.63,
#   'Max Temp': 90.21,
#   'Humidity': 48,
#   'Cloudiness': 40,
#   'Wind Speed': 4.56,
#   'Current Description': 'scattered clouds',
#   'Country': 'CF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Grand Baie',
#   'Lat': -20.02,
#   'Lng': 57.58,
#   'Max Temp': 77,
#   'Humidity': 70,
#   'Cloudiness': 83,
#   'Wind Speed': 13,
#   'Current Description': 'broken clouds',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ancud',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 44.01,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'shower rain',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 39.99,
#   'Humidity': 91,
#   'Cloudiness': 28,
#   'Wind Speed': 2.19,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Te Anau',
#   'Lat': -45.42,
#   'Lng': 167.72,
#   'Max Temp': 43.32,
#   'Humidity': 86,
#   'Cloudiness': 88,
#   'Wind Speed': 2.08,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Patricio',
#   'Lat': 19.22,
#   'Lng': -104.7,
#   'Max Temp': 76.12,
#   'Humidity': 76,
#   'Cloudiness': 77,
#   'Wind Speed': 3.13,
#   'Current Description': 'broken clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 84.78,
#   'Humidity': 73,
#   'Cloudiness': 94,
#   'Wind Speed': 6.69,
#   'Current Description': 'overcast clouds',
#   'Country': 'MV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 41.58,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 1.43,
#   'Current Description': 'clear sky',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Urumqi',
#   'Lat': 43.8,
#   'Lng': 87.6,
#   'Max Temp': 89.6,
#   'Humidity': 21,
#   'Cloudiness': 65,
#   'Wind Speed': 20.13,
#   'Current Description': 'broken clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sorong',
#   'Lat': -0.88,
#   'Lng': 131.25,
#   'Max Temp': 79.66,
#   'Humidity': 81,
#   'Cloudiness': 89,
#   'Wind Speed': 2.82,
#   'Current Description': 'light rain',
#   'Country': 'ID',
#   'Rain (inches)': 0.62,
#   'Snow (inches)': '0.0'},
#  {'City': 'Tevriz',
#   'Lat': 57.51,
#   'Lng': 72.4,
#   'Max Temp': 61.65,
#   'Humidity': 55,
#   'Cloudiness': 72,
#   'Wind Speed': 11.3,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.47,
#   'Max Temp': 46.99,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lagos',
#   'Lat': 6.58,
#   'Lng': 3.75,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Country': 'NG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 64.99,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 69.01,
#   'Humidity': 93,
#   'Cloudiness': 54,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds',
#   'Country': 'EC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 66,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain',
#   'Country': 'US',
#   'Rain (inches)': 0.51,
#   'Snow (inches)': '0.0'},
#  {'City': 'Bethal',
#   'Lat': -26.46,
#   'Lng': 29.47,
#   'Max Temp': 66,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 33.71,
#   'Humidity': 85,
#   'Cloudiness': 32,
#   'Wind Speed': 13,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Broome',
#   'Lat': 42.25,
#   'Lng': -75.83,
#   'Max Temp': 62.6,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Asfi',
#   'Lat': 32.3,
#   'Lng': -9.24,
#   'Max Temp': 74.14,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 21.61,
#   'Current Description': 'clear sky',
#   'Country': 'MA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'light intensity shower rain',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kroya',
#   'Lat': -7.63,
#   'Lng': 109.25,
#   'Max Temp': 77.41,
#   'Humidity': 86,
#   'Cloudiness': 48,
#   'Wind Speed': 7.27,
#   'Current Description': 'scattered clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'shower rain',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Country': 'IS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Eskilstuna',
#   'Lat': 59.37,
#   'Lng': 16.51,
#   'Max Temp': 86,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Country': 'SE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kristiansand',
#   'Lat': 58.15,
#   'Lng': 8,
#   'Max Temp': 77,
#   'Humidity': 50,
#   'Cloudiness': 7,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Komarovo',
#   'Lat': 60.18,
#   'Lng': 29.82,
#   'Max Temp': 81,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 15.66,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sault Sainte Marie',
#   'Lat': 46.52,
#   'Lng': -84.33,
#   'Max Temp': 62.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'fog',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Livingston',
#   'Lat': 55.9,
#   'Lng': -3.52,
#   'Max Temp': 66,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds',
#   'Country': 'GB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Olinda',
#   'Lat': -8.01,
#   'Lng': -34.86,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Katsuura',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 77,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Namibe',
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'AO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pareora',
#   'Lat': -44.49,
#   'Lng': 171.21,
#   'Max Temp': 48,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 73.94,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 55.02,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 5.95,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Imeni Poliny Osipenko',
#   'Lat': 52.42,
#   'Lng': 136.49,
#   'Max Temp': 58.96,
#   'Humidity': 77,
#   'Cloudiness': 72,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nador',
#   'Lat': 35.17,
#   'Lng': -2.93,
#   'Max Temp': 87.8,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Description': 'clear sky',
#   'Country': 'MA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 4.68,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hambantota',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 91.4,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds',
#   'Country': 'LK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mogzon',
#   'Lat': 51.74,
#   'Lng': 111.96,
#   'Max Temp': 68.47,
#   'Humidity': 60,
#   'Cloudiness': 26,
#   'Wind Speed': 5.64,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dombas',
#   'Lat': 62.07,
#   'Lng': 9.12,
#   'Max Temp': 76.21,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 12.71,
#   'Current Description': 'clear sky',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 76.77,
#   'Humidity': 77,
#   'Cloudiness': 25,
#   'Wind Speed': 15.97,
#   'Current Description': 'scattered clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Korla',
#   'Lat': 41.76,
#   'Lng': 86.15,
#   'Max Temp': 91.76,
#   'Humidity': 11,
#   'Cloudiness': 64,
#   'Wind Speed': 6.76,
#   'Current Description': 'broken clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 75.2,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 41,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds',
#   'Country': 'SJ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Biak',
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 74.66,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Current Description': 'moderate rain',
#   'Country': 'ID',
#   'Rain (inches)': 1.76,
#   'Snow (inches)': '0.0'},
#  {'City': 'Malpe',
#   'Lat': 13.35,
#   'Lng': 74.72,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 44.78,
#   'Humidity': 76,
#   'Cloudiness': 83,
#   'Wind Speed': 4.99,
#   'Current Description': 'broken clouds',
#   'Country': 'UY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 59.9,
#   'Humidity': 56,
#   'Cloudiness': 24,
#   'Wind Speed': 14.36,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain',
#   'Country': 'CK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Porto Walter',
#   'Lat': -8.27,
#   'Lng': -72.74,
#   'Max Temp': 72.21,
#   'Humidity': 96,
#   'Cloudiness': 84,
#   'Wind Speed': 0.65,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.23,
#   'Snow (inches)': '0.0'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.68,
#   'Max Temp': 53.92,
#   'Humidity': 42,
#   'Cloudiness': 29,
#   'Wind Speed': 8.95,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Alofi',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 93,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'NU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Angoram',
#   'Lat': -4.06,
#   'Lng': 144.07,
#   'Max Temp': 76.35,
#   'Humidity': 96,
#   'Cloudiness': 93,
#   'Wind Speed': 1.54,
#   'Current Description': 'light rain',
#   'Country': 'PG',
#   'Rain (inches)': 0.54,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sheltozero',
#   'Lat': 61.37,
#   'Lng': 35.37,
#   'Max Temp': 65.59,
#   'Humidity': 55,
#   'Cloudiness': 89,
#   'Wind Speed': 10.11,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Talara',
#   'Lat': -4.58,
#   'Lng': -81.27,
#   'Max Temp': 66.27,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 14.63,
#   'Current Description': 'broken clouds',
#   'Country': 'PE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Raudeberg',
#   'Lat': 61.99,
#   'Lng': 5.14,
#   'Max Temp': 80.6,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.76,
#   'Max Temp': 88,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 15.01,
#   'Current Description': 'clear sky',
#   'Country': 'IL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Yemelyanovo',
#   'Lat': 56.17,
#   'Lng': 92.68,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 89,
#   'Wind Speed': 4.47,
#   'Current Description': 'moderate rain',
#   'Country': 'RU',
#   'Rain (inches)': 1.62,
#   'Snow (inches)': '0.0'},
#  {'City': 'Tazmalt',
#   'Lat': 36.39,
#   'Lng': 4.4,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds',
#   'Country': 'DZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Victoria',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'HK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 69.8,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 18.34,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Orsha',
#   'Lat': 54.52,
#   'Lng': 30.41,
#   'Max Temp': 84.2,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky',
#   'Country': 'BY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Havre-Saint-Pierre',
#   'Lat': 50.23,
#   'Lng': -63.6,
#   'Max Temp': 64.4,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Jalu',
#   'Lat': 29.03,
#   'Lng': 21.55,
#   'Max Temp': 94.69,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 14.94,
#   'Current Description': 'clear sky',
#   'Country': 'LY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 81.09,
#   'Humidity': 79,
#   'Cloudiness': 10,
#   'Wind Speed': 9.66,
#   'Current Description': 'clear sky',
#   'Country': 'BS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ilulissat',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 33.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'fog',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 67.73,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 15.21,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 87.01,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 7.02,
#   'Current Description': 'clear sky',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Borovskoy',
#   'Lat': 53.8,
#   'Lng': 64.15,
#   'Max Temp': 61.29,
#   'Humidity': 55,
#   'Cloudiness': 5,
#   'Wind Speed': 14.67,
#   'Current Description': 'light rain',
#   'Country': 'KZ',
#   'Rain (inches)': 0.37,
#   'Snow (inches)': '0.0'},
#  {'City': 'Tilichiki',
#   'Lat': 60.47,
#   'Lng': 166.1,
#   'Max Temp': 49.51,
#   'Humidity': 70,
#   'Cloudiness': 7,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tokur',
#   'Lat': 53.13,
#   'Lng': 132.9,
#   'Max Temp': 56.3,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Antonio',
#   'Lat': 29.42,
#   'Lng': -98.49,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'mist',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Quintin',
#   'Lat': 30.48,
#   'Lng': -115.95,
#   'Max Temp': 61.47,
#   'Humidity': 92,
#   'Cloudiness': 6,
#   'Wind Speed': 7.25,
#   'Current Description': 'clear sky',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nelson Bay',
#   'Lat': -32.72,
#   'Lng': 152.15,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Corrente',
#   'Lat': -3.74,
#   'Lng': -43.34,
#   'Max Temp': 81.63,
#   'Humidity': 69,
#   'Cloudiness': 19,
#   'Wind Speed': 2.15,
#   'Current Description': 'few clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lorengau',
#   'Lat': -2.02,
#   'Lng': 147.27,
#   'Max Temp': 83.07,
#   'Humidity': 76,
#   'Cloudiness': 80,
#   'Wind Speed': 9.1,
#   'Current Description': 'light rain',
#   'Country': 'PG',
#   'Rain (inches)': 0.18,
#   'Snow (inches)': '0.0'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 69.44,
#   'Humidity': 52,
#   'Cloudiness': 12,
#   'Wind Speed': 9.98,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'shower rain',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Padang',
#   'Lat': -0.95,
#   'Lng': 100.35,
#   'Max Temp': 81.14,
#   'Humidity': 75,
#   'Cloudiness': 79,
#   'Wind Speed': 2.84,
#   'Current Description': 'broken clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 78.62,
#   'Humidity': 76,
#   'Cloudiness': 96,
#   'Wind Speed': 3.87,
#   'Current Description': 'overcast clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Anshun',
#   'Lat': 26.25,
#   'Lng': 105.93,
#   'Max Temp': 70.93,
#   'Humidity': 91,
#   'Cloudiness': 93,
#   'Wind Speed': 12.12,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Fiumicino',
#   'Lat': 41.77,
#   'Lng': 12.23,
#   'Max Temp': 95,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky',
#   'Country': 'IT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.87,
#   'Lng': -67.5,
#   'Max Temp': 28.4,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 66,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 11.99,
#   'Current Description': 'light rain',
#   'Country': 'GB',
#   'Rain (inches)': 0.16,
#   'Snow (inches)': '0.0'},
#  {'City': 'Campos Altos',
#   'Lat': -19.7,
#   'Lng': -46.17,
#   'Max Temp': 65.82,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 4.5,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 27,
#   'Wind Speed': 6.93,
#   'Current Description': 'light rain',
#   'Country': 'RE',
#   'Rain (inches)': 0.23,
#   'Snow (inches)': '0.0'},
#  {'City': 'Cayenne',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 0.92,
#   'Current Description': 'broken clouds',
#   'Country': 'GF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vilyuysk',
#   'Lat': 63.76,
#   'Lng': 121.62,
#   'Max Temp': 71.46,
#   'Humidity': 62,
#   'Cloudiness': 60,
#   'Wind Speed': 4.79,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Shemordan',
#   'Lat': 56.19,
#   'Lng': 50.4,
#   'Max Temp': 71.94,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 16.42,
#   'Current Description': 'moderate rain',
#   'Country': 'RU',
#   'Rain (inches)': 1.33,
#   'Snow (inches)': '0.0'},
#  {'City': 'Butembo',
#   'Lat': 0.15,
#   'Lng': 29.28,
#   'Max Temp': 70.79,
#   'Humidity': 72,
#   'Cloudiness': 85,
#   'Wind Speed': 1.97,
#   'Current Description': 'light rain',
#   'Country': 'CD',
#   'Rain (inches)': 0.67,
#   'Snow (inches)': '0.0'},
#  {'City': 'Airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 56.8,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Current Description': 'overcast clouds',
#   'Country': 'TL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Acari',
#   'Lat': -15.43,
#   'Lng': -74.62,
#   'Max Temp': 61.66,
#   'Humidity': 58,
#   'Cloudiness': 44,
#   'Wind Speed': 1.34,
#   'Current Description': 'scattered clouds',
#   'Country': 'PE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pozo Colorado',
#   'Lat': -23.49,
#   'Lng': -58.8,
#   'Max Temp': 49.14,
#   'Humidity': 89,
#   'Cloudiness': 1,
#   'Wind Speed': 5.55,
#   'Current Description': 'clear sky',
#   'Country': 'PY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Zhigalovo',
#   'Lat': 54.81,
#   'Lng': 105.16,
#   'Max Temp': 77.79,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 5.12,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Doha',
#   'Lat': 25.29,
#   'Lng': 51.53,
#   'Max Temp': 109.99,
#   'Humidity': 44,
#   'Cloudiness': 38,
#   'Wind Speed': 12.75,
#   'Current Description': 'scattered clouds',
#   'Country': 'QA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mount Hagen',
#   'Lat': -5.86,
#   'Lng': 144.23,
#   'Max Temp': 59.49,
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 1.83,
#   'Current Description': 'overcast clouds',
#   'Country': 'PG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Maldonado',
#   'Lat': -34.67,
#   'Lng': -54.92,
#   'Max Temp': 41,
#   'Humidity': 93,
#   'Cloudiness': 61,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Country': 'UY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Maltahohe',
#   'Lat': -24.83,
#   'Lng': 16.98,
#   'Max Temp': 69.8,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 7.49,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nara',
#   'Lat': 34.69,
#   'Lng': 135.8,
#   'Max Temp': 82,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Calama',
#   'Lat': -22.47,
#   'Lng': -68.93,
#   'Max Temp': 39.2,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 23.04,
#   'Current Description': 'clear sky',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kamenka',
#   'Lat': 51.32,
#   'Lng': 42.77,
#   'Max Temp': 81,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 30.79,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 24.43,
#   'Current Description': 'light snow',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': 0.4},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 72,
#   'Humidity': 63,
#   'Cloudiness': 6,
#   'Wind Speed': 10,
#   'Current Description': 'clear sky',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lanquin',
#   'Lat': 15.57,
#   'Lng': -89.97,
#   'Max Temp': 68.65,
#   'Humidity': 85,
#   'Cloudiness': 32,
#   'Wind Speed': 2.73,
#   'Current Description': 'scattered clouds',
#   'Country': 'GT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kurilsk',
#   'Lat': 45.23,
#   'Lng': 147.88,
#   'Max Temp': 48.56,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pasighat',
#   'Lat': 28.07,
#   'Lng': 95.33,
#   'Max Temp': 76.42,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Current Description': 'light rain',
#   'Country': 'IN',
#   'Rain (inches)': 0.9,
#   'Snow (inches)': '0.0'},
#  {'City': 'Pasni',
#   'Lat': 25.26,
#   'Lng': 63.47,
#   'Max Temp': 86.13,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 22.1,
#   'Current Description': 'clear sky',
#   'Country': 'PK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bontang',
#   'Lat': 0.13,
#   'Lng': 117.5,
#   'Max Temp': 75.97,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Current Description': 'light rain',
#   'Country': 'ID',
#   'Rain (inches)': 0.73,
#   'Snow (inches)': '0.0'},
#  {'City': 'Keuruu',
#   'Lat': 62.27,
#   'Lng': 24.7,
#   'Max Temp': 84.99,
#   'Humidity': 39,
#   'Cloudiness': 26,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds',
#   'Country': 'FI',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 49.08,
# ...
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 63.28,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 7.18,
#   'Current Description': 'clear sky',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Monte Patria',
#   'Lat': -30.69,
#   'Lng': -70.95,
#   'Max Temp': 54.54,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mvuma',
#   'Lat': -19.28,
#   'Lng': 30.53,
#   'Max Temp': 74.43,
#   'Humidity': 24,
#   'Cloudiness': 5,
#   'Wind Speed': 4.41,
#   'Current Description': 'clear sky',
#   'Country': 'ZW',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 80.1,
#   'Humidity': 32,
#   'Cloudiness': 65,
#   'Wind Speed': 8.46,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hailar',
#   'Lat': 49.2,
#   'Lng': 119.7,
#   'Max Temp': 68.31,
#   'Humidity': 50,
#   'Cloudiness': 42,
#   'Wind Speed': 4.12,
#   'Current Description': 'scattered clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Manicore',
#   'Lat': -5.81,
#   'Lng': -61.3,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 30,
#   'Wind Speed': 1.12,
#   'Current Description': 'scattered clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tecoanapa',
#   'Lat': 16.52,
#   'Lng': -98.75,
#   'Max Temp': 78.19,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Current Description': 'overcast clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ayagoz',
#   'Lat': 47.97,
#   'Lng': 80.44,
#   'Max Temp': 78.19,
#   'Humidity': 23,
#   'Cloudiness': 100,
#   'Wind Speed': 29.62,
#   'Current Description': 'overcast clouds',
#   'Country': 'KZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Berbera',
#   'Lat': 10.44,
#   'Lng': 45.01,
#   'Max Temp': 99.46,
#   'Humidity': 31,
#   'Cloudiness': 80,
#   'Wind Speed': 9.46,
#   'Current Description': 'broken clouds',
#   'Country': 'SO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Duluth',
#   'Lat': 46.78,
#   'Lng': -92.11,
#   'Max Temp': 66.99,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Steinbach',
#   'Lat': 50.17,
#   'Lng': 8.57,
#   'Max Temp': 80.01,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Current Description': 'few clouds',
#   'Country': 'DE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Turukhansk',
#   'Lat': 65.82,
#   'Lng': 87.98,
#   'Max Temp': 74.53,
#   'Humidity': 65,
#   'Cloudiness': 64,
#   'Wind Speed': 6.02,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.43,
#   'Snow (inches)': '0.0'},
#  {'City': 'Chimoio',
#   'Lat': -19.12,
#   'Lng': 33.48,
#   'Max Temp': 80.6,
#   'Humidity': 34,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds',
#   'Country': 'MZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Iralaya',
#   'Lat': 15,
#   'Lng': -83.23,
#   'Max Temp': 80.24,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 11.12,
#   'Current Description': 'light rain',
#   'Country': 'HN',
#   'Rain (inches)': 0.98,
#   'Snow (inches)': '0.0'},
#  {'City': 'Rundu',
#   'Lat': -17.93,
#   'Lng': 19.77,
#   'Max Temp': 64.4,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Coquimbo',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 79,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Greenville',
#   'Lat': 35.61,
#   'Lng': -77.37,
#   'Max Temp': 73.99,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 6.42,
#   'Current Description': 'overcast clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Burnie',
#   'Lat': -41.07,
#   'Lng': 145.92,
#   'Max Temp': 44.01,
#   'Humidity': 87,
#   'Cloudiness': 72,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Akdepe',
#   'Lat': 42.06,
#   'Lng': 59.38,
#   'Max Temp': 78.8,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky',
#   'Country': 'TM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Banff',
#   'Lat': 51.18,
#   'Lng': -115.57,
#   'Max Temp': 48.99,
#   'Humidity': 92,
#   'Cloudiness': 51,
#   'Wind Speed': 3,
#   'Current Description': 'light rain',
#   'Country': 'CA',
#   'Rain (inches)': 0.3,
#   'Snow (inches)': '0.0'},
#  {'City': 'Bonthe',
#   'Lat': 7.53,
#   'Lng': -12.51,
#   'Max Temp': 83.98,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds',
#   'Country': 'SL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Waddan',
#   'Lat': 29.16,
#   'Lng': 16.14,
#   'Max Temp': 95.11,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95,
#   'Current Description': 'clear sky',
#   'Country': 'LY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bograd',
#   'Lat': 54.23,
#   'Lng': 90.83,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 4,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Riberalta',
#   'Lat': -10.98,
#   'Lng': -66.1,
#   'Max Temp': 72.48,
#   'Humidity': 95,
#   'Cloudiness': 94,
#   'Wind Speed': 4.25,
#   'Current Description': 'overcast clouds',
#   'Country': 'BO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Weyburn',
#   'Lat': 49.67,
#   'Lng': -103.85,
#   'Max Temp': 62.01,
#   'Humidity': 72,
#   'Cloudiness': 69,
#   'Wind Speed': 5.99,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Auki',
#   'Lat': -8.77,
#   'Lng': 160.7,
#   'Max Temp': 78.73,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 4.83,
#   'Current Description': 'overcast clouds',
#   'Country': 'SB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bhagalpur',
#   'Lat': 25.25,
#   'Lng': 87,
#   'Max Temp': 93.74,
#   'Humidity': 60,
#   'Cloudiness': 84,
#   'Wind Speed': 1.57,
#   'Current Description': 'broken clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mragowo',
#   'Lat': 53.86,
#   'Lng': 21.31,
#   'Max Temp': 73.4,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Current Description': 'few clouds',
#   'Country': 'PL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Cristobal',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'fog',
#   'Country': 'VE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Novokayakent',
#   'Lat': 42.39,
#   'Lng': 47.99,
#   'Max Temp': 75.2,
#   'Humidity': 47,
#   'Cloudiness': 95,
#   'Wind Speed': 20.13,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Suleja',
#   'Lat': 9.18,
#   'Lng': 7.18,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'NG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vila Velha',
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 75,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 76.95,
#   'Humidity': 72,
#   'Cloudiness': 51,
#   'Wind Speed': 9.35,
#   'Current Description': 'broken clouds',
#   'Country': 'GA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sur',
#   'Lat': 22.57,
#   'Lng': 59.53,
#   'Max Temp': 94.69,
#   'Humidity': 51,
#   'Cloudiness': 66,
#   'Wind Speed': 9.24,
#   'Current Description': 'broken clouds',
#   'Country': 'OM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sabang',
#   'Lat': 5.89,
#   'Lng': 95.32,
#   'Max Temp': 83.7,
#   'Humidity': 71,
#   'Cloudiness': 25,
#   'Wind Speed': 7.36,
#   'Current Description': 'scattered clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kavaratti',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 83.35,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 24,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kysyl-Syr',
#   'Lat': 63.9,
#   'Lng': 122.76,
#   'Max Temp': 73.56,
#   'Humidity': 48,
#   'Cloudiness': 97,
#   'Wind Speed': 3.2,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Danville',
#   'Lat': 36.59,
#   'Lng': -79.39,
#   'Max Temp': 66,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 4.59,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Longhua',
#   'Lat': 23.61,
#   'Lng': 114.19,
#   'Max Temp': 81.81,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 3.62,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Samarai',
#   'Lat': -10.62,
#   'Lng': 150.67,
#   'Max Temp': 78.78,
#   'Humidity': 83,
#   'Cloudiness': 76,
#   'Wind Speed': 18.32,
#   'Current Description': 'light rain',
#   'Country': 'PG',
#   'Rain (inches)': 0.21,
#   'Snow (inches)': '0.0'},
#  {'City': 'Huarmey',
#   'Lat': -10.07,
#   'Lng': -78.15,
#   'Max Temp': 61.95,
#   'Humidity': 84,
#   'Cloudiness': 93,
#   'Wind Speed': 5.66,
#   'Current Description': 'overcast clouds',
#   'Country': 'PE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Erzin',
#   'Lat': 36.96,
#   'Lng': 36.2,
#   'Max Temp': 79,
#   'Humidity': 84,
#   'Cloudiness': 2,
#   'Wind Speed': 11.01,
#   'Current Description': 'clear sky',
#   'Country': 'TR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Shimoda',
#   'Lat': 34.67,
#   'Lng': 138.95,
#   'Max Temp': 73.99,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'General Pico',
#   'Lat': -35.66,
#   'Lng': -63.76,
#   'Max Temp': 38.62,
#   'Humidity': 74,
#   'Cloudiness': 12,
#   'Wind Speed': 4.16,
#   'Current Description': 'few clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Inirida',
#   'Lat': 3.87,
#   'Lng': -67.92,
#   'Max Temp': 74.41,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Current Description': 'light rain',
#   'Country': 'CO',
#   'Rain (inches)': 0.2,
#   'Snow (inches)': '0.0'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.43,
#   'Max Temp': 44.6,
#   'Humidity': 48,
#   'Cloudiness': 15,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Domoni',
#   'Lat': -12.26,
#   'Lng': 44.53,
#   'Max Temp': 79.95,
#   'Humidity': 71,
#   'Cloudiness': 50,
#   'Wind Speed': 5.66,
#   'Current Description': 'scattered clouds',
#   'Country': 'KM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gusau',
#   'Lat': 12.16,
#   'Lng': 6.66,
#   'Max Temp': 90.91,
#   'Humidity': 47,
#   'Cloudiness': 92,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds',
#   'Country': 'NG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ust-Kuyga',
#   'Lat': 70.02,
#   'Lng': 135.6,
#   'Max Temp': 79.54,
#   'Humidity': 41,
#   'Cloudiness': 76,
#   'Wind Speed': 4.32,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Beitbridge',
#   'Lat': -22.22,
#   'Lng': 30,
#   'Max Temp': 81.25,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 12.77,
#   'Current Description': 'clear sky',
#   'Country': 'ZW',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Reconquista',
#   'Lat': -29.15,
#   'Lng': -59.65,
#   'Max Temp': 42.98,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.22,
#   'Current Description': 'clear sky',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kendari',
#   'Lat': -3.94,
#   'Lng': 122.5,
#   'Max Temp': 75.31,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Current Description': 'light rain',
#   'Country': 'ID',
#   'Rain (inches)': 0.31,
#   'Snow (inches)': '0.0'},
#  {'City': 'Ha Giang',
#   'Lat': 22.83,
#   'Lng': 104.98,
#   'Max Temp': 81.9,
#   'Humidity': 81,
#   'Cloudiness': 55,
#   'Wind Speed': 1.34,
#   'Current Description': 'light rain',
#   'Country': 'VN',
#   'Rain (inches)': 0.12,
#   'Snow (inches)': '0.0'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 22,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kirkcudbright',
#   'Lat': 54.84,
#   'Lng': -4.05,
#   'Max Temp': 61,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Current Description': 'moderate rain',
#   'Country': 'GB',
#   'Rain (inches)': 1.16,
#   'Snow (inches)': '0.0'},
#  {'City': 'Ketchikan',
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Husavik',
#   'Lat': 66.04,
#   'Lng': -17.34,
#   'Max Temp': 50,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Country': 'IS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Antalaha',
#   'Lat': -14.9,
#   'Lng': 50.28,
#   'Max Temp': 78.28,
#   'Humidity': 70,
#   'Cloudiness': 7,
#   'Wind Speed': 13.49,
#   'Current Description': 'clear sky',
#   'Country': 'MG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Axim',
#   'Lat': 4.87,
#   'Lng': -2.24,
#   'Max Temp': 79.75,
#   'Humidity': 81,
#   'Cloudiness': 91,
#   'Wind Speed': 13.27,
#   'Current Description': 'light rain',
#   'Country': 'GH',
#   'Rain (inches)': 0.19,
#   'Snow (inches)': '0.0'},
#  {'City': 'Taraza',
#   'Lat': 7.58,
#   'Lng': -75.4,
#   'Max Temp': 75.38,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.68,
#   'Current Description': 'light rain',
#   'Country': 'CO',
#   'Rain (inches)': 0.13,
#   'Snow (inches)': '0.0'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.02,
#   'Lng': 37.27,
#   'Max Temp': 89.56,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 15.95,
#   'Current Description': 'clear sky',
#   'Country': 'SA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Turkistan',
#   'Lat': 43,
#   'Lng': 68,
#   'Max Temp': 79.5,
#   'Humidity': 16,
#   'Cloudiness': 8,
#   'Wind Speed': 16.44,
#   'Current Description': 'clear sky',
#   'Country': 'KZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Dikson  73.51   80.55     39.49        92         100       20.60
# 1       Bezenchuk  52.98   49.43     77.54        66          58       15.30
# 2          Albany  42.60  -73.97     66.00        74          95        3.89
# 3  Cabo San Lucas  22.89 -109.91     82.99        69          99        3.00
# 4            Lata  40.16   -8.33     78.01        68          94        7.11
# 5      Kaitangata -46.28  169.85     50.00        86          83        1.99
# 6      Nikolskoye  59.70   30.79     78.80        39           0       15.66
# 7    Punta Arenas -53.15  -70.92     33.80        69           0        8.05
# 8       Bathsheba  13.22  -59.52     84.20        74          20       23.04
# 9           Kapaa  22.08 -159.32     78.80        78          90       11.41
#
#   Current Description Country Rain (inches) Snow (inches)
# 0       moderate rain      RU          2.74           0.0
# 1          light rain      RU          0.93           0.0
# 2     overcast clouds      US           0.0           0.0
# 3     overcast clouds      MX           0.0           0.0
# 4     overcast clouds      PT           0.0           0.0
# 5       broken clouds      NZ           0.0           0.0
# 6           clear sky      RU           0.0           0.0
# 7           clear sky      CL           0.0           0.0
# 8          few clouds      BB           0.0           0.0
# 9     overcast clouds      US           0.0           0.0

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain (inches)", "Snow (inches)"]

# Assign district summary df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dikson      RU  73.51   80.55     39.49        92         100
# 1       Bezenchuk      RU  52.98   49.43     77.54        66          58
# 2          Albany      US  42.60  -73.97     66.00        74          95
# 3  Cabo San Lucas      MX  22.89 -109.91     82.99        69          99
# 4            Lata      PT  40.16   -8.33     78.01        68          94
#
#    Wind Speed Current Description Rain (inches) Snow (inches)
# 0       20.60       moderate rain          2.74           0.0
# 1       15.30          light rain          0.93           0.0
# 2        3.89     overcast clouds           0.0           0.0
# 3        3.00     overcast clouds           0.0           0.0
# 4        7.11     overcast clouds           0.0           0.0

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
