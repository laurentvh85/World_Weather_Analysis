# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key
from config import g_key

# %%
#create a random list of coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#coordinates list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add to the cities list.
    if city not in cities:
        cities.append(city)

# %%
cities
# Out:
# ['taolanaro',
#  'vaitupu',
#  'busselton',
#  'dingle',
#  'saleaula',
#  'east london',
#  'blackwater',
#  'mataura',
#  'kavieng',
#  'esperance',
#  'new norfolk',
#  'bambous virieux',
#  'vaini',
#  'hermanus',
#  'dikson',
#  'tuktoyaktuk',
#  'whyalla',
#  'lata',
#  'bluff',
#  'albany',
#  'praia',
#  'san cristobal',
#  'jetpur',
#  'kahului',
#  'nizhneyansk',
#  'ibra',
#  'cape town',
#  'hobart',
#  'longyearbyen',
#  'sitka',
#  'krasnoselkup',
#  'guerrero negro',
#  'port elizabeth',
#  'tumannyy',
#  'rikitea',
#  'ribeira grande',
#  'port alfred',
#  'enshi',
#  'narsaq',
#  'eskisehir',
#  'severo-kurilsk',
#  'talcahuano',
#  'carutapera',
#  'faanui',
#  'carlsbad',
#  'rio branco',
#  'ushuaia',
#  'san ramon',
#  'hithadhoo',
#  'upata',
#  'kapaa',
#  'labuhan',
#  'carnarvon',
#  'dong hoi',
#  'melfort',
#  'klaksvik',
#  'kemi',
#  'kuche',
#  'juegang',
#  'ornskoldsvik',
#  'boa vista',
#  'babanusah',
#  'buraydah',
#  'komsomolskiy',
#  'marzuq',
#  'bethel',
#  'jamestown',
#  'siva',
#  'ponta do sol',
#  'rocha',
#  'brae',
#  'neiafu',
#  'coquimbo',
#  'barrow',
#  'constitucion',
#  'belushya guba',
#  'seydi',
#  'atuona',
#  'arraial do cabo',
#  'saint-philippe',
#  'tutoia',
#  'luderitz',
#  'kloulklubed',
#  'chokurdakh',
#  'north bend',
#  'levelland',
#  'cherskiy',
#  'upernavik',
#  'awbari',
#  'fuling',
#  'scottsburgh',
#  'mount gambier',
#  'vao',
#  'lorengau',
#  'sao filipe',
#  'itupiranga',
#  'yellowknife',
#  'aljezur',
#  'les cayes',
#  'muyezerskiy',
#  'punta arenas',
#  'avarua',
#  'saskylakh',
#  'alihe',
#  'ostrovnoy',
#  'kavaratti',
#  'butaritari',
#  'santa cruz',
#  'cabo san lucas',
#  'mys shmidta',
#  'vredendal',
#  'cayenne',
#  'mar del plata',
#  'cidreira',
#  'hilo',
#  'pevek',
#  'vanimo',
#  'poum',
#  'tazlar',
#  'flinders',
#  'ngara',
#  'suluq',
#  'namibe',
#  'qaanaaq',
#  'kracheh',
#  'boueni',
#  'aswan',
#  'lebu',
#  'baishishan',
#  'kununurra',
#  'tasiilaq',
#  'buin',
#  'cay',
#  'tarudant',
#  'lolua',
#  'saint peter',
#  'padang',
#  'da nang',
#  'nikolskoye',
#  'mahibadhoo',
#  'westport',
#  'vardo',
#  'port-gentil',
#  'ganzhou',
#  'chinna salem',
#  'alekseyevsk',
#  'kodiak',
#  'college',
#  'san patricio',
#  'attawapiskat',
#  'marawi',
#  'saint-pierre',
#  'verkhoyansk',
#  'novopetrovskoye',
#  'halalo',
#  'tuatapere',
#  'saint-francois',
#  'nemuro',
#  'bengkulu',
#  'troitsko-pechorsk',
#  'tarko-sale',
#  'sabha',
#  'yar-sale',
#  'khorramabad',
#  'khatanga',
#  'kruisfontein',
#  'luba',
#  'aklavik',
#  'amderma',
#  'agaro',
#  'san borja',
#  'belaya gora',
#  'tromso',
#  'katsuura',
#  'puerto ayora',
#  'pisco',
#  'barentsburg',
#  'parkes',
#  'muheza',
#  'orlik',
#  'mount pleasant',
#  'liwale',
#  'bredasdorp',
#  'chinsali',
#  'alice springs',
#  'liberal',
#  'arman',
#  'san jeronimo',
#  'lavrentiya',
#  'thinadhoo',
#  'nabire',
#  'sumbawa',
#  'barra patuca',
#  'altay',
#  'chapada dos guimaraes',
#  'voyvozh',
#  'rungata',
#  'oussouye',
#  'luwuk',
#  'stornoway',
#  'kieta',
#  'tigil',
#  'candawaga',
#  'araouane',
#  'roald',
#  'azar shahr',
#  'norman wells',
#  'shingu',
#  'panjab',
#  'chuy',
#  'moron',
#  'hamilton',
#  'viedma',
#  'korla',
#  'novikovo',
#  'tornio',
#  'pedra azul',
#  'georgetown',
#  'vila velha',
#  'caravelas',
#  'pula',
#  'kajaani',
#  'nanortalik',
#  'sawakin',
#  'tawnat',
#  'amahai',
#  'cam ranh',
#  'sentyabrskiy',
#  'vasilsursk',
#  'subtanjalla',
#  'manggar',
#  'nouadhibou',
#  'broken hill',
#  'noumea',
#  'airai',
#  'keti bandar',
#  'hay river',
#  'tadpatri',
#  'bitung',
#  'sahrak',
#  'de-kastri',
#  'gazanjyk',
#  'rostovka',
#  'coromandel',
#  'lamu',
#  'lagoa',
#  'balkhash',
#  'hualmay',
#  'jadu',
#  'illoqqortoormiut',
#  'tashtyp',
#  'ossora',
#  'tiznit',
#  'lompoc',
#  'necochea',
#  'tir pol',
#  'bathsheba',
#  'vaitape',
#  'tanhacu',
#  'pedernales',
#  'egvekinot',
#  'chapais',
#  'harper',
#  'provideniya',
#  'torbay',
#  'thompson',
#  'pozo de gamboa',
#  'husavik',
#  'cockburn town',
#  'taoudenni',
#  'doume',
#  'fort nelson',
#  'sao joao da barra',
#  'rio gallegos',
#  'barbar',
#  'aripuana',
#  'venado tuerto',
#  'nanakuli',
#  'abnub',
#  'den helder',
#  'tsihombe',
#  'jiaojiang',
#  'dhidhdhoo',
#  'solnechnyy',
#  'la ronge',
#  'yeniseysk',
#  'ayia marina',
#  'leningradskiy',
#  'bahia honda',
#  'souillac',
#  'omsukchan',
#  'grand gaube',
#  'mentok',
#  'fukue',
#  'batagay-alyta',
#  'casa nova',
#  'beyneu',
#  'mumford',
#  'saint george',
#  'las cruces',
#  'texarkana',
#  'matagami',
#  'manta',
#  'mogadishu',
#  'mahebourg',
#  'castro',
#  'qasigiannguit',
#  'touros',
#  'batticaloa',
#  'toamasina',
#  'beringovskiy',
#  'coihaique',
#  'saint-georges',
#  'yirol',
#  'rio de janeiro',
#  'tiksi',
#  'brits',
#  'salalah',
#  'olafsvik',
#  'genhe',
#  'yanaul',
#  'karasjok',
#  'alugan',
#  'bonthe',
#  'seoul',
#  'huarmey',
#  'sao jose da coroa grande',
#  'ramanathapuram',
#  'buala',
#  'toba',
#  'kaitangata',
#  'reftinskiy',
#  'port augusta',
#  'dalby',
#  'piacabucu',
#  'antalaha',
#  'xuddur',
#  'mulege',
#  'sulangan',
#  'kefalos',
#  'byron bay',
#  'fairbanks',
#  'namatanai',
#  'otuzco',
#  'nome',
#  'sorong',
#  'comodoro rivadavia',
#  'saint anthony',
#  'shimoda',
#  'parrsboro',
#  'grand river south east',
#  'klaeng',
#  'plettenberg bay',
#  'ambilobe',
#  'turukhansk',
#  'bac lieu',
#  'saldanha',
#  'tokur',
#  'la asuncion',
#  'beloha',
#  'port hardy',
#  'linhares',
#  'howard springs',
#  'cap malheureux',
#  'muskogee',
#  'victoria',
#  'catabola',
#  'santa cruz de la palma',
#  'beruwala',
#  'halifax',
#  'hambantota',
#  'rovaniemi',
#  'fortuna',
#  'freeport',
#  'urumqi',
#  'sola',
#  'evensk',
#  'puerto leguizamo',
#  'pauini',
#  'morondava',
#  'colwyn bay',
#  'tilichiki',
#  'luang prabang',
#  'nicoya',
#  'dengzhou',
#  'esso',
#  'zhanatas',
#  'haines junction',
#  'ixtapa',
#  'xique-xique',
#  'ferry pass',
#  'roebourne',
#  'berlevag',
#  'catazaja',
#  'chodavaram',
#  'khasan',
#  'linares',
#  'avera',
#  'gayny',
#  'kyzyl-suu',
#  'vestmannaeyjar',
#  'kanda',
#  'hobyo',
#  'tessalit',
#  'lucapa',
#  'chagda',
#  'ahipara',
#  'quatre cocos',
#  'laguna',
#  'ancud',
#  'arrecife',
#  'meulaboh',
#  'bellevue',
#  'conceicao do araguaia',
#  'kiama',
#  'goure',
#  'rawannawi',
#  'sinjah',
#  'pangkalanbuun',
#  'malmesbury',
#  'kota bahru',
#  'sayyan',
#  'clyde river',
#  'mehamn',
#  'harwich',
#  'aporawan',
#  'ilam',
#  'akropong',
#  'christchurch',
#  'karauzyak',
#  'sistranda',
#  'mizan teferi',
#  'mirnyy',
#  'loralai',
#  'metro',
#  'panaba',
#  'birjand',
#  'khuzdar',
#  'catamarca',
#  'inirida',
#  'bridlington',
#  'vidim',
#  'puerto carreno',
#  'giyani',
#  'shumyachi',
#  'banjar',
#  'werda',
#  'tamala',
#  'marsh harbour',
#  'cupertino',
#  'galesong',
#  'epe',
#  'jalu',
#  'megion',
#  'kastrakion',
#  'kilindoni',
#  'kula',
#  'camacha',
#  'rawson',
#  'itarema',
#  'ahuimanu',
#  'sol-iletsk',
#  'ha tinh',
#  'ust-tsilma',
#  'sumenep',
#  'progreso',
#  'along',
#  'carupano',
#  'wewak',
#  'sisimiut',
#  'miri',
#  'cacu',
#  'teya',
#  'bela',
#  'craig',
#  'suleja',
#  'makakilo city',
#  'lac du bonnet',
#  'caldwell',
#  'nacala',
#  'la palma',
#  'colesberg',
#  'barahona',
#  'kaeo',
#  'isangel',
#  'filadelfia',
#  'margate',
#  'marcona',
#  'batsfjord',
#  'tukrah',
#  'portel',
#  'monte cristi',
#  'georgiyevka',
#  'chanute',
#  'te anau',
#  'romanovka',
#  'bonavista',
#  'mocambique',
#  'polovinnoye',
#  'grindavik',
#  'sao sebastiao',
#  'yeppoon',
#  'fare',
#  'gao',
#  'simao',
#  'maniitsoq',
#  'abu samrah',
#  'khandbari',
#  'olga',
#  'dunedin',
#  'makokou',
#  'lar',
#  'adrar',
#  'gazli',
#  'burkhala',
#  'samarai',
#  'troitskoye',
#  'rock springs',
#  'diffa',
#  'eyl',
#  'severo-yeniseyskiy',
#  'saquena',
#  'sorvag',
#  'shache',
#  'turinsk',
#  'bell ville',
#  'nipawin',
#  'petropavlovsk-kamchatskiy',
#  'locri',
#  'iqaluit',
#  'nichlaul',
#  'licheng',
#  'soc trang',
#  'manzil tamim',
#  'akyab',
#  'ziniare',
#  'paamiut',
#  'geraldton',
#  'samusu',
#  'pangnirtung',
#  'khonuu',
#  'bilecik',
#  'tual',
#  'san carlos de bariloche',
#  'yichun',
#  'faya',
#  'weligama',
#  'salinopolis',
#  'xingcheng',
#  'borogontsy',
#  'vanavara',
#  'sur',
#  'constantine',
#  'verkhnevilyuysk',
#  'corner brook',
#  'jiazi',
#  'moree',
#  'mbandaka',
#  'haverfordwest',
#  'birpur',
#  'flin flon',
#  'havre-saint-pierre',
#  'baft',
#  'basudebpur',
#  'kampong thum',
#  'mchinji',
#  'ukiah',
#  'bokoro',
#  'ambodifototra',
#  'sosnovka',
#  'caramay',
#  'bilibino',
#  'kamensk-shakhtinskiy',
#  'iquique',
#  'nguiu',
#  'san quintin',
#  'tarsus',
#  'hasaki',
#  'gweru',
#  'zhezkazgan',
#  'pampierstad',
#  'gerede',
#  'cabedelo',
#  'nalhati',
#  'polur',
#  'mnogovershinnyy',
#  'ponyri',
#  'nieuwpoort',
#  'jieshi',
#  'tateyama',
#  'abu kamal',
#  'baykit',
#  'strezhevoy',
#  'talnakh',
#  'tiarei',
#  'peace river',
#  'lazaro cardenas',
#  'aasiaat',
#  'chifeng',
#  'los llanos de aridane',
#  'trairi',
#  'bambanglipuro',
#  'cranbourne',
#  'tadine',
#  'praia da vitoria',
#  'antofagasta',
#  'toul',
#  'gobabis',
#  'gold coast',
#  'varzea da palma',
#  'kentau',
#  'bosanska gradiska',
#  'puerto escondido']

# %%
#URL for Weather API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    
# Loop through all the cities.
for i, city in enumerate(cities):
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
          
        try:
            city_rain = city_weather["rain"]["1h"]
            
        except KeyError:
            city_rain = "0.0"
        try:
            city_snow = city_weather["snow"]["1h"]
                       
        except KeyError:
            city_snow = "0.0"
        
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description,
                          "Country": city_country,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})
        

# If an error is experienced, skip the city.
    except:
        pass

# %%
city_weather = requests.get(city_url)

# %%
city_weather.json()
# Out:
# {'coord': {'lon': -97.07, 'lat': 15.85},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 77,
#   'feels_like': 82.09,
#   'temp_min': 77,
#   'temp_max': 77,
#   'pressure': 1013,
#   'humidity': 83},
#  'visibility': 14484,
#  'wind': {'speed': 5.82, 'deg': 130},
#  'clouds': {'all': 75},
#  'dt': 1593261315,
#  'sys': {'type': 1,
#   'id': 7157,
#   'country': 'MX',
#   'sunrise': 1593259169,
#   'sunset': 1593306193},
#  'timezone': -18000,
#  'id': 3520994,
#  'name': 'Puerto Escondido',
#  'cod': 200}

# %%
city_data
# Out:
# [{'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 59,
#   'Humidity': 80,
#   'Cloudiness': 15,
#   'Wind Speed': 19.1,
#   'Current Description': 'few clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 79.14,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Current Description': 'moderate rain',
#   'Country': 'PH',
#   'Rain (inches)': 1.12,
#   'Snow (inches)': '0.0'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 73.4,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Blackwater',
#   'Lat': -23.58,
#   'Lng': 148.88,
#   'Max Temp': 57.87,
#   'Humidity': 73,
#   'Cloudiness': 46,
#   'Wind Speed': 7.85,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 81.14,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 14.03,
#   'Current Description': 'light rain',
#   'Country': 'PG',
#   'Rain (inches)': 0.23,
#   'Snow (inches)': '0.0'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 57.2,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 39.99,
#   'Humidity': 91,
#   'Cloudiness': 32,
#   'Wind Speed': 2.37,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 75.99,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'shower rain',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Country': 'TO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 57.99,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 17,
#   'Current Description': 'light rain',
#   'Country': 'ZA',
#   'Rain (inches)': 0.13,
#   'Snow (inches)': '0.0'},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 42.78,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 11.9,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 33.46,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 15.82,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Whyalla',
#   'Lat': -33.03,
#   'Lng': 137.58,
#   'Max Temp': 41,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lata',
#   'Lat': 40.16,
#   'Lng': -8.33,
#   'Max Temp': 73,
#   'Humidity': 70,
#   'Cloudiness': 95,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 68,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Praia',
#   'Lat': 14.92,
#   'Lng': -23.51,
#   'Max Temp': 84.2,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Current Description': 'scattered clouds',
#   'Country': 'CV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Cristobal',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'fog',
#   'Country': 'VE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Jetpur',
#   'Lat': 21.73,
#   'Lng': 70.62,
#   'Max Temp': 92.3,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 14.38,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kahului',
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ibra',
#   'Lat': 22.69,
#   'Lng': 58.53,
#   'Max Temp': 108.37,
#   'Humidity': 17,
#   'Cloudiness': 98,
#   'Wind Speed': 9.73,
#   'Current Description': 'overcast clouds',
#   'Country': 'OM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 61,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 23.04,
#   'Current Description': 'light rain',
#   'Country': 'ZA',
#   'Rain (inches)': 0.51,
#   'Snow (inches)': '0.0'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 42.01,
#   'Humidity': 93,
#   'Cloudiness': 38,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 41.83,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Current Description': 'overcast clouds',
#   'Country': 'SJ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'mist',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.47,
#   'Max Temp': 65.57,
#   'Humidity': 48,
#   'Cloudiness': 99,
#   'Wind Speed': 8.5,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 60.1,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 2.48,
#   'Current Description': 'clear sky',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 73.4,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 23.04,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 72.03,
#   'Humidity': 80,
#   'Cloudiness': 31,
#   'Wind Speed': 14.14,
#   'Current Description': 'scattered clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 74.93,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 21.07,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Enshi',
#   'Lat': 30.3,
#   'Lng': 109.48,
#   'Max Temp': 75.61,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.04,
#   'Current Description': 'moderate rain',
#   'Country': 'CN',
#   'Rain (inches)': 2.7,
#   'Snow (inches)': '0.0'},
#  {'City': 'Narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Eskisehir',
#   'Lat': 39.78,
#   'Lng': 30.52,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Country': 'TR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 49.51,
#   'Humidity': 61,
#   'Cloudiness': 19,
#   'Wind Speed': 10.31,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Talcahuano',
#   'Lat': -36.72,
#   'Lng': -73.12,
#   'Max Temp': 48.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Carutapera',
#   'Lat': -1.2,
#   'Lng': -46.02,
#   'Max Temp': 81.16,
#   'Humidity': 87,
#   'Cloudiness': 31,
#   'Wind Speed': 5.23,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.46,
#   'Snow (inches)': '0.0'},
#  {'City': 'Faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 76.78,
#   'Humidity': 76,
#   'Cloudiness': 34,
#   'Wind Speed': 15.97,
#   'Current Description': 'scattered clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Carlsbad',
#   'Lat': 33.16,
#   'Lng': -117.35,
#   'Max Temp': 66.99,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rio Branco',
#   'Lat': -9.97,
#   'Lng': -67.81,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 9,
#   'Wind Speed': 2.24,
#   'Current Description': 'mist',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 33.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Current Description': 'broken clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Ramon',
#   'Lat': 37.78,
#   'Lng': -121.98,
#   'Max Temp': 61,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 84.76,
#   'Humidity': 74,
#   'Cloudiness': 96,
#   'Wind Speed': 6.71,
#   'Current Description': 'overcast clouds',
#   'Country': 'MV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Upata',
#   'Lat': 8.01,
#   'Lng': -62.4,
#   'Max Temp': 78.01,
#   'Humidity': 90,
#   'Cloudiness': 71,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds',
#   'Country': 'VE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Labuhan',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 79.39,
#   'Humidity': 80,
#   'Cloudiness': 7,
#   'Wind Speed': 5.41,
#   'Current Description': 'clear sky',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dong Hoi',
#   'Lat': 17.48,
#   'Lng': 106.6,
#   'Max Temp': 84.09,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 10.04,
#   'Current Description': 'overcast clouds',
#   'Country': 'VN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Melfort',
#   'Lat': 52.87,
#   'Lng': -104.62,
#   'Max Temp': 57.2,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'light rain',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 62.6,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 18.34,
#   'Current Description': 'overcast clouds',
#   'Country': 'FO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kemi',
#   'Lat': 65.86,
#   'Lng': 24.82,
#   'Max Temp': 62.6,
#   'Humidity': 45,
#   'Cloudiness': 33,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'FI',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Juegang',
#   'Lat': 32.32,
#   'Lng': 121.19,
#   'Max Temp': 79,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.35,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ornskoldsvik',
#   'Lat': 63.29,
#   'Lng': 18.72,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'SE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Boa Vista',
#   'Lat': 2.82,
#   'Lng': -60.67,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Buraydah',
#   'Lat': 26.33,
#   'Lng': 43.98,
#   'Max Temp': 109.4,
#   'Humidity': 10,
#   'Cloudiness': 31,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds',
#   'Country': 'SA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 77,
#   'Humidity': 29,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Current Description': 'light rain',
#   'Country': 'UZ',
#   'Rain (inches)': 0.21,
#   'Snow (inches)': '0.0'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.47,
#   'Max Temp': 91.56,
#   'Humidity': 27,
#   'Cloudiness': 88,
#   'Wind Speed': 4.18,
#   'Current Description': 'overcast clouds',
#   'Country': 'YE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 69.01,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Current Description': 'broken clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 66.99,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Siva',
#   'Lat': 29.2,
#   'Lng': 25.52,
#   'Max Temp': 95.9,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 10.11,
#   'Current Description': 'clear sky',
#   'Country': 'EG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 73,
#   'Humidity': 62,
#   'Cloudiness': 6,
#   'Wind Speed': 11.01,
#   'Current Description': 'clear sky',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rocha',
#   'Lat': -34.48,
#   'Lng': -54.33,
#   'Max Temp': 47.91,
#   'Humidity': 71,
#   'Cloudiness': 11,
#   'Wind Speed': 5.37,
#   'Current Description': 'few clouds',
#   'Country': 'UY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Brae',
#   'Lat': 60.4,
#   'Lng': -1.35,
#   'Max Temp': 68,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 21.92,
#   'Current Description': 'overcast clouds',
#   'Country': 'GB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Neiafu',
#   'Lat': -18.65,
#   'Lng': -173.98,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Country': 'TO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Coquimbo',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 48.2,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 39.2,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Constitucion',
#   'Lat': -35.33,
#   'Lng': -72.42,
#   'Max Temp': 51.91,
#   'Humidity': 82,
#   'Cloudiness': 86,
#   'Wind Speed': 4.9,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Seydi',
#   'Lat': 39.48,
#   'Lng': 62.91,
#   'Max Temp': 85.73,
#   'Humidity': 12,
#   'Cloudiness': 28,
#   'Wind Speed': 20.2,
#   'Current Description': 'scattered clouds',
#   'Country': 'TM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 80.33,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 12.24,
#   'Current Description': 'clear sky',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds',
#   'Country': 'RE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tutoia',
#   'Lat': -2.76,
#   'Lng': -42.27,
#   'Max Temp': 83.32,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 8.66,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 68,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds',
#   'Country': 'PW',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 48.97,
#   'Humidity': 49,
#   'Cloudiness': 50,
#   'Wind Speed': 15.32,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'North Bend',
#   'Lat': 43.41,
#   'Lng': -124.22,
#   'Max Temp': 59,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'mist',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Levelland',
#   'Lat': 33.59,
#   'Lng': -102.38,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Current Description': 'few clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 32.58,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 11.97,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 38.34,
#   'Humidity': 85,
#   'Cloudiness': 91,
#   'Wind Speed': 4.97,
#   'Current Description': 'overcast clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Awbari',
#   'Lat': 26.59,
#   'Lng': 12.78,
#   'Max Temp': 98.89,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 17.52,
#   'Current Description': 'clear sky',
#   'Country': 'LY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Fuling',
#   'Lat': 29.7,
#   'Lng': 107.39,
#   'Max Temp': 73.99,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Current Description': 'light rain',
#   'Country': 'CN',
#   'Rain (inches)': 0.62,
#   'Snow (inches)': '0.0'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 28,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 70.27,
#   'Humidity': 70,
#   'Cloudiness': 35,
#   'Wind Speed': 11.39,
#   'Current Description': 'light rain',
#   'Country': 'NC',
#   'Rain (inches)': 0.13,
#   'Snow (inches)': '0.0'},
#  {'City': 'Lorengau',
#   'Lat': -2.02,
#   'Lng': 147.27,
#   'Max Temp': 83.1,
#   'Humidity': 75,
#   'Cloudiness': 78,
#   'Wind Speed': 8.79,
#   'Current Description': 'light rain',
#   'Country': 'PG',
#   'Rain (inches)': 0.14,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 75.06,
#   'Humidity': 78,
#   'Cloudiness': 56,
#   'Wind Speed': 4.76,
#   'Current Description': 'broken clouds',
#   'Country': 'CV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Itupiranga',
#   'Lat': -5.13,
#   'Lng': -49.33,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aljezur',
#   'Lat': 37.32,
#   'Lng': -8.8,
#   'Max Temp': 73,
#   'Humidity': 77,
#   'Cloudiness': 8,
#   'Wind Speed': 13.31,
#   'Current Description': 'clear sky',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Les Cayes',
#   'Lat': 18.2,
#   'Lng': -73.75,
#   'Max Temp': 84.09,
#   'Humidity': 69,
#   'Cloudiness': 96,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds',
#   'Country': 'HT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Muyezerskiy',
#   'Lat': 63.93,
#   'Lng': 31.65,
#   'Max Temp': 63.66,
#   'Humidity': 39,
#   'Cloudiness': 2,
#   'Wind Speed': 11.36,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 26.6,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'light rain',
#   'Country': 'CK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 57.7,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 13.33,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Alihe',
#   'Lat': 50.57,
#   'Lng': 123.72,
#   'Max Temp': 58.44,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 0.18,
#   'Current Description': 'moderate rain',
#   'Country': 'CN',
#   'Rain (inches)': 1.98,
#   'Snow (inches)': '0.0'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 44.35,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 18.43,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kavaratti',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 83.79,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 22.62,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 82.44,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 18.45,
#   'Current Description': 'light rain',
#   'Country': 'KI',
#   'Rain (inches)': 0.2,
#   'Snow (inches)': '0.0'},
#  {'City': 'Santa Cruz',
#   'Lat': -17.8,
#   'Lng': -63.17,
#   'Max Temp': 53.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Current Description': 'overcast clouds',
#   'Country': 'BO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 82.99,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 3.74,
#   'Current Description': 'broken clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vredendal',
#   'Lat': -31.67,
#   'Lng': 18.5,
#   'Max Temp': 62.08,
#   'Humidity': 62,
#   'Cloudiness': 49,
#   'Wind Speed': 25.28,
#   'Current Description': 'scattered clouds',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cayenne',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Current Description': 'light rain',
#   'Country': 'GF',
#   'Rain (inches)': 0.14,
#   'Snow (inches)': '0.0'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 43,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'light rain',
#   'Country': 'AR',
#   'Rain (inches)': 0.25,
#   'Snow (inches)': '0.0'},
#  {'City': 'Cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 55.11,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 31.15,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 22.88,
#   'Current Description': 'light snow',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': 0.3},
#  {'City': 'Vanimo',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 80.17,
#   'Humidity': 82,
#   'Cloudiness': 97,
#   'Wind Speed': 6.67,
#   'Current Description': 'overcast clouds',
#   'Country': 'PG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Poum',
#   'Lat': -20.23,
#   'Lng': 164.02,
#   'Max Temp': 71.13,
#   'Humidity': 60,
#   'Cloudiness': 76,
#   'Wind Speed': 6.62,
#   'Current Description': 'broken clouds',
#   'Country': 'NC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tazlar',
#   'Lat': 46.55,
#   'Lng': 19.51,
#   'Max Temp': 90,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'HU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Flinders',
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 48.99,
#   'Humidity': 80,
#   'Cloudiness': 48,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ngara',
#   'Lat': -2.51,
#   'Lng': 30.66,
#   'Max Temp': 75.58,
#   'Humidity': 41,
#   'Cloudiness': 80,
#   'Wind Speed': 5.01,
#   'Current Description': 'broken clouds',
#   'Country': 'TZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Suluq',
#   'Lat': 31.67,
#   'Lng': 20.25,
#   'Max Temp': 90.39,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 20.54,
#   'Current Description': 'clear sky',
#   'Country': 'LY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Namibe',
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'AO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 41.02,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 1.88,
#   'Current Description': 'clear sky',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Boueni',
#   'Lat': -12.9,
#   'Lng': 45.08,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'YT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aswan',
#   'Lat': 24.09,
#   'Lng': 32.91,
#   'Max Temp': 106.23,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 8.93,
#   'Current Description': 'clear sky',
#   'Country': 'EG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 49.26,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Baishishan',
#   'Lat': 43.58,
#   'Lng': 127.57,
#   'Max Temp': 61.63,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Current Description': 'light rain',
#   'Country': 'CN',
#   'Rain (inches)': 0.38,
#   'Snow (inches)': '0.0'},
#  {'City': 'Kununurra',
#   'Lat': -15.77,
#   'Lng': 128.73,
#   'Max Temp': 64.4,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 5.59,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Buin',
#   'Lat': -33.73,
#   'Lng': -70.75,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 2.04,
#   'Current Description': 'broken clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cay',
#   'Lat': 38.59,
#   'Lng': 31.03,
#   'Max Temp': 79.7,
#   'Humidity': 34,
#   'Cloudiness': 7,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky',
#   'Country': 'TR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint Peter',
#   'Lat': 13.25,
#   'Lng': -59.62,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 25.28,
#   'Current Description': 'few clouds',
#   'Country': 'BB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Padang',
#   'Lat': -0.95,
#   'Lng': 100.35,
#   'Max Temp': 80.8,
#   'Humidity': 75,
#   'Cloudiness': 92,
#   'Wind Speed': 3.31,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Da Nang',
#   'Lat': 16.07,
#   'Lng': 108.22,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Country': 'VN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 80.6,
#   'Humidity': 36,
#   'Cloudiness': 20,
#   'Wind Speed': 13.42,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mahibadhoo',
#   'Lat': 3.78,
#   'Lng': 72.97,
#   'Max Temp': 83.82,
#   'Humidity': 77,
#   'Cloudiness': 70,
#   'Wind Speed': 14.09,
#   'Current Description': 'broken clouds',
#   'Country': 'MV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Westport',
#   'Lat': 41.14,
#   'Lng': -73.36,
#   'Max Temp': 73.4,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 6.51,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'shower rain',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.72,
#   'Lng': 8.78,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Current Description': 'scattered clouds',
#   'Country': 'GA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ganzhou',
#   'Lat': 28.82,
#   'Lng': 115.43,
#   'Max Temp': 81.39,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chinna Salem',
#   'Lat': 11.65,
#   'Lng': 78.9,
#   'Max Temp': 94.57,
#   'Humidity': 44,
#   'Cloudiness': 30,
#   'Wind Speed': 3.74,
#   'Current Description': 'scattered clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Alekseyevsk',
#   'Lat': 57.84,
#   'Lng': 108.35,
#   'Max Temp': 72.95,
#   'Humidity': 52,
#   'Cloudiness': 44,
#   'Wind Speed': 4.21,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 41,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'College',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 3.96,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Patricio',
#   'Lat': 19.22,
#   'Lng': -104.7,
#   'Max Temp': 76.77,
#   'Humidity': 75,
#   'Cloudiness': 71,
#   'Wind Speed': 3.78,
#   'Current Description': 'broken clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Marawi',
#   'Lat': 8,
#   'Lng': 124.29,
#   'Max Temp': 75,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'moderate rain',
#   'Country': 'PH',
#   'Rain (inches)': 1.2,
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.34,
#   'Lng': 55.48,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds',
#   'Country': 'RE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Verkhoyansk',
#   'Lat': 67.54,
#   'Lng': 133.38,
#   'Max Temp': 74.48,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 4.94,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Novopetrovskoye',
#   'Lat': 55.99,
#   'Lng': 36.47,
#   'Max Temp': 84.2,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 15.66,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.42,
#   'Lng': 3.91,
#   'Max Temp': 82,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'FR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 51.17,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 14.16,
#   'Current Description': 'overcast clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 80.38,
#   'Humidity': 81,
#   'Cloudiness': 8,
#   'Wind Speed': 4.29,
#   'Current Description': 'clear sky',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Troitsko-Pechorsk',
#   'Lat': 62.71,
#   'Lng': 56.2,
#   'Max Temp': 54.25,
#   'Humidity': 69,
#   'Cloudiness': 77,
#   'Wind Speed': 2.01,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tarko-Sale',
#   'Lat': 64.92,
#   'Lng': 77.78,
#   'Max Temp': 61,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 7.4,
#   'Current Description': 'heavy intensity rain',
#   'Country': 'RU',
#   'Rain (inches)': 8.64,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sabha',
#   'Lat': 27.04,
#   'Lng': 14.43,
#   'Max Temp': 98.13,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 13.96,
#   'Current Description': 'clear sky',
#   'Country': 'LY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 57.97,
#   'Humidity': 62,
#   'Cloudiness': 85,
#   'Wind Speed': 14.38,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.17,
#   'Snow (inches)': '0.0'},
#  {'City': 'Khorramabad',
#   'Lat': 33.49,
#   'Lng': 48.36,
#   'Max Temp': 100.4,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Country': 'IR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 65.91,
#   'Humidity': 49,
#   'Cloudiness': 73,
#   'Wind Speed': 13.96,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 64.72,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 11.79,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Luba',
#   'Lat': 3.46,
#   'Lng': 8.55,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Description': 'broken clouds',
#   'Country': 'GQ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Agaro',
#   'Lat': 7.85,
#   'Lng': 36.65,
#   'Max Temp': 72.68,
#   'Humidity': 78,
#   'Cloudiness': 97,
#   'Wind Speed': 0.85,
#   'Current Description': 'moderate rain',
#   'Country': 'ET',
#   'Rain (inches)': 1.51,
#   'Snow (inches)': '0.0'},
#  {'City': 'San Borja',
#   'Lat': -14.82,
#   'Lng': -66.85,
#   'Max Temp': 62.37,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 3.06,
#   'Current Description': 'light rain',
#   'Country': 'BO',
#   'Rain (inches)': 0.68,
#   'Snow (inches)': '0.0'},
#  {'City': 'Belaya Gora',
#   'Lat': 68.53,
#   'Lng': 146.42,
#   'Max Temp': 60.82,
#   'Humidity': 38,
#   'Cloudiness': 41,
#   'Wind Speed': 15.84,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tromso',
#   'Lat': 69.65,
#   'Lng': 18.96,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Katsuura',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 78.01,
#   'Humidity': 70,
#   'Cloudiness': 70,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 69.01,
#   'Humidity': 93,
#   'Cloudiness': 80,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds',
#   'Country': 'EC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 61,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'mist',
#   'Country': 'PE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Parkes',
#   'Lat': -33.13,
#   'Lng': 148.18,
#   'Max Temp': 43,
#   'Humidity': 89,
#   'Cloudiness': 88,
#   'Wind Speed': 2.04,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Muheza',
#   'Lat': -5.17,
#   'Lng': 38.78,
#   'Max Temp': 80.83,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 8.66,
#   'Current Description': 'clear sky',
#   'Country': 'TZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Orlik',
#   'Lat': 52.52,
#   'Lng': 99.83,
#   'Max Temp': 61.75,
#   'Humidity': 61,
#   'Cloudiness': 63,
#   'Wind Speed': 5.64,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.52,
#   'Snow (inches)': '0.0'},
#  {'City': 'Mount Pleasant',
#   'Lat': 32.79,
#   'Lng': -79.86,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'haze',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Liwale',
#   'Lat': -9.77,
#   'Lng': 37.93,
#   'Max Temp': 87.15,
#   'Humidity': 30,
#   'Cloudiness': 52,
#   'Wind Speed': 6.38,
#   'Current Description': 'broken clouds',
#   'Country': 'TZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 20.8,
#   'Current Description': 'overcast clouds',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chinsali',
#   'Lat': -10.54,
#   'Lng': 32.08,
#   'Max Temp': 78.33,
#   'Humidity': 39,
#   'Cloudiness': 81,
#   'Wind Speed': 6.44,
#   'Current Description': 'broken clouds',
#   'Country': 'ZM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 48.2,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Liberal',
#   'Lat': 37.04,
#   'Lng': -100.92,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.17,
#   'Max Temp': 46.74,
#   'Humidity': 86,
#   'Cloudiness': 62,
#   'Wind Speed': 1.07,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Jeronimo',
#   'Lat': -11.95,
#   'Lng': -75.28,
#   'Max Temp': 48.78,
#   'Humidity': 62,
#   'Cloudiness': 88,
#   'Wind Speed': 1.77,
#   'Current Description': 'overcast clouds',
#   'Country': 'PE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 40.1,
#   'Humidity': 82,
#   'Cloudiness': 51,
#   'Wind Speed': 17.09,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.53,
#   'Lng': 72.93,
#   'Max Temp': 85.12,
#   'Humidity': 72,
#   'Cloudiness': 43,
#   'Wind Speed': 9.08,
#   'Current Description': 'scattered clouds',
#   'Country': 'MV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nabire',
#   'Lat': -3.37,
#   'Lng': 135.48,
#   'Max Temp': 77.99,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Barra Patuca',
#   'Lat': 15.8,
#   'Lng': -84.28,
#   'Max Temp': 81.77,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Current Description': 'overcast clouds',
#   'Country': 'HN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Altay',
#   'Lat': 47.87,
#   'Lng': 88.12,
#   'Max Temp': 77.83,
#   'Humidity': 31,
#   'Cloudiness': 43,
#   'Wind Speed': 0.22,
#   'Current Description': 'scattered clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chapada Dos Guimaraes',
#   'Lat': -15.46,
#   'Lng': -55.75,
#   'Max Temp': 66.2,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'mist',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Voyvozh',
#   'Lat': 62.89,
#   'Lng': 54.96,
#   'Max Temp': 53.19,
#   'Humidity': 72,
#   'Cloudiness': 95,
#   'Wind Speed': 6.2,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.26,
#   'Snow (inches)': '0.0'},
#  {'City': 'Oussouye',
#   'Lat': 12.48,
#   'Lng': -16.55,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 83,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain',
#   'Country': 'SN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Luwuk',
#   'Lat': -0.95,
#   'Lng': 122.79,
#   'Max Temp': 75.58,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 6.76,
#   'Current Description': 'light rain',
#   'Country': 'ID',
#   'Rain (inches)': 0.89,
#   'Snow (inches)': '0.0'},
#  {'City': 'Stornoway',
#   'Lat': 58.21,
#   'Lng': -6.39,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Country': 'GB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kieta',
#   'Lat': -6.22,
#   'Lng': 155.63,
#   'Max Temp': 77.76,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.97,
#   'Current Description': 'moderate rain',
#   'Country': 'PG',
#   'Rain (inches)': 1.94,
#   'Snow (inches)': '0.0'},
#  {'City': 'Tigil',
#   'Lat': 57.8,
#   'Lng': 158.67,
#   'Max Temp': 43.86,
#   'Humidity': 81,
#   'Cloudiness': 5,
#   'Wind Speed': 5.61,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Araouane',
#   'Lat': 18.9,
#   'Lng': -3.53,
#   'Max Temp': 114.22,
#   'Humidity': 5,
#   'Cloudiness': 22,
#   'Wind Speed': 9.35,
#   'Current Description': 'few clouds',
#   'Country': 'ML',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Roald',
#   'Lat': 62.58,
#   'Lng': 6.13,
#   'Max Temp': 78.8,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Shingu',
#   'Lat': 33.73,
#   'Lng': 135.98,
#   'Max Temp': 72.32,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Current Description': 'light rain',
#   'Country': 'JP',
#   'Rain (inches)': 0.42,
#   'Snow (inches)': '0.0'},
#  {'City': 'Panjab',
#   'Lat': 34.39,
#   'Lng': 67.02,
#   'Max Temp': 73.89,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 13.82,
#   'Current Description': 'clear sky',
#   'Country': 'AF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 48.42,
#   'Humidity': 69,
#   'Cloudiness': 8,
#   'Wind Speed': 6.38,
#   'Current Description': 'clear sky',
#   'Country': 'UY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Moron',
#   'Lat': -34.65,
#   'Lng': -58.62,
#   'Max Temp': 52,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Current Description': 'overcast clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hamilton',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 75,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Viedma',
#   'Lat': -40.81,
#   'Lng': -63,
#   'Max Temp': 41.79,
#   'Humidity': 69,
#   'Cloudiness': 78,
#   'Wind Speed': 5.44,
#   'Current Description': 'broken clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Korla',
#   'Lat': 41.76,
#   'Lng': 86.15,
#   'Max Temp': 90.14,
#   'Humidity': 13,
#   'Cloudiness': 13,
#   'Wind Speed': 8.66,
#   'Current Description': 'few clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Novikovo',
#   'Lat': 51.15,
#   'Lng': 37.89,
#   'Max Temp': 78.06,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
# ...
#   'Country': 'LK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Salinopolis',
#   'Lat': -0.61,
#   'Lng': -47.36,
#   'Max Temp': 81.59,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 8.59,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.51,
#   'Snow (inches)': '0.0'},
#  {'City': 'Xingcheng',
#   'Lat': 40.62,
#   'Lng': 120.72,
#   'Max Temp': 72.55,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26,
#   'Current Description': 'clear sky',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Borogontsy',
#   'Lat': 62.67,
#   'Lng': 131.17,
#   'Max Temp': 68.43,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 4.97,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.28,
#   'Max Temp': 73.38,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 5.5,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sur',
#   'Lat': 22.57,
#   'Lng': 59.53,
#   'Max Temp': 93.56,
#   'Humidity': 54,
#   'Cloudiness': 80,
#   'Wind Speed': 14.43,
#   'Current Description': 'broken clouds',
#   'Country': 'OM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Constantine',
#   'Lat': 36.37,
#   'Lng': 6.61,
#   'Max Temp': 89.6,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky',
#   'Country': 'DZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Verkhnevilyuysk',
#   'Lat': 63.45,
#   'Lng': 120.32,
#   'Max Temp': 64.42,
#   'Humidity': 72,
#   'Cloudiness': 68,
#   'Wind Speed': 3.33,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Corner Brook',
#   'Lat': 48.97,
#   'Lng': -57.95,
#   'Max Temp': 73.4,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Jiazi',
#   'Lat': 22.88,
#   'Lng': 116.07,
#   'Max Temp': 82.35,
#   'Humidity': 86,
#   'Cloudiness': 63,
#   'Wind Speed': 6.04,
#   'Current Description': 'broken clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Moree',
#   'Lat': -29.47,
#   'Lng': 149.85,
#   'Max Temp': 46.4,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mbandaka',
#   'Lat': 0.05,
#   'Lng': 18.26,
#   'Max Temp': 86.4,
#   'Humidity': 50,
#   'Cloudiness': 77,
#   'Wind Speed': 1.72,
#   'Current Description': 'broken clouds',
#   'Country': 'CD',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Haverfordwest',
#   'Lat': 51.8,
#   'Lng': -4.97,
#   'Max Temp': 62.01,
#   'Humidity': 93,
#   'Cloudiness': 95,
#   'Wind Speed': 26.4,
#   'Current Description': 'light rain',
#   'Country': 'GB',
#   'Rain (inches)': 0.31,
#   'Snow (inches)': '0.0'},
#  {'City': 'Birpur',
#   'Lat': 26.52,
#   'Lng': 87.02,
#   'Max Temp': 86.38,
#   'Humidity': 67,
#   'Cloudiness': 57,
#   'Wind Speed': 3.98,
#   'Current Description': 'broken clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Flin Flon',
#   'Lat': 54.77,
#   'Lng': -101.86,
#   'Max Temp': 60.8,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Havre-Saint-Pierre',
#   'Lat': 50.23,
#   'Lng': -63.6,
#   'Max Temp': 64.4,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'thunderstorm',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Baft',
#   'Lat': 29.23,
#   'Lng': 56.61,
#   'Max Temp': 91.96,
#   'Humidity': 11,
#   'Cloudiness': 54,
#   'Wind Speed': 10.38,
#   'Current Description': 'broken clouds',
#   'Country': 'IR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Basudebpur',
#   'Lat': 21.14,
#   'Lng': 86.74,
#   'Max Temp': 83.8,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Current Description': 'light rain',
#   'Country': 'IN',
#   'Rain (inches)': 0.46,
#   'Snow (inches)': '0.0'},
#  {'City': 'Kampong Thum',
#   'Lat': 12.71,
#   'Lng': 104.89,
#   'Max Temp': 81.05,
#   'Humidity': 85,
#   'Cloudiness': 55,
#   'Wind Speed': 1.07,
#   'Current Description': 'moderate rain',
#   'Country': 'KH',
#   'Rain (inches)': 1.63,
#   'Snow (inches)': '0.0'},
#  {'City': 'Mchinji',
#   'Lat': -13.8,
#   'Lng': 32.88,
#   'Max Temp': 76.24,
#   'Humidity': 36,
#   'Cloudiness': 78,
#   'Wind Speed': 2.37,
#   'Current Description': 'broken clouds',
#   'Country': 'MW',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ukiah',
#   'Lat': 39.15,
#   'Lng': -123.21,
#   'Max Temp': 63,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bokoro',
#   'Lat': 12.38,
#   'Lng': 17.06,
#   'Max Temp': 98.08,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 5.28,
#   'Current Description': 'clear sky',
#   'Country': 'TD',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sosnovka',
#   'Lat': 56.26,
#   'Lng': 51.28,
#   'Max Temp': 67.96,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Current Description': 'moderate rain',
#   'Country': 'RU',
#   'Rain (inches)': 2.03,
#   'Snow (inches)': '0.0'},
#  {'City': 'Caramay',
#   'Lat': 10.18,
#   'Lng': 119.24,
#   'Max Temp': 81.52,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72,
#   'Current Description': 'light rain',
#   'Country': 'PH',
#   'Rain (inches)': 0.76,
#   'Snow (inches)': '0.0'},
#  {'City': 'Bilibino',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 26.46,
#   'Humidity': 91,
#   'Cloudiness': 7,
#   'Wind Speed': 5.03,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kamensk-Shakhtinskiy',
#   'Lat': 48.32,
#   'Lng': 40.26,
#   'Max Temp': 82.24,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Iquique',
#   'Lat': -20.22,
#   'Lng': -70.14,
#   'Max Temp': 59,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Quintin',
#   'Lat': 30.48,
#   'Lng': -115.95,
#   'Max Temp': 61.38,
#   'Humidity': 91,
#   'Cloudiness': 11,
#   'Wind Speed': 6.42,
#   'Current Description': 'few clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tarsus',
#   'Lat': 36.92,
#   'Lng': 34.88,
#   'Max Temp': 95,
#   'Humidity': 43,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Current Description': 'few clouds',
#   'Country': 'TR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 73,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'mist',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gweru',
#   'Lat': -19.45,
#   'Lng': 29.82,
#   'Max Temp': 72.68,
#   'Humidity': 27,
#   'Cloudiness': 5,
#   'Wind Speed': 4.74,
#   'Current Description': 'clear sky',
#   'Country': 'ZW',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Zhezkazgan',
#   'Lat': 47.8,
#   'Lng': 67.71,
#   'Max Temp': 64.4,
#   'Humidity': 31,
#   'Cloudiness': 90,
#   'Wind Speed': 17.9,
#   'Current Description': 'overcast clouds',
#   'Country': 'KZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pampierstad',
#   'Lat': -27.78,
#   'Lng': 24.69,
#   'Max Temp': 65.23,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 4.85,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gerede',
#   'Lat': 40.8,
#   'Lng': 32.2,
#   'Max Temp': 70.05,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 7.25,
#   'Current Description': 'clear sky',
#   'Country': 'TR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cabedelo',
#   'Lat': -6.98,
#   'Lng': -34.83,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nalhati',
#   'Lat': 24.3,
#   'Lng': 87.82,
#   'Max Temp': 88.36,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 14.76,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Polur',
#   'Lat': 12.5,
#   'Lng': 79.13,
#   'Max Temp': 93.24,
#   'Humidity': 48,
#   'Cloudiness': 81,
#   'Wind Speed': 2.19,
#   'Current Description': 'broken clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mnogovershinnyy',
#   'Lat': 53.94,
#   'Lng': 139.92,
#   'Max Temp': 40.75,
#   'Humidity': 100,
#   'Cloudiness': 98,
#   'Wind Speed': 2.17,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ponyri',
#   'Lat': 52.32,
#   'Lng': 36.3,
#   'Max Temp': 80.6,
#   'Humidity': 44,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nieuwpoort',
#   'Lat': 51.12,
#   'Lng': 2.77,
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 20.8,
#   'Current Description': 'overcast clouds',
#   'Country': 'BE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Jieshi',
#   'Lat': 22.81,
#   'Lng': 115.83,
#   'Max Temp': 83.5,
#   'Humidity': 84,
#   'Cloudiness': 87,
#   'Wind Speed': 7.36,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tateyama',
#   'Lat': 34.98,
#   'Lng': 139.87,
#   'Max Temp': 79,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Abu Kamal',
#   'Lat': 34.45,
#   'Lng': 40.92,
#   'Max Temp': 105.94,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 14,
#   'Current Description': 'clear sky',
#   'Country': 'SY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 76.64,
#   'Humidity': 37,
#   'Cloudiness': 95,
#   'Wind Speed': 7.45,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Strezhevoy',
#   'Lat': 60.73,
#   'Lng': 77.59,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 4.47,
#   'Current Description': 'light intensity shower rain',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 69.8,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 15.66,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tiarei',
#   'Lat': -17.53,
#   'Lng': -149.33,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Peace River',
#   'Lat': 56.25,
#   'Lng': -117.29,
#   'Max Temp': 51.01,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'shower rain',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lazaro Cardenas',
#   'Lat': 17.96,
#   'Lng': -102.2,
#   'Max Temp': 77.74,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Current Description': 'overcast clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aasiaat',
#   'Lat': 68.71,
#   'Lng': -52.87,
#   'Max Temp': 39.34,
#   'Humidity': 89,
#   'Cloudiness': 10,
#   'Wind Speed': 6.38,
#   'Current Description': 'clear sky',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chifeng',
#   'Lat': 42.27,
#   'Lng': 118.96,
#   'Max Temp': 71.08,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Current Description': 'clear sky',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 77,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 18.34,
#   'Current Description': 'broken clouds',
#   'Country': 'ES',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Trairi',
#   'Lat': -3.28,
#   'Lng': -39.27,
#   'Max Temp': 82.26,
#   'Humidity': 71,
#   'Cloudiness': 48,
#   'Wind Speed': 8.77,
#   'Current Description': 'scattered clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.28,
#   'Max Temp': 76.08,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 8.28,
#   'Current Description': 'clear sky',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cranbourne',
#   'Lat': -38.1,
#   'Lng': 145.28,
#   'Max Temp': 44.01,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tadine',
#   'Lat': -21.55,
#   'Lng': 167.88,
#   'Max Temp': 67.95,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 11.03,
#   'Current Description': 'clear sky',
#   'Country': 'NC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 6.8,
#   'Current Description': 'broken clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Toul',
#   'Lat': 48.67,
#   'Lng': 5.92,
#   'Max Temp': 80.6,
#   'Humidity': 61,
#   'Cloudiness': 44,
#   'Wind Speed': 14.99,
#   'Current Description': 'scattered clouds',
#   'Country': 'FR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gobabis',
#   'Lat': -22.45,
#   'Lng': 18.97,
#   'Max Temp': 75.2,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gold Coast',
#   'Lat': -28,
#   'Lng': 153.43,
#   'Max Temp': 61,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Varzea Da Palma',
#   'Lat': -17.6,
#   'Lng': -44.73,
#   'Max Temp': 75.13,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 4.68,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kentau',
#   'Lat': 43.52,
#   'Lng': 68.51,
#   'Max Temp': 72.05,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 18.01,
#   'Current Description': 'clear sky',
#   'Country': 'KZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bosanska Gradiska',
#   'Lat': 45.14,
#   'Lng': 17.25,
#   'Max Temp': 89.6,
#   'Humidity': 38,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds',
#   'Country': 'BA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Busselton -33.65  115.33     59.00        80          15       19.10
# 1           Dingle  11.00  122.67     79.14        84         100        4.63
# 2      East London -33.02   27.91     73.40        28           0        5.82
# 3       Blackwater -23.58  148.88     57.87        73          46        7.85
# 4          Mataura -46.19  168.86     39.00        83          99        3.00
# 5          Kavieng  -2.57  150.80     81.14        84         100       14.03
# 6        Esperance -33.87  121.90     57.20        58           0        8.05
# 7      New Norfolk -42.78  147.06     39.99        91          32        2.37
# 8  Bambous Virieux -20.34   57.76     75.99        83          75       12.75
# 9            Vaini -21.20 -175.20     73.40        88          20        5.82
#
#   Current Description Country Rain (inches) Snow (inches)
# 0          few clouds      AU           0.0           0.0
# 1       moderate rain      PH          1.12           0.0
# 2           clear sky      ZA           0.0           0.0
# 3    scattered clouds      AU           0.0           0.0
# 4     overcast clouds      NZ           0.0           0.0
# 5          light rain      PG          0.23           0.0
# 6           clear sky      AU           0.0           0.0
# 7    scattered clouds      AU           0.0           0.0
# 8         shower rain      MU           0.0           0.0
# 9          few clouds      TO           0.0           0.0

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain (inches)", "Snow (inches)"]

# Assign district summary df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Busselton      AU -33.65  115.33     59.00        80          15
# 1       Dingle      PH  11.00  122.67     79.14        84         100
# 2  East London      ZA -33.02   27.91     73.40        28           0
# 3   Blackwater      AU -23.58  148.88     57.87        73          46
# 4      Mataura      NZ -46.19  168.86     39.00        83          99
#
#    Wind Speed Current Description Rain (inches) Snow (inches)
# 0       19.10          few clouds           0.0           0.0
# 1        4.63       moderate rain          1.12           0.0
# 2        5.82           clear sky           0.0           0.0
# 3        7.85    scattered clouds           0.0           0.0
# 4        3.00     overcast clouds           0.0           0.0

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
