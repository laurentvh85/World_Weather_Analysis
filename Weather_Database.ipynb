# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key
from config import g_key

# %%
#create a random list of coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#variable list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
cities
# Out:
# ['busselton',
#  'saint-francois',
#  'ushuaia',
#  'mataura',
#  'rikitea',
#  'dikson',
#  'sao filipe',
#  'atocha',
#  'punta arenas',
#  'illoqqortoormiut',
#  'hecun',
#  'bredasdorp',
#  'barentsburg',
#  'khani',
#  'karakol',
#  'mys shmidta',
#  'ponta do sol',
#  'new norfolk',
#  'pangnirtung',
#  'longyearbyen',
#  'fortuna',
#  'humaita',
#  'atuona',
#  'cidreira',
#  'turukhansk',
#  'lompoc',
#  'henties bay',
#  'port blair',
#  'puttur',
#  'satitoa',
#  'port hardy',
#  'gat',
#  'butaritari',
#  'hermanus',
#  'honiara',
#  'eau claire',
#  'bluff',
#  'yellowknife',
#  'umzimvubu',
#  'vaini',
#  'jamestown',
#  'puerto ayora',
#  'hobart',
#  'camacha',
#  'avarua',
#  'san cristobal',
#  'qaanaaq',
#  'galveston',
#  'chuy',
#  'rawannawi',
#  'bilibino',
#  'te anau',
#  'torbay',
#  'kaputa',
#  'hilo',
#  'ruatoria',
#  'comodoro rivadavia',
#  'port alfred',
#  'albany',
#  'kruisfontein',
#  'plastun',
#  'vila franca do campo',
#  'saint george',
#  'kaitangata',
#  'cape town',
#  'roebourne',
#  'chibombo',
#  'coxim',
#  'iqaluit',
#  'taltal',
#  'dingle',
#  'portree',
#  'belushya guba',
#  'rokytnice nad jizerou',
#  'kodiak',
#  'isangel',
#  'constitucion',
#  'bolungarvik',
#  'severo-kurilsk',
#  'victoria',
#  'ust-nera',
#  'silopi',
#  'nanortalik',
#  'taolanaro',
#  'husavik',
#  'sakakah',
#  'antsohihy',
#  'lavrentiya',
#  'provideniya',
#  'lulea',
#  'eyl',
#  'bethel',
#  'miranda',
#  'tommot',
#  'szczytno',
#  'longlac',
#  'sirsilla',
#  'mahebourg',
#  'guhagar',
#  'nuuk',
#  'komsomolskiy',
#  'vardo',
#  'canutama',
#  'mar del plata',
#  'nikolskoye',
#  'upernavik',
#  'opuwo',
#  'saldanha',
#  'tongren',
#  'kenda',
#  'balimo',
#  'narsaq',
#  'odweyne',
#  'chokurdakh',
#  'ilulissat',
#  'asheville',
#  'kapaa',
#  'castro',
#  'hobyo',
#  'sorong',
#  'nizhneyansk',
#  'ambulu',
#  'skibbereen',
#  'vanimo',
#  'oktyabrskoye',
#  'paka',
#  'morant bay',
#  'salekhard',
#  'codrington',
#  'vao',
#  'nome',
#  'skalistyy',
#  'sitka',
#  'araguatins',
#  'tumannyy',
#  'cayenne',
#  'urumqi',
#  'coihaique',
#  'oranjemund',
#  'georgetown',
#  'cardston',
#  'lebu',
#  'mehamn',
#  'nador',
#  'xichang',
#  'alofi',
#  'mackenzie',
#  'port elizabeth',
#  'adrar',
#  'coffeyville',
#  'rimouski',
#  'tsihombe',
#  'sinnamary',
#  'souillac',
#  'amalapuram',
#  'barrow',
#  'ribeira grande',
#  'zyryanka',
#  'bonavista',
#  'hofn',
#  'geraldton',
#  'aromashevo',
#  'tuktoyaktuk',
#  'rocha',
#  'sao felix do xingu',
#  'kamenka',
#  'margate',
#  'upington',
#  'beroroha',
#  'kununurra',
#  'juneau',
#  'itarema',
#  'semey',
#  'arraial do cabo',
#  'airai',
#  'aranjuez',
#  'haines junction',
#  'hambantota',
#  'dwarahat',
#  'harper',
#  'yaan',
#  'vestmannaeyjar',
#  'katsuura',
#  'aloja',
#  'amderma',
#  'kieta',
#  'khatanga',
#  'tromso',
#  'balikpapan',
#  'tazovskiy',
#  'dangara',
#  'kenai',
#  'buncrana',
#  'vitim',
#  'galiwinku',
#  'badarpur',
#  'saint-philippe',
#  'shingu',
#  'kutum',
#  'doctor pedro p. pena',
#  'tiksi',
#  'sitio novo do tocantins',
#  'batagay-alyta',
#  'goderich',
#  'vostok',
#  'hasaki',
#  'sungaipenuh',
#  'rincon',
#  'guarapari',
#  'surgut',
#  'sovetskaya',
#  'mutsamudu',
#  'glubczyce',
#  'attawapiskat',
#  'mount gambier',
#  'esperance',
#  'kirkwood',
#  'diamantino',
#  'tabriz',
#  'samusu',
#  'murray bridge',
#  'hithadhoo',
#  'praia',
#  'east london',
#  'leningradskiy',
#  'tasiilaq',
#  'san juan',
#  'sorvag',
#  'saskylakh',
#  'cam ranh',
#  'thompson',
#  'srednekolymsk',
#  'inskoy',
#  'kalbay',
#  'dakar',
#  'conceicao da barra',
#  'garden city',
#  'ulaangom',
#  'amahai',
#  'arrecife',
#  'champerico',
#  'santa cruz',
#  'buala',
#  'pemba',
#  'victor harbor',
#  'yulara',
#  'broome',
#  'inhambane',
#  'madang',
#  'astaneh-ye ashrafiyeh',
#  'omsukchan',
#  'lagoa',
#  'alta floresta',
#  'moree',
#  'viedma',
#  'vaitupu',
#  'norman wells',
#  'ust-omchug',
#  'faanui',
#  'palabuhanratu',
#  'byron bay',
#  'voskresenskoye',
#  'pevek',
#  'howell',
#  'cockburn town',
#  'san rafael',
#  'paso de carrasco',
#  'selma',
#  'tangier',
#  'manjo',
#  'limoux',
#  'narasannapeta',
#  'lexington',
#  'artesia',
#  'san patricio',
#  'grindavik',
#  'boone',
#  'mercedes',
#  'kananga',
#  'poronaysk',
#  'bargal',
#  'caborca',
#  'andros town',
#  'north battleford',
#  'karoi',
#  'havoysund',
#  'karatsu',
#  'gabu',
#  'bintulu',
#  'mrirt',
#  'poykovskiy',
#  'yiyang',
#  'tabiauea',
#  'kibala',
#  'nguiu',
#  'belaya gora',
#  'labuhan',
#  'lazaro cardenas',
#  'mingshui',
#  'dicabisagan',
#  'fort nelson',
#  'sawtell',
#  'mayskiy',
#  'pietrosani',
#  'pringsewu',
#  'hamilton',
#  'fairlie',
#  'temyasovo',
#  'lafiagi',
#  'tirano',
#  'borgarnes',
#  'taunggyi',
#  'biak',
#  'yumen',
#  'quatre cocos',
#  'kaukauna',
#  'carnarvon',
#  'severnyy-kospashskiy',
#  'toumodi',
#  'los llanos de aridane',
#  'farah',
#  'necochea',
#  'saint-pierre',
#  'nadudvar',
#  'broken hill',
#  'manokwari',
#  'rolim de moura',
#  'tilichiki',
#  'tomatlan',
#  'saleaula',
#  'ahuimanu',
#  'sabinopolis',
#  'fez',
#  'parras',
#  'dolbeau',
#  'brigantine',
#  'tura',
#  'pangoa',
#  'sunnyside',
#  'cabo san lucas',
#  'samarai',
#  'great yarmouth',
#  'cherskiy',
#  'samalaeulu',
#  'nantucket',
#  'kavieng',
#  'toora-khem',
#  'goose creek',
#  'xinqing',
#  'hirapur',
#  'tocache',
#  'jizan',
#  'namibe',
#  'le port',
#  'clonakilty',
#  'waipawa',
#  'terra rica',
#  'nouadhibou',
#  'tuatapere',
#  'barra do garcas',
#  'burica',
#  'high prairie',
#  'chagda',
#  'general pico',
#  'santa adelia',
#  'campbell river',
#  'baihar',
#  'lorengau',
#  'maracacume',
#  'arman',
#  'takoradi',
#  'karaul',
#  'shetpe',
#  'mao',
#  'itaituba',
#  'nyrob',
#  'acari',
#  'aklavik',
#  'namestovo',
#  'halalo',
#  'north bend',
#  'tazmalt',
#  'portland',
#  'namatanai',
#  'kota belud',
#  'idil',
#  'titlagarh',
#  'polyarnyy',
#  'las palmas',
#  'ancud',
#  'soto la marina',
#  'atasu',
#  'caravelas',
#  'inongo',
#  'lewiston',
#  'berlevag',
#  'kachug',
#  'kaoma',
#  'kahului',
#  'luderitz',
#  'miedzyrzecz',
#  'maksi',
#  'teguise',
#  'miguelopolis',
#  'sentyabrskiy',
#  'antalaha',
#  'kourou',
#  'maine-soroa',
#  'nizhnyaya pavlovka',
#  'chute-aux-outardes',
#  'matagami',
#  'puerto baquerizo moreno',
#  'sabang',
#  'puerto carreno',
#  'bandarbeyla',
#  'salalah',
#  'luziania',
#  'kawalu',
#  'lolua',
#  'avera',
#  'beyla',
#  'lugo',
#  'wagga wagga',
#  'hami',
#  'maningrida',
#  'kathu',
#  'aykhal',
#  'san lawrenz',
#  'sao gabriel da cachoeira',
#  'naze',
#  'ozinki',
#  'palmer',
#  'orocue',
#  'charlestown',
#  'constantine',
#  'mama',
#  'mnogovershinnyy',
#  'deputatskiy',
#  'burriana',
#  'khandyga',
#  'macaboboni',
#  'lapithos',
#  'atar',
#  'dwarka',
#  'gashua',
#  'bengkulu',
#  'angouleme',
#  'fonte boa',
#  'kirakira',
#  'tubruq',
#  'yuxia',
#  'aksu',
#  'bereslavka',
#  'kaura namoda',
#  'king city',
#  'middelkerke',
#  'bilma',
#  'ust-kulom',
#  'eugene',
#  'mitu',
#  'urengoy',
#  'kerema',
#  'meyungs',
#  'hunza',
#  'hagere hiywet',
#  'saravan',
#  'okhotsk',
#  'monrovia',
#  'parati',
#  'arlit',
#  'kyshtovka',
#  'yadgir',
#  'ust-kamchatsk',
#  'finschhafen',
#  'sepuka',
#  'palana',
#  'khelyulya',
#  'huilong',
#  'vila velha',
#  'areia branca',
#  'coquimbo',
#  'haljala',
#  'mahadday weyne',
#  'manzil salim',
#  'chibuto',
#  'kurilsk',
#  'bayir',
#  'yeppoon',
#  'kushima',
#  'bambous virieux',
#  'batemans bay',
#  'pemberton',
#  'matara',
#  'porbandar',
#  'porto novo',
#  'whitehorse',
#  'carndonagh',
#  'port-cartier',
#  'bacolod',
#  'langfang',
#  'ranau',
#  'escanaba',
#  'matamoros',
#  'saiha',
#  'baruun-urt',
#  'ferrol',
#  'guerrero negro',
#  'kant',
#  'olafsvik',
#  'balabac',
#  'sinjar',
#  'mogwase',
#  'lakshmipur',
#  'maceio',
#  'carballo',
#  'ulladulla',
#  'viransehir',
#  'seoul',
#  'udachnyy',
#  'banda aceh',
#  'gornopravdinsk',
#  'sindor',
#  'vaitape',
#  'teguldet',
#  'rubiataba',
#  'wanning',
#  'ozernovskiy',
#  'kangaatsiaq',
#  'aflu',
#  'khonuu',
#  'shunyi',
#  'zhangjiakou',
#  'inirida',
#  'marsh harbour',
#  'westport',
#  'klaksvik',
#  'nioro',
#  'port macquarie',
#  'kempele',
#  'formosa',
#  'tual',
#  'soligalich',
#  'krasnoselkup',
#  'otjimbingwe',
#  'moranbah',
#  'bathsheba',
#  'sobolevo',
#  'suzu',
#  'zarubino',
#  'walvis bay',
#  'ketchikan',
#  'ahipara',
#  'prince rupert',
#  'tooele',
#  'soyo',
#  'santa isabel do rio negro',
#  'digri',
#  'biltine',
#  'kemin',
#  'ostroh',
#  'jenjarom',
#  'springbok',
#  'acarau',
#  'russell',
#  'manyana',
#  'eirunepe',
#  'south sioux city',
#  'valparaiso',
#  'berettyoujfalu',
#  'leh',
#  'jubayl',
#  'makakilo city',
#  'whitchurch-stouffville',
#  'aquiraz',
#  'hit',
#  'bogorodsk',
#  'mareeba',
#  'zhigansk',
#  'salo',
#  'ajdabiya',
#  'fairbanks',
#  'tiarei',
#  'port-de-paix',
#  'talnakh',
#  'chegdomyn',
#  'teya',
#  'eching',
#  'tsiroanomandidy',
#  'hualmay',
#  'bocana de paiwas',
#  'calahorra',
#  'rujewa',
#  'chernushka']

# %%
#URL for Weather API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
          
        try:
            city_rain = city_weather["rain"]["1h"]
            
        except KeyError:
            city_rain = "0.0"
        try:
            city_snow = city_weather["snow"]["1h"]
                       
        except KeyError:
            city_snow = "0.0"
        
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description,
                          "Country": city_country,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})
        

# If an error is experienced, skip the city.
    except:
        pass

# %%
city_weather = requests.get(city_url)

# %%
city_weather.json()
# Out:
# {'coord': {'lon': 56.08, 'lat': 56.51},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 50.63,
#   'feels_like': 44.4,
#   'temp_min': 50.63,
#   'temp_max': 50.63,
#   'pressure': 1012,
#   'humidity': 93,
#   'sea_level': 1012,
#   'grnd_level': 994},
#  'wind': {'speed': 10.58, 'deg': 231},
#  'rain': {'1h': 0.14},
#  'clouds': {'all': 39},
#  'dt': 1592950922,
#  'sys': {'country': 'RU', 'sunrise': 1592954749, 'sunset': 1593018621},
#  'timezone': 18000,
#  'id': 568608,
#  'name': 'Chernushka',
#  'cod': 200}

# %%
city_data
# Out:
# [{'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 52,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 12.82,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.42,
#   'Lng': 3.91,
#   'Max Temp': 69.8,
#   'Humidity': 60,
#   'Cloudiness': 41,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Country': 'FR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 33.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'shower rain',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 94,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 69.93,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 9.95,
#   'Current Description': 'overcast clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 38.07,
#   'Humidity': 79,
#   'Cloudiness': 17,
#   'Wind Speed': 11.92,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 79.57,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 16.04,
#   'Current Description': 'clear sky',
#   'Country': 'CV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Atocha',
#   'Lat': -20.93,
#   'Lng': -66.23,
#   'Max Temp': 41.38,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 10.96,
#   'Current Description': 'clear sky',
#   'Country': 'BO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 35.6,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hecun',
#   'Lat': 36.53,
#   'Lng': 114.11,
#   'Max Temp': 73.17,
#   'Humidity': 60,
#   'Cloudiness': 27,
#   'Wind Speed': 1.92,
#   'Current Description': 'scattered clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 46.4,
#   'Humidity': 100,
#   'Cloudiness': 14,
#   'Wind Speed': 3.47,
#   'Current Description': 'few clouds',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Khani',
#   'Lat': 41.96,
#   'Lng': 42.96,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky',
#   'Country': 'GE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Karakol',
#   'Lat': 42.49,
#   'Lng': 78.39,
#   'Max Temp': 52.23,
#   'Humidity': 60,
#   'Cloudiness': 96,
#   'Wind Speed': 1.74,
#   'Current Description': 'overcast clouds',
#   'Country': 'KG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 69.8,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Current Description': 'few clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 53.01,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.15,
#   'Lng': -65.71,
#   'Max Temp': 39.2,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Country': 'SJ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 73,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Humaita',
#   'Lat': -7.51,
#   'Lng': -63.02,
#   'Max Temp': 82.35,
#   'Humidity': 62,
#   'Cloudiness': 85,
#   'Wind Speed': 1.48,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 79.77,
#   'Humidity': 71,
#   'Cloudiness': 7,
#   'Wind Speed': 14.5,
#   'Current Description': 'clear sky',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 68.27,
#   'Humidity': 71,
#   'Cloudiness': 33,
#   'Wind Speed': 9.15,
#   'Current Description': 'scattered clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Turukhansk',
#   'Lat': 65.82,
#   'Lng': 87.98,
#   'Max Temp': 55.78,
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 6.02,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lompoc',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 72,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Current Description': 'broken clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Henties Bay',
#   'Lat': -22.12,
#   'Lng': 14.28,
#   'Max Temp': 66.99,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 82.35,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 7.47,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puttur',
#   'Lat': 12.77,
#   'Lng': 75.22,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Hardy',
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 59,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'mist',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.76,
#   'Max Temp': 75,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 3.06,
#   'Current Description': 'clear sky',
#   'Country': 'IL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 83.53,
#   'Humidity': 72,
#   'Cloudiness': 32,
#   'Wind Speed': 16.2,
#   'Current Description': 'scattered clouds',
#   'Country': 'KI',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 51.01,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 3.11,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Honiara',
#   'Lat': -9.43,
#   'Lng': 159.95,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Current Description': 'scattered clouds',
#   'Country': 'SB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Eau Claire',
#   'Lat': 44.81,
#   'Lng': -91.5,
#   'Max Temp': 72,
#   'Humidity': 56,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 96,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 73,
#   'Humidity': 42,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Current Description': 'scattered clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Country': 'TO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 71.01,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'light rain',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 72,
#   'Humidity': 86,
#   'Cloudiness': 85,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'EC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 53.01,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'drizzle',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Camacha',
#   'Lat': 33.08,
#   'Lng': -16.33,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Current Description': 'scattered clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds',
#   'Country': 'CK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Cristobal',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'shower rain',
#   'Country': 'VE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 38.14,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 2.26,
#   'Current Description': 'clear sky',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Galveston',
#   'Lat': 29.37,
#   'Lng': -94.97,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 18.34,
#   'Current Description': 'few clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 67.73,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 9.44,
#   'Current Description': 'overcast clouds',
#   'Country': 'UY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bilibino',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 54.37,
#   'Humidity': 42,
#   'Cloudiness': 81,
#   'Wind Speed': 3.38,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Te Anau',
#   'Lat': -45.42,
#   'Lng': 167.72,
#   'Max Temp': 42.93,
#   'Humidity': 87,
#   'Cloudiness': 39,
#   'Wind Speed': 0.83,
#   'Current Description': 'scattered clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 19.46,
#   'Current Description': 'scattered clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kaputa',
#   'Lat': -8.47,
#   'Lng': 29.66,
#   'Max Temp': 66.92,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky',
#   'Country': 'ZM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.87,
#   'Lng': -67.5,
#   'Max Temp': 44.6,
#   'Humidity': 65,
#   'Cloudiness': 6,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 57.99,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 7.02,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 88,
#   'Humidity': 53,
#   'Cloudiness': 27,
#   'Wind Speed': 1.99,
#   'Current Description': 'light rain',
#   'Country': 'US',
#   'Rain (inches)': 0.48,
#   'Snow (inches)': '0.0'},
#  {'City': 'Kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 53.65,
#   'Humidity': 49,
#   'Cloudiness': 3,
#   'Wind Speed': 4.59,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Plastun',
#   'Lat': 44.76,
#   'Lng': 136.29,
#   'Max Temp': 56.19,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.15,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.72,
#   'Lng': -25.43,
#   'Max Temp': 62.6,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Current Description': 'light intensity drizzle',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 105.8,
#   'Humidity': 9,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 48.99,
#   'Humidity': 80,
#   'Cloudiness': 93,
#   'Wind Speed': 2.89,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Roebourne',
#   'Lat': -20.78,
#   'Lng': 117.13,
#   'Max Temp': 67.5,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 6.02,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chibombo',
#   'Lat': -14.66,
#   'Lng': 28.07,
#   'Max Temp': 55.38,
#   'Humidity': 74,
#   'Cloudiness': 44,
#   'Wind Speed': 4.81,
#   'Current Description': 'scattered clouds',
#   'Country': 'ZM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Coxim',
#   'Lat': -18.51,
#   'Lng': -54.76,
#   'Max Temp': 74.66,
#   'Humidity': 39,
#   'Cloudiness': 59,
#   'Wind Speed': 5.91,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Taltal',
#   'Lat': -25.4,
#   'Lng': -70.48,
#   'Max Temp': 56.79,
#   'Humidity': 80,
#   'Cloudiness': 93,
#   'Wind Speed': 4.68,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 78.35,
#   'Humidity': 83,
#   'Cloudiness': 71,
#   'Wind Speed': 3.6,
#   'Current Description': 'broken clouds',
#   'Country': 'PH',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Portree',
#   'Lat': 57.41,
#   'Lng': -6.19,
#   'Max Temp': 57.99,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 18.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'GB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rokytnice Nad Jizerou',
#   'Lat': 50.73,
#   'Lng': 15.43,
#   'Max Temp': 55.99,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 4.74,
#   'Current Description': 'clear sky',
#   'Country': 'CZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 7.85,
#   'Current Description': 'broken clouds',
#   'Country': 'VU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Constitucion',
#   'Lat': -35.33,
#   'Lng': -72.42,
#   'Max Temp': 49.6,
#   'Humidity': 82,
#   'Cloudiness': 97,
#   'Wind Speed': 7.94,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 48.27,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 9.48,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Victoria',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 84,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'HK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ust-Nera',
#   'Lat': 64.57,
#   'Lng': 143.2,
#   'Max Temp': 74.12,
#   'Humidity': 41,
#   'Cloudiness': 5,
#   'Wind Speed': 1.05,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Silopi',
#   'Lat': 37.25,
#   'Lng': 42.47,
#   'Max Temp': 77,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'TR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 42.08,
#   'Humidity': 76,
#   'Cloudiness': 43,
#   'Wind Speed': 6.06,
#   'Current Description': 'scattered clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Husavik',
#   'Lat': 66.04,
#   'Lng': -17.34,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'light rain',
#   'Country': 'IS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sakakah',
#   'Lat': 29.97,
#   'Lng': 40.21,
#   'Max Temp': 82.4,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Country': 'SA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Antsohihy',
#   'Lat': -14.88,
#   'Lng': 47.99,
#   'Max Temp': 71.64,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky',
#   'Country': 'MG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 40.44,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 13.42,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lulea',
#   'Lat': 65.58,
#   'Lng': 22.15,
#   'Max Temp': 60.8,
#   'Humidity': 93,
#   'Cloudiness': 47,
#   'Wind Speed': 1.12,
#   'Current Description': 'scattered clouds',
#   'Country': 'SE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Eyl',
#   'Lat': 7.98,
#   'Lng': 49.82,
#   'Max Temp': 81.14,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 22.1,
#   'Current Description': 'clear sky',
#   'Country': 'SO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 82,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Miranda',
#   'Lat': 3.25,
#   'Lng': -76.23,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'CO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tommot',
#   'Lat': 58.96,
#   'Lng': 126.29,
#   'Max Temp': 64.31,
#   'Humidity': 61,
#   'Cloudiness': 12,
#   'Wind Speed': 1.52,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Szczytno',
#   'Lat': 53.56,
#   'Lng': 20.99,
#   'Max Temp': 58.24,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 7.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'PL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sirsilla',
#   'Lat': 18.38,
#   'Lng': 78.83,
#   'Max Temp': 77.63,
#   'Humidity': 84,
#   'Cloudiness': 44,
#   'Wind Speed': 1.7,
#   'Current Description': 'scattered clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Guhagar',
#   'Lat': 17.48,
#   'Lng': 73.19,
#   'Max Temp': 79.5,
#   'Humidity': 85,
#   'Cloudiness': 77,
#   'Wind Speed': 8.32,
#   'Current Description': 'broken clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nuuk',
#   'Lat': 64.18,
#   'Lng': -51.72,
#   'Max Temp': 41.67,
#   'Humidity': 68,
#   'Cloudiness': 30,
#   'Wind Speed': 10.69,
#   'Current Description': 'scattered clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 78.8,
#   'Humidity': 29,
#   'Cloudiness': 58,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds',
#   'Country': 'UZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Canutama',
#   'Lat': -6.53,
#   'Lng': -64.38,
#   'Max Temp': 81.7,
#   'Humidity': 65,
#   'Cloudiness': 43,
#   'Wind Speed': 1.66,
#   'Current Description': 'scattered clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 54,
#   'Humidity': 93,
#   'Cloudiness': 50,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 34.99,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 10.69,
#   'Current Description': 'clear sky',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Opuwo',
#   'Lat': -18.06,
#   'Lng': 13.84,
#   'Max Temp': 56.66,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 8.23,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 5.35,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tongren',
#   'Lat': 27.72,
#   'Lng': 109.19,
#   'Max Temp': 72.12,
#   'Humidity': 91,
#   'Cloudiness': 87,
#   'Wind Speed': 0.6,
#   'Current Description': 'light rain',
#   'Country': 'CN',
#   'Rain (inches)': 0.75,
#   'Snow (inches)': '0.0'},
#  {'City': 'Kenda',
#   'Lat': 23.2,
#   'Lng': 86.53,
#   'Max Temp': 80.62,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 7.72,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 57.2,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Description': 'broken clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Odweyne',
#   'Lat': 9.41,
#   'Lng': 45.06,
#   'Max Temp': 77.74,
#   'Humidity': 54,
#   'Cloudiness': 86,
#   'Wind Speed': 13.91,
#   'Current Description': 'overcast clouds',
#   'Country': 'SO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 71.4,
#   'Humidity': 26,
#   'Cloudiness': 55,
#   'Wind Speed': 8.41,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ilulissat',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 41,
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Asheville',
#   'Lat': 35.6,
#   'Lng': -82.55,
#   'Max Temp': 77,
#   'Humidity': 77,
#   'Cloudiness': 93,
#   'Wind Speed': 1.01,
#   'Current Description': 'light rain',
#   'Country': 'US',
#   'Rain (inches)': 0.69,
#   'Snow (inches)': '0.0'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 57.52,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 3.83,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hobyo',
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 78.53,
#   'Humidity': 80,
#   'Cloudiness': 7,
#   'Wind Speed': 25.9,
#   'Current Description': 'clear sky',
#   'Country': 'SO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sorong',
#   'Lat': -0.88,
#   'Lng': 131.25,
#   'Max Temp': 78.13,
#   'Humidity': 88,
#   'Cloudiness': 94,
#   'Wind Speed': 8.81,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ambulu',
#   'Lat': -8.35,
#   'Lng': 113.61,
#   'Max Temp': 72.95,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Skibbereen',
#   'Lat': 51.55,
#   'Lng': -9.27,
#   'Max Temp': 55.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Description': 'light intensity drizzle',
#   'Country': 'IE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vanimo',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 79.68,
#   'Humidity': 84,
#   'Cloudiness': 68,
#   'Wind Speed': 4.9,
#   'Current Description': 'light rain',
#   'Country': 'PG',
#   'Rain (inches)': 0.22,
#   'Snow (inches)': '0.0'},
#  {'City': 'Oktyabrskoye',
#   'Lat': 43.06,
#   'Lng': 44.74,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Paka',
#   'Lat': 4.64,
#   'Lng': 103.44,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 2.24,
#   'Current Description': 'light rain',
#   'Country': 'MY',
#   'Rain (inches)': 0.18,
#   'Snow (inches)': '0.0'},
#  {'City': 'Morant Bay',
#   'Lat': 17.88,
#   'Lng': -76.41,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 21.92,
#   'Current Description': 'few clouds',
#   'Country': 'JM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Salekhard',
#   'Lat': 66.53,
#   'Lng': 66.6,
#   'Max Temp': 46.06,
#   'Humidity': 74,
#   'Cloudiness': 74,
#   'Wind Speed': 1.5,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Codrington',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 48.33,
#   'Humidity': 96,
#   'Cloudiness': 19,
#   'Wind Speed': 6.55,
#   'Current Description': 'few clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 72.27,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 10.54,
#   'Current Description': 'clear sky',
#   'Country': 'NC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nome',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 51.8,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 57.2,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cayenne',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Current Description': 'light rain',
#   'Country': 'GF',
#   'Rain (inches)': 0.46,
#   'Snow (inches)': '0.0'},
#  {'City': 'Urumqi',
#   'Lat': 43.8,
#   'Lng': 87.6,
#   'Max Temp': 69.8,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Coihaique',
#   'Lat': -45.58,
#   'Lng': -72.07,
#   'Max Temp': 33.8,
#   'Humidity': 95,
#   'Cloudiness': 42,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.43,
#   'Max Temp': 57.43,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 2.08,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds',
#   'Country': 'MY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cardston',
#   'Lat': 49.2,
#   'Lng': -113.3,
#   'Max Temp': 82.4,
#   'Humidity': 37,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 47.98,
#   'Humidity': 73,
#   'Cloudiness': 51,
#   'Wind Speed': 8.28,
#   'Current Description': 'broken clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mehamn',
#   'Lat': 71.04,
#   'Lng': 27.85,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nador',
#   'Lat': 35.17,
#   'Lng': -2.93,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 65,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Country': 'MA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Xichang',
#   'Lat': 27.9,
#   'Lng': 102.26,
#   'Max Temp': 65.98,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Current Description': 'heavy intensity rain',
#   'Country': 'CN',
#   'Rain (inches)': 4.09,
#   'Snow (inches)': '0.0'},
#  {'City': 'Alofi',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Country': 'NU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mackenzie',
#   'Lat': 55.3,
#   'Lng': -123.17,
#   'Max Temp': 64.4,
#   'Humidity': 45,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Current Description': 'few clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Adrar',
#   'Lat': 20.5,
#   'Lng': -10.07,
#   'Max Temp': 101.48,
#   'Humidity': 12,
#   'Cloudiness': 48,
#   'Wind Speed': 6.42,
#   'Current Description': 'scattered clouds',
#   'Country': 'MR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Coffeyville',
#   'Lat': 37.04,
#   'Lng': -95.62,
#   'Max Temp': 84.2,
#   'Humidity': 28,
#   'Cloudiness': 1,
#   'Wind Speed': 17.22,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rimouski',
#   'Lat': 48.45,
#   'Lng': -68.52,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sinnamary',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 77.4,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Current Description': 'light rain',
#   'Country': 'GF',
#   'Rain (inches)': 0.74,
#   'Snow (inches)': '0.0'},
#  {'City': 'Souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Amalapuram',
#   'Lat': 16.58,
#   'Lng': 82.02,
#   'Max Temp': 82.42,
#   'Humidity': 80,
#   'Cloudiness': 6,
#   'Wind Speed': 3.06,
#   'Current Description': 'clear sky',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 35.6,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 61.32,
#   'Humidity': 71,
#   'Cloudiness': 9,
#   'Wind Speed': 17.67,
#   'Current Description': 'clear sky',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Zyryanka',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': 75.33,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 4.34,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bonavista',
#   'Lat': 48.65,
#   'Lng': -53.11,
#   'Max Temp': 63.91,
#   'Humidity': 83,
#   'Cloudiness': 66,
#   'Wind Speed': 17.34,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 50.22,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 17.83,
#   'Current Description': 'moderate rain',
#   'Country': 'IS',
#   'Rain (inches)': 1.98,
#   'Snow (inches)': '0.0'},
#  {'City': 'Geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 57.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aromashevo',
#   'Lat': 56.86,
#   'Lng': 68.64,
#   'Max Temp': 50.34,
#   'Humidity': 78,
#   'Cloudiness': 44,
#   'Wind Speed': 5.46,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rocha',
#   'Lat': -34.48,
#   'Lng': -54.33,
#   'Max Temp': 66.29,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 4.34,
#   'Current Description': 'moderate rain',
#   'Country': 'UY',
#   'Rain (inches)': 1.59,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.64,
#   'Lng': -51.99,
#   'Max Temp': 75.7,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 2.89,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kamenka',
#   'Lat': 51.32,
#   'Lng': 42.77,
#   'Max Temp': 64,
#   'Humidity': 61,
#   'Cloudiness': 58,
#   'Wind Speed': 8.63,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.16,
#   'Snow (inches)': '0.0'},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 64,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68,
#   'Current Description': 'overcast clouds',
#   'Country': 'GB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Upington',
#   'Lat': -28.45,
#   'Lng': 21.26,
#   'Max Temp': 51.8,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Beroroha',
#   'Lat': -21.67,
#   'Lng': 45.17,
#   'Max Temp': 69.89,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 3.58,
#   'Current Description': 'few clouds',
#   'Country': 'MG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kununurra',
#   'Lat': -15.77,
#   'Lng': 128.73,
#   'Max Temp': 53.6,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Juneau',
#   'Lat': 58.3,
#   'Lng': -134.42,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain',
#   'Country': 'US',
#   'Rain (inches)': 0.25,
#   'Snow (inches)': '0.0'},
#  {'City': 'Itarema',
#   'Lat': -2.92,
#   'Lng': -39.92,
#   'Max Temp': 76.98,
#   'Humidity': 71,
#   'Cloudiness': 64,
#   'Wind Speed': 14.12,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.22,
#   'Snow (inches)': '0.0'},
#  {'City': 'Semey',
#   'Lat': 50.41,
#   'Lng': 80.23,
#   'Max Temp': 65.95,
#   'Humidity': 56,
#   'Cloudiness': 92,
#   'Wind Speed': 6.53,
#   'Current Description': 'overcast clouds',
#   'Country': 'KZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 71.6,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 56.03,
#   'Humidity': 100,
#   'Cloudiness': 47,
#   'Wind Speed': 3.71,
#   'Current Description': 'scattered clouds',
#   'Country': 'TL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aranjuez',
#   'Lat': 40.03,
#   'Lng': -3.6,
#   'Max Temp': 84.99,
#   'Humidity': 28,
#   'Cloudiness': 5,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'ES',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Haines Junction',
#   'Lat': 60.75,
#   'Lng': -137.51,
#   'Max Temp': 56.32,
#   'Humidity': 42,
#   'Cloudiness': 75,
#   'Wind Speed': 10.67,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hambantota',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds',
#   'Country': 'LK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dwarahat',
#   'Lat': 29.78,
#   'Lng': 79.43,
#   'Max Temp': 66.99,
#   'Humidity': 90,
#   'Cloudiness': 29,
#   'Wind Speed': 1.07,
#   'Current Description': 'light rain',
#   'Country': 'IN',
#   'Rain (inches)': 0.4,
#   'Snow (inches)': '0.0'},
#  {'City': 'Harper',
#   'Lat': 4.38,
#   'Lng': -7.72,
#   'Max Temp': 77.07,
#   'Humidity': 80,
#   'Cloudiness': 83,
#   'Wind Speed': 8.81,
#   'Current Description': 'broken clouds',
#   'Country': 'LR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Yaan',
#   'Lat': 7.38,
#   'Lng': 8.57,
#   'Max Temp': 77.04,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 4.03,
#   'Current Description': 'overcast clouds',
#   'Country': 'NG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 50.02,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 22.97,
#   'Current Description': 'light rain',
#   'Country': 'IS',
#   'Rain (inches)': 0.66,
#   'Snow (inches)': '0.0'},
#  {'City': 'Katsuura',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 73,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'mist',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aloja',
#   'Lat': 57.77,
#   'Lng': 24.88,
#   'Max Temp': 61,
#   'Humidity': 79,
#   'Cloudiness': 8,
#   'Wind Speed': 4.16,
#   'Current Description': 'clear sky',
#   'Country': 'LV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kieta',
#   'Lat': -6.22,
#   'Lng': 155.63,
#   'Max Temp': 82.94,
#   'Humidity': 71,
#   'Cloudiness': 33,
#   'Wind Speed': 6.02,
#   'Current Description': 'scattered clouds',
#   'Country': 'PG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 68.94,
#   'Humidity': 55,
#   'Cloudiness': 33,
#   'Wind Speed': 7.99,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.21,
#   'Snow (inches)': '0.0'},
#  {'City': 'Tromso',
#   'Lat': 69.65,
#   'Lng': 18.96,
#   'Max Temp': 53.6,
#   'Humidity': 81,
#   'Cloudiness': 69,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Balikpapan',
#   'Lat': -1.27,
#   'Lng': 116.83,
#   'Max Temp': 76.71,
#   'Humidity': 88,
#   'Cloudiness': 87,
#   'Wind Speed': 8.7,
#   'Current Description': 'light rain',
#   'Country': 'ID',
#   'Rain (inches)': 0.32,
#   'Snow (inches)': '0.0'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.47,
#   'Lng': 78.7,
#   'Max Temp': 45.45,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 8.23,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.22,
#   'Snow (inches)': '0.0'},
#  {'City': 'Dangara',
#   'Lat': 29.68,
#   'Lng': 75.89,
#   'Max Temp': 91.67,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kenai',
#   'Lat': 60.55,
#   'Lng': -151.26,
#   'Max Temp': 55.99,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Current Description': 'shower rain',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Buncrana',
#   'Lat': 55.13,
#   'Lng': -7.45,
#   'Max Temp': 56.14,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.45,
#   'Current Description': 'moderate rain',
#   'Country': 'IE',
#   'Rain (inches)': 1.52,
#   'Snow (inches)': '0.0'},
#  {'City': 'Vitim',
#   'Lat': 59.45,
#   'Lng': 112.56,
#   'Max Temp': 58.32,
#   'Humidity': 79,
#   'Cloudiness': 68,
#   'Wind Speed': 1.03,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Badarpur',
#   'Lat': 24.9,
#   'Lng': 92.6,
#   'Max Temp': 77.79,
#   'Humidity': 92,
#   'Cloudiness': 74,
#   'Wind Speed': 1.05,
#   'Current Description': 'light rain',
#   'Country': 'IN',
#   'Rain (inches)': 0.43,
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds',
#   'Country': 'RE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Shingu',
#   'Lat': 33.73,
#   'Lng': 135.98,
#   'Max Temp': 71.94,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 3.6,
#   'Current Description': 'broken clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.67,
#   'Max Temp': 77.63,
#   'Humidity': 17,
#   'Cloudiness': 45,
#   'Wind Speed': 5.12,
#   'Current Description': 'scattered clouds',
#   'Country': 'SD',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 56.89,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 6.06,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sitio Novo Do Tocantins',
#   'Lat': -5.52,
#   'Lng': -47.46,
#   'Max Temp': 76.93,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 0.98,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8,
#   'Lng': 130.41,
#   'Max Temp': 74.86,
#   'Humidity': 40,
#   'Cloudiness': 6,
#   'Wind Speed': 4.34,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Goderich',
#   'Lat': 43.75,
#   'Lng': -81.72,
#   'Max Temp': 73.99,
#   'Humidity': 83,
#   'Cloudiness': 62,
#   'Wind Speed': 17.6,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vostok',
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 53.24,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Current Description': 'moderate rain',
#   'Country': 'RU',
#   'Rain (inches)': 1.26,
#   'Snow (inches)': '0.0'},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sungaipenuh',
#   'Lat': -2.08,
#   'Lng': 101.38,
#   'Max Temp': 64.27,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 1.5,
#   'Current Description': 'light rain',
#   'Country': 'ID',
#   'Rain (inches)': 0.34,
#   'Snow (inches)': '0.0'},
#  {'City': 'Rincon',
#   'Lat': 32.3,
#   'Lng': -81.24,
#   'Max Temp': 87.8,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Guarapari',
#   'Lat': -20.67,
#   'Lng': -40.5,
#   'Max Temp': 70,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Surgut',
#   'Lat': 61.25,
#   'Lng': 73.42,
#   'Max Temp': 46.4,
#   'Humidity': 100,
#   'Cloudiness': 26,
#   'Wind Speed': 5.48,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sovetskaya',
#   'Lat': 44.78,
#   'Lng': 41.17,
#   'Max Temp': 69.01,
#   'Humidity': 5,
#   'Cloudiness': 0,
#   'Wind Speed': 8.01,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.11,
#   'Snow (inches)': '0.0'},
#  {'City': 'Glubczyce',
#   'Lat': 50.2,
#   'Lng': 17.83,
#   'Max Temp': 57.99,
#   'Humidity': 82,
#   'Cloudiness': 69,
#   'Wind Speed': 7.67,
#   'Current Description': 'broken clouds',
#   'Country': 'PL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 50,
#   'Humidity': 87,
# ...
#   'Current Description': 'overcast clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Teguldet',
#   'Lat': 57.31,
#   'Lng': 88.17,
#   'Max Temp': 56.46,
#   'Humidity': 91,
#   'Cloudiness': 22,
#   'Wind Speed': 4.09,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rubiataba',
#   'Lat': -15.16,
#   'Lng': -49.8,
#   'Max Temp': 68.74,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 1.97,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Wanning',
#   'Lat': 18.8,
#   'Lng': 110.4,
#   'Max Temp': 81.66,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.83,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ozernovskiy',
#   'Lat': 51.5,
#   'Lng': 156.52,
#   'Max Temp': 46.02,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.54,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kangaatsiaq',
#   'Lat': 68.31,
#   'Lng': -53.46,
#   'Max Temp': 39.29,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.19,
#   'Current Description': 'overcast clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Shunyi',
#   'Lat': 40.12,
#   'Lng': 116.65,
#   'Max Temp': 75,
#   'Humidity': 82,
#   'Cloudiness': 92,
#   'Wind Speed': 4.47,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Zhangjiakou',
#   'Lat': 40.81,
#   'Lng': 114.88,
#   'Max Temp': 66.6,
#   'Humidity': 69,
#   'Cloudiness': 8,
#   'Wind Speed': 4.85,
#   'Current Description': 'clear sky',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Inirida',
#   'Lat': 3.87,
#   'Lng': -67.92,
#   'Max Temp': 79.57,
#   'Humidity': 91,
#   'Cloudiness': 93,
#   'Wind Speed': 2.46,
#   'Current Description': 'light rain',
#   'Country': 'CO',
#   'Rain (inches)': 0.77,
#   'Snow (inches)': '0.0'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 83.32,
#   'Humidity': 77,
#   'Cloudiness': 46,
#   'Wind Speed': 6.96,
#   'Current Description': 'scattered clouds',
#   'Country': 'BS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Westport',
#   'Lat': 41.14,
#   'Lng': -73.36,
#   'Max Temp': 82.4,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 66,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Country': 'FO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 85.53,
#   'Humidity': 65,
#   'Cloudiness': 61,
#   'Wind Speed': 10.71,
#   'Current Description': 'light rain',
#   'Country': 'GM',
#   'Rain (inches)': 0.19,
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.43,
#   'Lng': 152.92,
#   'Max Temp': 51.01,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 6.55,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kempele',
#   'Lat': 64.91,
#   'Lng': 25.5,
#   'Max Temp': 60.8,
#   'Humidity': 63,
#   'Cloudiness': 42,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Country': 'FI',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Formosa',
#   'Lat': -26.18,
#   'Lng': -58.18,
#   'Max Temp': 84.2,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tual',
#   'Lat': -5.67,
#   'Lng': 132.75,
#   'Max Temp': 80.26,
#   'Humidity': 81,
#   'Cloudiness': 62,
#   'Wind Speed': 21.63,
#   'Current Description': 'broken clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Soligalich',
#   'Lat': 59.08,
#   'Lng': 42.29,
#   'Max Temp': 50.38,
#   'Humidity': 93,
#   'Cloudiness': 15,
#   'Wind Speed': 4.63,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.47,
#   'Max Temp': 51.89,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 1.07,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Otjimbingwe',
#   'Lat': -22.35,
#   'Lng': 16.13,
#   'Max Temp': 56.43,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 7.11,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Moranbah',
#   'Lat': -22,
#   'Lng': 148.05,
#   'Max Temp': 54.45,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Current Description': 'haze',
#   'Country': 'BB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sobolevo',
#   'Lat': 54.43,
#   'Lng': 31.9,
#   'Max Temp': 57.61,
#   'Humidity': 90,
#   'Cloudiness': 49,
#   'Wind Speed': 4.36,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Zarubino',
#   'Lat': 42.63,
#   'Lng': 131.09,
#   'Max Temp': 57.85,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.37,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.96,
#   'Lng': 14.51,
#   'Max Temp': 66.99,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ketchikan',
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Description': 'broken clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ahipara',
#   'Lat': -35.17,
#   'Lng': 173.17,
#   'Max Temp': 60.71,
#   'Humidity': 84,
#   'Cloudiness': 91,
#   'Wind Speed': 13.49,
#   'Current Description': 'light rain',
#   'Country': 'NZ',
#   'Rain (inches)': 0.49,
#   'Snow (inches)': '0.0'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.32,
#   'Lng': -130.32,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tooele',
#   'Lat': 40.53,
#   'Lng': -112.3,
#   'Max Temp': 86,
#   'Humidity': 20,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Soyo',
#   'Lat': -6.13,
#   'Lng': 12.37,
#   'Max Temp': 72.45,
#   'Humidity': 87,
#   'Cloudiness': 93,
#   'Wind Speed': 6.96,
#   'Current Description': 'overcast clouds',
#   'Country': 'AO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Lat': -0.41,
#   'Lng': -65.02,
#   'Max Temp': 77.67,
#   'Humidity': 85,
#   'Cloudiness': 98,
#   'Wind Speed': 0.43,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Digri',
#   'Lat': 25.16,
#   'Lng': 69.11,
#   'Max Temp': 89.42,
#   'Humidity': 65,
#   'Cloudiness': 17,
#   'Wind Speed': 15.57,
#   'Current Description': 'few clouds',
#   'Country': 'PK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Biltine',
#   'Lat': 14.53,
#   'Lng': 20.92,
#   'Max Temp': 84.87,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 6.4,
#   'Current Description': 'clear sky',
#   'Country': 'TD',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kemin',
#   'Lat': 42.78,
#   'Lng': 75.69,
#   'Max Temp': 62.53,
#   'Humidity': 44,
#   'Cloudiness': 44,
#   'Wind Speed': 5.35,
#   'Current Description': 'scattered clouds',
#   'Country': 'KG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ostroh',
#   'Lat': 50.33,
#   'Lng': 26.51,
#   'Max Temp': 63.5,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7.05,
#   'Current Description': 'light rain',
#   'Country': 'UA',
#   'Rain (inches)': 0.54,
#   'Snow (inches)': '0.0'},
#  {'City': 'Jenjarom',
#   'Lat': 2.88,
#   'Lng': 101.5,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Description': 'few clouds',
#   'Country': 'MY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Springbok',
#   'Lat': -29.66,
#   'Lng': 17.89,
#   'Max Temp': 56.32,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Acarau',
#   'Lat': -2.89,
#   'Lng': -40.12,
#   'Max Temp': 76.98,
#   'Humidity': 72,
#   'Cloudiness': 43,
#   'Wind Speed': 14.16,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.27,
#   'Snow (inches)': '0.0'},
#  {'City': 'Russell',
#   'Lat': 32.35,
#   'Lng': -85.2,
#   'Max Temp': 89.6,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Manyana',
#   'Lat': -23.4,
#   'Lng': 21.72,
#   'Max Temp': 49.06,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 7.09,
#   'Current Description': 'clear sky',
#   'Country': 'BW',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Eirunepe',
#   'Lat': -6.66,
#   'Lng': -69.87,
#   'Max Temp': 78.04,
#   'Humidity': 89,
#   'Cloudiness': 77,
#   'Wind Speed': 1.86,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.26,
#   'Snow (inches)': '0.0'},
#  {'City': 'South Sioux City',
#   'Lat': 42.47,
#   'Lng': -96.41,
#   'Max Temp': 78.8,
#   'Humidity': 39,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Current Description': 'scattered clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Valparaiso',
#   'Lat': -33.04,
#   'Lng': -71.63,
#   'Max Temp': 55.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 10.04,
#   'Current Description': 'heavy intensity rain',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Berettyoujfalu',
#   'Lat': 47.22,
#   'Lng': 21.55,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Current Description': 'drizzle',
#   'Country': 'HU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Leh',
#   'Lat': 34.17,
#   'Lng': 77.58,
#   'Max Temp': 57.49,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 5.88,
#   'Current Description': 'clear sky',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Makakilo City',
#   'Lat': 21.35,
#   'Lng': -158.09,
#   'Max Temp': 84.2,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aquiraz',
#   'Lat': -3.9,
#   'Lng': -38.39,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hit',
#   'Lat': 33.64,
#   'Lng': 42.83,
#   'Max Temp': 86.65,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Current Description': 'clear sky',
#   'Country': 'IQ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bogorodsk',
#   'Lat': 56.1,
#   'Lng': 43.52,
#   'Max Temp': 61,
#   'Humidity': 82,
#   'Cloudiness': 80,
#   'Wind Speed': 4.47,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mareeba',
#   'Lat': -17,
#   'Lng': 145.43,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': 69.17,
#   'Humidity': 41,
#   'Cloudiness': 4,
#   'Wind Speed': 2.08,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Salo',
#   'Lat': 45.61,
#   'Lng': 10.53,
#   'Max Temp': 78.01,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 1.12,
#   'Current Description': 'few clouds',
#   'Country': 'IT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ajdabiya',
#   'Lat': 30.76,
#   'Lng': 20.23,
#   'Max Temp': 68.52,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 10.04,
#   'Current Description': 'clear sky',
#   'Country': 'LY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.12,
#   'Current Description': 'light rain',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tiarei',
#   'Lat': -17.53,
#   'Lng': -149.33,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 53.6,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chegdomyn',
#   'Lat': 51.12,
#   'Lng': 133.02,
#   'Max Temp': 56.84,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Teya',
#   'Lat': 60.38,
#   'Lng': 92.63,
#   'Max Temp': 60.58,
#   'Humidity': 71,
#   'Cloudiness': 92,
#   'Wind Speed': 2.37,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Eching',
#   'Lat': 48.3,
#   'Lng': 11.62,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Current Description': 'clear sky',
#   'Country': 'DE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tsiroanomandidy',
#   'Lat': -18.77,
#   'Lng': 46.03,
#   'Max Temp': 66.34,
#   'Humidity': 78,
#   'Cloudiness': 39,
#   'Wind Speed': 1.68,
#   'Current Description': 'scattered clouds',
#   'Country': 'MG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hualmay',
#   'Lat': -11.1,
#   'Lng': -77.61,
#   'Max Temp': 65.08,
#   'Humidity': 75,
#   'Cloudiness': 72,
#   'Wind Speed': 10.96,
#   'Current Description': 'broken clouds',
#   'Country': 'PE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bocana De Paiwas',
#   'Lat': 12.79,
#   'Lng': -85.12,
#   'Max Temp': 79.63,
#   'Humidity': 86,
#   'Cloudiness': 98,
#   'Wind Speed': 12.37,
#   'Current Description': 'light rain',
#   'Country': 'NI',
#   'Rain (inches)': 0.54,
#   'Snow (inches)': '0.0'},
#  {'City': 'Calahorra',
#   'Lat': 42.31,
#   'Lng': -1.97,
#   'Max Temp': 78.8,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'light rain',
#   'Country': 'ES',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rujewa',
#   'Lat': -8.7,
#   'Lng': 34.38,
#   'Max Temp': 65.52,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 10.13,
#   'Current Description': 'clear sky',
#   'Country': 'TZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chernushka',
#   'Lat': 56.51,
#   'Lng': 56.08,
#   'Max Temp': 50.63,
#   'Humidity': 93,
#   'Cloudiness': 39,
#   'Wind Speed': 10.58,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.14,
#   'Snow (inches)': '0.0'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Busselton -33.65  115.33     52.00        71          40       12.82
# 1  Saint-Francois  46.42    3.91     69.80        60          41        3.36
# 2         Ushuaia -54.80  -68.30     33.80        94          75       12.75
# 3         Mataura -46.19  168.86     39.00        83          94        3.00
# 4         Rikitea -23.12 -134.97     69.93        54         100        9.95
# 5          Dikson  73.51   80.55     38.07        79          17       11.92
# 6      Sao Filipe  14.90  -24.50     79.57        64           0       16.04
# 7          Atocha -20.93  -66.23     41.38        48           0       10.96
# 8    Punta Arenas -53.15  -70.92     35.60        64           0       13.87
# 9           Hecun  36.53  114.11     73.17        60          27        1.92
#
#   Current Description Country Rain (inches) Snow (inches)
# 0    scattered clouds      AU           0.0           0.0
# 1    scattered clouds      FR           0.0           0.0
# 2         shower rain      AR           0.0           0.0
# 3     overcast clouds      NZ           0.0           0.0
# 4     overcast clouds      PF           0.0           0.0
# 5          few clouds      RU           0.0           0.0
# 6           clear sky      CV           0.0           0.0
# 7           clear sky      BO           0.0           0.0
# 8           clear sky      CL           0.0           0.0
# 9    scattered clouds      CN           0.0           0.0

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain (inches)", "Snow (inches)"]

# Assign district summary df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Busselton      AU -33.65  115.33     52.00        71          40
# 1      Saint-Francois      FR  46.42    3.91     69.80        60          41
# 2             Ushuaia      AR -54.80  -68.30     33.80        94          75
# 3             Mataura      NZ -46.19  168.86     39.00        83          94
# 4             Rikitea      PF -23.12 -134.97     69.93        54         100
# ..                ...     ...    ...     ...       ...       ...         ...
# 534           Hualmay      PE -11.10  -77.61     65.08        75          72
# 535  Bocana De Paiwas      NI  12.79  -85.12     79.63        86          98
# 536         Calahorra      ES  42.31   -1.97     78.80        60           0
# 537            Rujewa      TZ  -8.70   34.38     65.52        63           0
# 538        Chernushka      RU  56.51   56.08     50.63        93          39
#
#      Wind Speed Current Description Rain (inches) Snow (inches)
# 0         12.82    scattered clouds           0.0           0.0
# 1          3.36    scattered clouds           0.0           0.0
# 2         12.75         shower rain           0.0           0.0
# 3          3.00     overcast clouds           0.0           0.0
# 4          9.95     overcast clouds           0.0           0.0
# ..          ...                 ...           ...           ...
# 534       10.96       broken clouds           0.0           0.0
# 535       12.37          light rain          0.54           0.0
# 536        5.82          light rain           0.0           0.0
# 537       10.13           clear sky           0.0           0.0
# 538       10.58          light rain          0.14           0.0
#
# [539 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
