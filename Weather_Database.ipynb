# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key
from config import g_key

# %%
#create a random list of coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#coordinates list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add to the cities list.
    if city not in cities:
        cities.append(city)

# %%
cities
# Out:
# ['rikitea',
#  'rocha',
#  'vegachi',
#  'busselton',
#  'port-gentil',
#  'amderma',
#  'leningradskiy',
#  'cape town',
#  'mataura',
#  'avera',
#  'hilo',
#  'atuona',
#  'castro',
#  'ushuaia',
#  'nizhneyansk',
#  'ribeira grande',
#  'plettenberg bay',
#  'kapaa',
#  'punta arenas',
#  'barrow',
#  'carnarvon',
#  'east london',
#  'pisco',
#  'bredasdorp',
#  'bengkulu',
#  'cherskiy',
#  'tuktoyaktuk',
#  'hofn',
#  'klaksvik',
#  'flinders',
#  'dingle',
#  'fortuna',
#  'bandarbeyla',
#  'dikson',
#  'margate',
#  'bargal',
#  'albany',
#  'svetlyy',
#  'thompson',
#  'lasa',
#  'bata',
#  'shimoda',
#  'bethel',
#  'panama city',
#  'conceicao do araguaia',
#  'male',
#  'jamestown',
#  'yellowknife',
#  'esperance',
#  'kaitangata',
#  'muroto',
#  'asyut',
#  'la ronge',
#  'sitka',
#  'henties bay',
#  'arraial do cabo',
#  'dali',
#  'new norfolk',
#  'celestun',
#  'kushmurun',
#  'georgetown',
#  'nouadhibou',
#  'hermanus',
#  'mar del plata',
#  'bowen',
#  'burica',
#  'taolanaro',
#  'bitkine',
#  'puerto ayora',
#  'vaini',
#  'yulara',
#  'goedereede',
#  'port elizabeth',
#  'qaanaaq',
#  'souillac',
#  'roma',
#  'cockburn town',
#  'bluff',
#  'khatanga',
#  'hobart',
#  'galveston',
#  'dicabisagan',
#  'uvinza',
#  'grindavik',
#  'saldanha',
#  'elizabeth city',
#  'bathsheba',
#  'barentsburg',
#  'abha',
#  'muros',
#  'pasni',
#  'natal',
#  'arvi',
#  'acapulco',
#  'puerto escondido',
#  'panguipulli',
#  'haines junction',
#  'port alfred',
#  'saint-pierre',
#  'fort nelson',
#  'colares',
#  'kachiry',
#  'mount gambier',
#  'ponta do sol',
#  'touros',
#  'san benito',
#  'shubarshi',
#  'ixtapa',
#  'belushya guba',
#  'martyush',
#  'hopeman',
#  'upington',
#  'rudnogorsk',
#  'la palma',
#  'tabialan',
#  'puerto rico',
#  'kenora',
#  'plastun',
#  'talkha',
#  'pacific grove',
#  'chaozhou',
#  'miri',
#  'babanusah',
#  'port hardy',
#  'illoqqortoormiut',
#  'chuy',
#  'barbar',
#  'corlu',
#  'wajima',
#  'hithadhoo',
#  'arman',
#  'bara',
#  'moquegua',
#  'harper',
#  'sao joao do piaui',
#  'beeville',
#  'podosinovets',
#  'mahebourg',
#  'corn island',
#  'tura',
#  'vallenar',
#  'hamilton',
#  'tevaitoa',
#  'marsh harbour',
#  'grand gaube',
#  'luanda',
#  'glendive',
#  'sakakah',
#  'hvide sande',
#  'yerofey pavlovich',
#  'minab',
#  'thomasville',
#  'katherine',
#  'tsihombe',
#  'maraa',
#  'faanui',
#  'raudeberg',
#  'airai',
#  'narsaq',
#  'norman wells',
#  'san patricio',
#  'banda aceh',
#  'meiringen',
#  'halalo',
#  'buenos aires',
#  'aron',
#  'tateyama',
#  'palmer',
#  'mys shmidta',
#  'vardo',
#  'ilheus',
#  'naze',
#  'erenhot',
#  'codrington',
#  'ostersund',
#  'nalut',
#  'puyang',
#  'kirakira',
#  'alamosa',
#  'butaritari',
#  'kahului',
#  'namatanai',
#  'mayo',
#  'bambanglipuro',
#  'abengourou',
#  'chokurdakh',
#  'upernavik',
#  'solsvik',
#  'caravelas',
#  'srandakan',
#  'kudahuvadhoo',
#  'sabalgarh',
#  'phrai bung',
#  'pevek',
#  'iranshahr',
#  'voh',
#  'konyshevka',
#  'grand river south east',
#  'vaitupu',
#  'kodiak',
#  'hami',
#  'severo-kurilsk',
#  'stabat',
#  'salalah',
#  'saint-augustin',
#  'sentyabrskiy',
#  'bambous virieux',
#  'lagoa',
#  'madang',
#  'akdepe',
#  'buchanan',
#  'ozernovskiy',
#  'russkaya polyana',
#  'tasiilaq',
#  'jaciara',
#  'kavaratti',
#  'forestville',
#  'longyearbyen',
#  'samusu',
#  'podgorenskiy',
#  'port blair',
#  'birao',
#  'maningrida',
#  'chapais',
#  'kedrovyy',
#  'tiksi',
#  'ilulissat',
#  'pontes e lacerda',
#  'lichuan',
#  'biloela',
#  'pokosnoye',
#  'faya',
#  'te anau',
#  'fare',
#  'mafinga',
#  'gat',
#  'alofi',
#  'sergeyevka',
#  'petropavlovsk-kamchatskiy',
#  'kamenskoye',
#  'ferrandina',
#  'pokhara',
#  'amazar',
#  'egvekinot',
#  'det udom',
#  'soubre',
#  'camacha',
#  'talisay',
#  'nicoya',
#  'avarua',
#  'aripuana',
#  'katsuura',
#  'kijang',
#  'abnub',
#  'vigrestad',
#  'moron',
#  'port-cartier',
#  'solnechnyy',
#  'nome',
#  'sabzevar',
#  'zhezkazgan',
#  'santiago',
#  'tezu',
#  'dovbysh',
#  'talara',
#  'provideniya',
#  'mayumba',
#  'peitou',
#  'alice springs',
#  'dhidhdhoo',
#  'hualmay',
#  'san cristobal',
#  'saint george',
#  'ravar',
#  'baghdad',
#  'lompoc',
#  'tortosa',
#  'mundra',
#  'marrakesh',
#  'lebu',
#  'saint-philippe',
#  'tuatapere',
#  'cabo san lucas',
#  'bulgan',
#  'deputatskiy',
#  'moindou',
#  'jacqueville',
#  'mbeya',
#  'kindersley',
#  'port maria',
#  'urumqi',
#  'valparaiso',
#  'oliver',
#  'kem',
#  'druzhba',
#  'rawah',
#  'pozo colorado',
#  'clyde river',
#  'montes claros',
#  'aklera',
#  'lieksa',
#  'port lincoln',
#  'porto velho',
#  'puteyets',
#  'tabou',
#  'tonantins',
#  'alcudia',
#  'darhan',
#  'komsomolskiy',
#  'marly',
#  'yalutorovsk',
#  'lata',
#  'vila franca do campo',
#  'kaeo',
#  'honiara',
#  'beringovskiy',
#  'acari',
#  'sinnamary',
#  'konevo',
#  'kavieng',
#  'ancud',
#  'daitari',
#  'aflu',
#  'port moresby',
#  'angoche',
#  'kapiri mposhi',
#  'aykhal',
#  'cianorte',
#  'hendijan',
#  'fairmont',
#  'luderitz',
#  'kelme',
#  'vila',
#  'mega',
#  'torbay',
#  'bombay',
#  'veere',
#  'jais',
#  'mbanza-ngungu',
#  'yumen',
#  'maymanak',
#  'daru',
#  'ketchikan',
#  'katobu',
#  'cheuskiny',
#  'tessalit',
#  'bereda',
#  'martigues',
#  'gurgan',
#  'cidreira',
#  'mount isa',
#  'muisne',
#  'tautira',
#  'palabuhanratu',
#  'denau',
#  'gorin',
#  'agirish',
#  'olafsvik',
#  'damaturu',
#  'nikolskoye',
#  'ust-omchug',
#  'talnakh',
#  'tornio',
#  'belmonte',
#  'lorengau',
#  'scottsbluff',
#  'melenki',
#  'linjiang',
#  'llaillay',
#  'nhulunbuy',
#  'elbistan',
#  'port hedland',
#  'tigil',
#  'shymkent',
#  'caucaia',
#  'barra',
#  'saint-francois',
#  'farah',
#  'dukat',
#  'kruisfontein',
#  'bilibino',
#  'hansi',
#  'paraiba do sul',
#  'nanortalik',
#  'tres arroyos',
#  'ahipara',
#  'victoria',
#  'marawi',
#  'saskylakh',
#  'sabha',
#  'marsaxlokk',
#  'atar',
#  'labutta',
#  'berbera',
#  'middelburg',
#  'phan thiet',
#  'attawapiskat',
#  'lower hutt',
#  'dingzhou',
#  'coruche',
#  'jardim',
#  'suntar',
#  'marzuq',
#  'sept-iles',
#  'bolungarvik',
#  'jinchengjiang',
#  'bose',
#  'dolores',
#  'nizwa',
#  'skagastrond',
#  'guerrero negro',
#  'amalner',
#  'coihaique',
#  'trelew',
#  'ust-nera',
#  'pedernales',
#  'hokitika',
#  'bartica',
#  'roblin',
#  'los llanos de aridane',
#  'hope mills',
#  'dawlatabad',
#  'broome',
#  'cajamarca',
#  'nassau',
#  'shingu',
#  'kawalu',
#  'saint augustine',
#  'sao felix do xingu',
#  'humberto de campos',
#  'qui nhon',
#  'nago',
#  'dzierzoniow',
#  'corpus christi',
#  'geraldton',
#  'baherden',
#  'laguna',
#  'puerto madero',
#  'neuquen',
#  'buraydah',
#  'misratah',
#  'kannangad',
#  'dajal',
#  'fort saint john',
#  'esna',
#  'djibo',
#  'kaa-khem',
#  'nikko',
#  'kuche',
#  'puerto colombia',
#  'przhevalskoye',
#  'glazov',
#  'dokka',
#  'yingshang',
#  'riviere-au-renard',
#  'vanimo',
#  'sao filipe',
#  'siocon',
#  'berlevag',
#  'san jose',
#  'ayan',
#  'louisbourg',
#  'westport',
#  'soyo',
#  'shache',
#  'brae',
#  'at-bashi',
#  'zyryanka',
#  'porbandar',
#  'along',
#  'ust-kamchatsk',
#  'kochetok',
#  'teguise',
#  'yuma',
#  'mahadday weyne',
#  'indiaroba',
#  'armidale',
#  'korla',
#  'morant bay',
#  'verkhoyansk',
#  'kitgum',
#  'trairi',
#  'tumannyy',
#  'maceio',
#  'brookhaven',
#  'adilcevaz',
#  'surubim',
#  'craig',
#  'kitakata',
#  'synya',
#  'vao',
#  'xicotencatl',
#  'bubaque',
#  'zhangye',
#  'maldonado',
#  'los algarrobos',
#  'pinar del rio',
#  'havelock',
#  'hambantota',
#  'sulurpeta',
#  'davila',
#  'mitsamiouli',
#  'locri',
#  'kandrian',
#  'tahta',
#  'lypova dolyna',
#  'kardymovo',
#  'aksu',
#  'macamic',
#  'whitehorse',
#  'charters towers',
#  'gubkinskiy',
#  'stornoway',
#  'eureka',
#  'sorland',
#  'bolshaya sosnova',
#  'sisimiut',
#  'chulumani',
#  'tonj',
#  'brigantine',
#  'salumbar',
#  'gwadar',
#  'salvador',
#  'hasaki',
#  'fukuchiyama',
#  'baguanos',
#  'beira',
#  'alotau',
#  'arlit',
#  'xuddur',
#  'marcona',
#  'rehoboth',
#  'pringsewu',
#  'burglengenfeld',
#  'isabela',
#  'pangai',
#  'suhbaatar',
#  'japura',
#  'bismarck',
#  'bitung',
#  'erzurum',
#  'necochea',
#  'mareeba',
#  'puerto baquerizo moreno',
#  'ploemeur',
#  'prince rupert',
#  'lumby',
#  'wanning',
#  'taoudenni',
#  'lichinga',
#  'kuzino',
#  'karamea',
#  'ca mau',
#  'husavik',
#  'houma',
#  'abu samrah',
#  'mandiana',
#  'sonoita',
#  'sadao',
#  'rio gallegos',
#  'salinopolis',
#  'sampit',
#  'ambilobe',
#  'kansanshi',
#  'skala',
#  'fairbanks',
#  'omsukchan',
#  'epe',
#  'meridian',
#  'kisumu',
#  'balkanabat',
#  'karratha',
#  'padang',
#  'sibolga',
#  'trinidad',
#  'ulaangom',
#  'meulaboh',
#  'coquimbo',
#  'arauca',
#  'mongoumba',
#  'loreto',
#  'sinop',
#  'saint cyrus',
#  'ratnagiri',
#  'anchorage',
#  'billings',
#  'taltal',
#  'cabedelo',
#  'acarau',
#  'guaruja',
#  'ibotirama',
#  'kitimat',
#  'salinas',
#  'marystown',
#  'santa isabel do rio negro',
#  'miyako',
#  'richards bay',
#  'sozimskiy',
#  'stuttgart',
#  'pailon',
#  'poum',
#  'butembo',
#  'agadez',
#  'rudbar',
#  'kieta',
#  'jishou',
#  'hammerfest',
#  'gidole',
#  'zhigansk',
#  'nipawin',
#  'nuuk',
#  'saint-georges']

# %%
#URL for Weather API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    
# Loop through all the cities.
for i, city in enumerate(cities):
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
          
        try:
            city_rain = city_weather["rain"]["1h"]
            
        except KeyError:
            city_rain = "0.0"
        try:
            city_snow = city_weather["snow"]["1h"]
                       
        except KeyError:
            city_snow = "0.0"
        
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description,
                          "Country": city_country,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})
        

# If an error is experienced, skip the city.
    except:
        pass

# %%
city_weather = requests.get(city_url)

# %%
city_weather.json()
# Out:
# {'coord': {'lon': -61.75, 'lat': 12.06},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 86,
#   'feels_like': 84.42,
#   'temp_min': 86,
#   'temp_max': 86,
#   'pressure': 1012,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 23.04, 'deg': 70},
#  'clouds': {'all': 20},
#  'dt': 1593207431,
#  'sys': {'type': 1,
#   'id': 8781,
#   'country': 'GD',
#   'sunrise': 1593164699,
#   'sunset': 1593210884},
#  'timezone': -14400,
#  'id': 3579925,
#  'name': "St. George's",
#  'cod': 200}

# %%
city_data
# Out:
# [{'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.74,
#   'Humidity': 84,
#   'Cloudiness': 79,
#   'Wind Speed': 12.48,
#   'Current Description': 'broken clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rocha',
#   'Lat': -34.48,
#   'Lng': -54.33,
#   'Max Temp': 43,
#   'Humidity': 73,
#   'Cloudiness': 73,
#   'Wind Speed': 6.42,
#   'Current Description': 'broken clouds',
#   'Country': 'UY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vegachi',
#   'Lat': 6.76,
#   'Lng': -74.79,
#   'Max Temp': 73.89,
#   'Humidity': 96,
#   'Cloudiness': 72,
#   'Wind Speed': 1.59,
#   'Current Description': 'moderate rain',
#   'Country': 'CO',
#   'Rain (inches)': 2.95,
#   'Snow (inches)': '0.0'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 57,
#   'Humidity': 89,
#   'Cloudiness': 11,
#   'Wind Speed': 12.24,
#   'Current Description': 'few clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.72,
#   'Lng': 8.78,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds',
#   'Country': 'GA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 32.68,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 17.43,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 59,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 20.8,
#   'Current Description': 'broken clouds',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Avera',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 89.01,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 14.99,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 80.58,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 13.31,
#   'Current Description': 'clear sky',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 56.79,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Current Description': 'moderate rain',
#   'Country': 'BR',
#   'Rain (inches)': 1.34,
#   'Snow (inches)': '0.0'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 37.4,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 24.16,
#   'Current Description': 'few clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.05,
#   'Lng': 23.37,
#   'Max Temp': 54.07,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 6.6,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 84.2,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Current Description': 'few clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 41,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'mist',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 57.2,
#   'Humidity': 93,
#   'Cloudiness': 15,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 61.11,
#   'Humidity': 64,
#   'Cloudiness': 16,
#   'Wind Speed': 10.69,
#   'Current Description': 'few clouds',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 64.99,
#   'Humidity': 77,
#   'Cloudiness': 6,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'PE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 53.6,
#   'Humidity': 71,
#   'Cloudiness': 22,
#   'Wind Speed': 10.29,
#   'Current Description': 'few clouds',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 75.87,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 4.25,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 38.75,
#   'Humidity': 72,
#   'Cloudiness': 94,
#   'Wind Speed': 13.82,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'light rain',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 50.45,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 8.16,
#   'Current Description': 'overcast clouds',
#   'Country': 'IS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Current Description': 'mist',
#   'Country': 'FO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Flinders',
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 51.01,
#   'Humidity': 76,
#   'Cloudiness': 66,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 77.41,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 1.52,
#   'Current Description': 'overcast clouds',
#   'Country': 'PH',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 64.4,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Current Description': 'few clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.49,
#   'Lng': 50.81,
#   'Max Temp': 79.38,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 35.05,
#   'Current Description': 'overcast clouds',
#   'Country': 'SO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 35.91,
#   'Humidity': 88,
#   'Cloudiness': 14,
#   'Wind Speed': 25.52,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 66,
#   'Humidity': 79,
#   'Cloudiness': 33,
#   'Wind Speed': 4,
#   'Current Description': 'light rain',
#   'Country': 'GB',
#   'Rain (inches)': 0.4,
#   'Snow (inches)': '0.0'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 81,
#   'Humidity': 40,
#   'Cloudiness': 50,
#   'Wind Speed': 9.86,
#   'Current Description': 'scattered clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Svetlyy',
#   'Lat': 54.67,
#   'Lng': 20.13,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 48,
#   'Wind Speed': 4.47,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 75.2,
#   'Humidity': 41,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'shower rain',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lasa',
#   'Lat': 46.62,
#   'Lng': 10.7,
#   'Max Temp': 57.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'light rain',
#   'Country': 'IT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bata',
#   'Lat': 1.86,
#   'Lng': 9.77,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds',
#   'Country': 'GQ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Shimoda',
#   'Lat': 34.67,
#   'Lng': 138.95,
#   'Max Temp': 78.01,
#   'Humidity': 80,
#   'Cloudiness': 74,
#   'Wind Speed': 13.04,
#   'Current Description': 'broken clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 84,
#   'Humidity': 39,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Panama City',
#   'Lat': 8.99,
#   'Lng': -79.52,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Description': 'shower rain',
#   'Country': 'PA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Conceicao Do Araguaia',
#   'Lat': -8.26,
#   'Lng': -49.26,
#   'Max Temp': 89.6,
#   'Humidity': 46,
#   'Cloudiness': 72,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Male',
#   'Lat': 4.17,
#   'Lng': 73.51,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 21.92,
#   'Current Description': 'broken clouds',
#   'Country': 'MV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 78.01,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 66,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'light intensity shower rain',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 50,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 48,
#   'Humidity': 90,
#   'Cloudiness': 91,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Muroto',
#   'Lat': 33.28,
#   'Lng': 134.15,
#   'Max Temp': 76.46,
#   'Humidity': 87,
#   'Cloudiness': 85,
#   'Wind Speed': 6.82,
#   'Current Description': 'overcast clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Asyut',
#   'Lat': 27.18,
#   'Lng': 31.18,
#   'Max Temp': 80.65,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 15.86,
#   'Current Description': 'clear sky',
#   'Country': 'EG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'La Ronge',
#   'Lat': 55.1,
#   'Lng': -105.28,
#   'Max Temp': 73.4,
#   'Humidity': 40,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 53.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.19,
#   'Current Description': 'moderate rain',
#   'Country': 'US',
#   'Rain (inches)': 1.02,
#   'Snow (inches)': '0.0'},
#  {'City': 'Henties Bay',
#   'Lat': -22.12,
#   'Lng': 14.28,
#   'Max Temp': 55,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 13.76,
#   'Current Description': 'clear sky',
#   'Country': 'NA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 58,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dali',
#   'Lat': 25.7,
#   'Lng': 100.18,
#   'Max Temp': 62.89,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 4.94,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 39.99,
#   'Humidity': 90,
#   'Cloudiness': 47,
#   'Wind Speed': 3.09,
#   'Current Description': 'scattered clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Celestun',
#   'Lat': 20.87,
#   'Lng': -90.4,
#   'Max Temp': 89.01,
#   'Humidity': 63,
#   'Cloudiness': 21,
#   'Wind Speed': 17.38,
#   'Current Description': 'few clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kushmurun',
#   'Lat': 52.45,
#   'Lng': 64.63,
#   'Max Temp': 48.74,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 12.3,
#   'Current Description': 'clear sky',
#   'Country': 'KZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.59,
#   'Current Description': 'few clouds',
#   'Country': 'MY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.93,
#   'Lng': -17.03,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 18.34,
#   'Current Description': 'clear sky',
#   'Country': 'MR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 52,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 13,
#   'Current Description': 'few clouds',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 46,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bowen',
#   'Lat': -20.02,
#   'Lng': 148.23,
#   'Max Temp': 64.99,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.09,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bitkine',
#   'Lat': 11.98,
#   'Lng': 18.21,
#   'Max Temp': 84.54,
#   'Humidity': 50,
#   'Cloudiness': 29,
#   'Wind Speed': 4.81,
#   'Current Description': 'scattered clouds',
#   'Country': 'TD',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Current Description': 'scattered clouds',
#   'Country': 'EC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Country': 'TO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Yulara',
#   'Lat': -25.24,
#   'Lng': 130.99,
#   'Max Temp': 35.6,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Goedereede',
#   'Lat': 51.82,
#   'Lng': 3.98,
#   'Max Temp': 73,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 14.99,
#   'Current Description': 'overcast clouds',
#   'Country': 'NL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 53.6,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 35.73,
#   'Humidity': 85,
#   'Cloudiness': 9,
#   'Wind Speed': 1.41,
#   'Current Description': 'clear sky',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'shower rain',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Roma',
#   'Lat': 43.21,
#   'Lng': -75.46,
#   'Max Temp': 82.4,
#   'Humidity': 28,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.46,
#   'Lng': -71.14,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Current Description': 'scattered clouds',
#   'Country': 'TC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds',
#   'Country': 'NZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 61.65,
#   'Humidity': 58,
#   'Cloudiness': 79,
#   'Wind Speed': 9.91,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 41,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain',
#   'Country': 'AU',
#   'Rain (inches)': 0.25,
#   'Snow (inches)': '0.0'},
#  {'City': 'Galveston',
#   'Lat': 29.37,
#   'Lng': -94.97,
#   'Max Temp': 84.99,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Current Description': 'haze',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Dicabisagan',
#   'Lat': 17.08,
#   'Lng': 122.42,
#   'Max Temp': 79.41,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Current Description': 'light rain',
#   'Country': 'PH',
#   'Rain (inches)': 0.11,
#   'Snow (inches)': '0.0'},
#  {'City': 'Uvinza',
#   'Lat': -5.1,
#   'Lng': 30.39,
#   'Max Temp': 70.86,
#   'Humidity': 62,
#   'Cloudiness': 70,
#   'Wind Speed': 3.02,
#   'Current Description': 'broken clouds',
#   'Country': 'TZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Grindavik',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Max Temp': 51.8,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Country': 'IS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 55.4,
#   'Humidity': 76,
#   'Cloudiness': 71,
#   'Wind Speed': 9.17,
#   'Current Description': 'broken clouds',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Elizabeth City',
#   'Lat': 36.29,
#   'Lng': -76.25,
#   'Max Temp': 89.01,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Current Description': 'broken clouds',
#   'Country': 'BB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Abha',
#   'Lat': 18.22,
#   'Lng': 42.51,
#   'Max Temp': 78.8,
#   'Humidity': 22,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds',
#   'Country': 'SA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Muros',
#   'Lat': 42.78,
#   'Lng': -9.06,
#   'Max Temp': 62.01,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Current Description': 'light rain',
#   'Country': 'ES',
#   'Rain (inches)': 0.15,
#   'Snow (inches)': '0.0'},
#  {'City': 'Pasni',
#   'Lat': 25.26,
#   'Lng': 63.47,
#   'Max Temp': 84.38,
#   'Humidity': 86,
#   'Cloudiness': 56,
#   'Wind Speed': 8.59,
#   'Current Description': 'broken clouds',
#   'Country': 'PK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Natal',
#   'Lat': -5.79,
#   'Lng': -35.21,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Arvi',
#   'Lat': 20.98,
#   'Lng': 78.23,
#   'Max Temp': 82.04,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Current Description': 'moderate rain',
#   'Country': 'IN',
#   'Rain (inches)': 1.8,
#   'Snow (inches)': '0.0'},
#  {'City': 'Acapulco',
#   'Lat': 16.86,
#   'Lng': -99.89,
#   'Max Temp': 89.6,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Current Description': 'overcast clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Panguipulli',
#   'Lat': -39.63,
#   'Lng': -72.33,
#   'Max Temp': 46.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Haines Junction',
#   'Lat': 60.75,
#   'Lng': -137.51,
#   'Max Temp': 62.76,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 4.14,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 53.01,
#   'Humidity': 78,
#   'Cloudiness': 4,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.34,
#   'Lng': 55.48,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 49,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'RE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': 68,
#   'Humidity': 40,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Colares',
#   'Lat': 38.8,
#   'Lng': -9.45,
#   'Max Temp': 69.01,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kachiry',
#   'Lat': 53.07,
#   'Lng': 76.1,
#   'Max Temp': 63.46,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 10.11,
#   'Current Description': 'moderate rain',
#   'Country': 'KZ',
#   'Rain (inches)': 2.09,
#   'Snow (inches)': '0.0'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'overcast clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 69.8,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Touros',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Benito',
#   'Lat': 16.91,
#   'Lng': -89.91,
#   'Max Temp': 91.85,
#   'Humidity': 47,
#   'Cloudiness': 44,
#   'Wind Speed': 6.24,
#   'Current Description': 'scattered clouds',
#   'Country': 'GT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Shubarshi',
#   'Lat': 48.59,
#   'Lng': 57.19,
#   'Max Temp': 53.11,
#   'Humidity': 60,
#   'Cloudiness': 3,
#   'Wind Speed': 11.97,
#   'Current Description': 'clear sky',
#   'Country': 'KZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain',
#   'Country': 'MX',
#   'Rain (inches)': 0.51,
#   'Snow (inches)': '0.0'},
#  {'City': 'Martyush',
#   'Lat': 56.4,
#   'Lng': 61.88,
#   'Max Temp': 40.55,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 8.63,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hopeman',
#   'Lat': 57.71,
#   'Lng': -3.43,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds',
#   'Country': 'GB',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Upington',
#   'Lat': -28.45,
#   'Lng': 21.26,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rudnogorsk',
#   'Lat': 57.26,
#   'Lng': 103.75,
#   'Max Temp': 61.11,
#   'Humidity': 88,
#   'Cloudiness': 25,
#   'Wind Speed': 1.7,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'La Palma',
#   'Lat': 33.85,
#   'Lng': -118.05,
#   'Max Temp': 86,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puerto Rico',
#   'Lat': -26.8,
#   'Lng': -55.02,
#   'Max Temp': 49.87,
#   'Humidity': 74,
#   'Cloudiness': 60,
#   'Wind Speed': 4.83,
#   'Current Description': 'broken clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kenora',
#   'Lat': 49.82,
#   'Lng': -94.43,
#   'Max Temp': 77,
#   'Humidity': 47,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Plastun',
#   'Lat': 44.76,
#   'Lng': 136.29,
#   'Max Temp': 55.08,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.29,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.24,
#   'Snow (inches)': '0.0'},
#  {'City': 'Talkha',
#   'Lat': 31.05,
#   'Lng': 31.38,
#   'Max Temp': 68.16,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 4.68,
#   'Current Description': 'clear sky',
#   'Country': 'EG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.62,
#   'Lng': -121.92,
#   'Max Temp': 78.01,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chaozhou',
#   'Lat': 23.67,
#   'Lng': 116.64,
#   'Max Temp': 80.6,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 1.63,
#   'Current Description': 'few clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Miri',
#   'Lat': 4.41,
#   'Lng': 114.01,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds',
#   'Country': 'MY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Port Hardy',
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 45.82,
#   'Humidity': 73,
#   'Cloudiness': 34,
#   'Wind Speed': 6.08,
#   'Current Description': 'scattered clouds',
#   'Country': 'UY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Corlu',
#   'Lat': 41.16,
#   'Lng': 27.8,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky',
#   'Country': 'TR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Wajima',
#   'Lat': 37.4,
#   'Lng': 136.9,
#   'Max Temp': 72.09,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 18.3,
#   'Current Description': 'overcast clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 84.54,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 9.15,
#   'Current Description': 'overcast clouds',
#   'Country': 'MV',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.17,
#   'Max Temp': 58.35,
#   'Humidity': 65,
#   'Cloudiness': 4,
#   'Wind Speed': 7.31,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bara',
#   'Lat': 10.37,
#   'Lng': 10.73,
#   'Max Temp': 74.55,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 9.51,
#   'Current Description': 'light rain',
#   'Country': 'NG',
#   'Rain (inches)': 0.12,
#   'Snow (inches)': '0.0'},
#  {'City': 'Moquegua',
#   'Lat': -17.2,
#   'Lng': -70.94,
#   'Max Temp': 67.12,
#   'Humidity': 31,
#   'Cloudiness': 1,
#   'Wind Speed': 5.26,
#   'Current Description': 'clear sky',
#   'Country': 'PE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Harper',
#   'Lat': 4.38,
#   'Lng': -7.72,
#   'Max Temp': 75.61,
#   'Humidity': 84,
#   'Cloudiness': 70,
#   'Wind Speed': 12.82,
#   'Current Description': 'broken clouds',
#   'Country': 'LR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sao Joao Do Piaui',
#   'Lat': -8.36,
#   'Lng': -42.25,
#   'Max Temp': 78.48,
#   'Humidity': 45,
#   'Cloudiness': 3,
#   'Wind Speed': 5.91,
#   'Current Description': 'clear sky',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Beeville',
#   'Lat': 28.4,
#   'Lng': -97.75,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Podosinovets',
#   'Lat': 60.28,
#   'Lng': 47.07,
#   'Max Temp': 57.27,
#   'Humidity': 97,
#   'Cloudiness': 94,
#   'Wind Speed': 7.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'shower rain',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Corn Island',
#   'Lat': 12.17,
#   'Lng': -83.04,
#   'Max Temp': 82.53,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 19.39,
#   'Current Description': 'overcast clouds',
#   'Country': 'NI',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tura',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 73.26,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 9.19,
#   'Current Description': 'heavy intensity rain',
#   'Country': 'IN',
#   'Rain (inches)': 10.32,
#   'Snow (inches)': '0.0'},
#  {'City': 'Vallenar',
#   'Lat': -28.57,
#   'Lng': -70.76,
#   'Max Temp': 63.93,
#   'Humidity': 46,
#   'Cloudiness': 4,
#   'Wind Speed': 2.71,
#   'Current Description': 'clear sky',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hamilton',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 82,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tevaitoa',
#   'Lat': -16.78,
#   'Lng': -151.5,
#   'Max Temp': 78.6,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 11.1,
#   'Current Description': 'few clouds',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 83.28,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 9.71,
#   'Current Description': 'overcast clouds',
#   'Country': 'BS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.01,
#   'Lng': 57.66,
#   'Max Temp': 71.01,
#   'Humidity': 83,
#   'Cloudiness': 28,
#   'Wind Speed': 7,
#   'Current Description': 'light rain',
#   'Country': 'MU',
#   'Rain (inches)': 0.2,
#   'Snow (inches)': '0.0'},
#  {'City': 'Luanda',
#   'Lat': -8.84,
#   'Lng': 13.23,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'AO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Glendive',
#   'Lat': 47.11,
#   'Lng': -104.71,
#   'Max Temp': 87.8,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sakakah',
#   'Lat': 29.97,
#   'Lng': 40.21,
#   'Max Temp': 89.6,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'SA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hvide Sande',
#   'Lat': 56,
#   'Lng': 8.13,
#   'Max Temp': 68,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 12.5,
#   'Current Description': 'clear sky',
#   'Country': 'DK',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Yerofey Pavlovich',
#   'Lat': 53.97,
#   'Lng': 121.97,
#   'Max Temp': 59.09,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 2.91,
#   'Current Description': 'light rain',
#   'Country': 'RU',
#   'Rain (inches)': 0.11,
#   'Snow (inches)': '0.0'},
#  {'City': 'Minab',
#   'Lat': 27.15,
#   'Lng': 57.08,
#   'Max Temp': 89.6,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'haze',
#   'Country': 'IR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Thomasville',
#   'Lat': 35.88,
#   'Lng': -80.08,
#   'Max Temp': 89.01,
#   'Humidity': 44,
#   'Cloudiness': 35,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Katherine',
#   'Lat': -14.47,
#   'Lng': 132.27,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Maraa',
#   'Lat': -1.83,
#   'Lng': -65.37,
#   'Max Temp': 78.55,
#   'Humidity': 93,
#   'Cloudiness': 88,
#   'Wind Speed': 1.23,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.49,
#   'Snow (inches)': '0.0'},
#  {'City': 'Faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 78.39,
#   'Humidity': 71,
#   'Cloudiness': 10,
#   'Wind Speed': 11.32,
#   'Current Description': 'clear sky',
#   'Country': 'PF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Raudeberg',
#   'Lat': 61.99,
#   'Lng': 5.14,
#   'Max Temp': 70,
#   'Humidity': 69,
#   'Cloudiness': 17,
#   'Wind Speed': 5.79,
#   'Current Description': 'few clouds',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 54.09,
#   'Humidity': 89,
#   'Cloudiness': 71,
#   'Wind Speed': 3.91,
#   'Current Description': 'broken clouds',
#   'Country': 'TL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 53.6,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 68,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 20.8,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'San Patricio',
#   'Lat': 19.22,
#   'Lng': -104.7,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 79.03,
#   'Humidity': 78,
#   'Cloudiness': 96,
#   'Wind Speed': 5.28,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Meiringen',
#   'Lat': 46.73,
#   'Lng': 8.18,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 23,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds',
#   'Country': 'CH',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Buenos Aires',
#   'Lat': -34.61,
#   'Lng': -58.38,
#   'Max Temp': 55.4,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Aron',
#   'Lat': 24.38,
#   'Lng': 77.42,
#   'Max Temp': 78.6,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 6.71,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Tateyama',
#   'Lat': 34.98,
#   'Lng': 139.87,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.12,
#   'Current Description': 'mist',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Palmer',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 86,
#   'Humidity': 25,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 46.4,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Current Description': 'shower rain',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ilheus',
#   'Lat': -14.79,
#   'Lng': -39.05,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Naze',
#   'Lat': 28.37,
#   'Lng': 129.48,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Erenhot',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 66.79,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 7.52,
#   'Current Description': 'clear sky',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Codrington',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 41.05,
#   'Humidity': 80,
#   'Cloudiness': 77,
#   'Wind Speed': 7.07,
#   'Current Description': 'broken clouds',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ostersund',
#   'Lat': 63.18,
#   'Lng': 14.64,
#   'Max Temp': 73.4,
#   'Humidity': 49,
#   'Cloudiness': 6,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky',
#   'Country': 'SE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nalut',
#   'Lat': 30.33,
#   'Lng': 10.85,
#   'Max Temp': 83.89,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 13.87,
#   'Current Description': 'clear sky',
#   'Country': 'LY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Puyang',
#   'Lat': 29.46,
#   'Lng': 119.89,
#   'Max Temp': 75.74,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 2.84,
#   'Current Description': 'light rain',
#   'Country': 'CN',
#   'Rain (inches)': 0.41,
#   'Snow (inches)': '0.0'},
#  {'City': 'Kirakira',
#   'Lat': -10.45,
#   'Lng': 161.92,
#   'Max Temp': 82.96,
#   'Humidity': 76,
#   'Cloudiness': 50,
#   'Wind Speed': 9.4,
#   'Current Description': 'light rain',
#   'Country': 'SB',
#   'Rain (inches)': 0.27,
#   'Snow (inches)': '0.0'},
#  {'City': 'Alamosa',
#   'Lat': 37.47,
#   'Lng': -105.87,
#   'Max Temp': 86,
#   'Humidity': 7,
#   'Cloudiness': 1,
#   'Wind Speed': 14.99,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 83.97,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 11.9,
#   'Current Description': 'overcast clouds',
#   'Country': 'KI',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kahului',
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 84.2,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 18.34,
#   'Current Description': 'scattered clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Namatanai',
#   'Lat': -3.67,
#   'Lng': 152.43,
#   'Max Temp': 80.2,
#   'Humidity': 81,
#   'Cloudiness': 74,
#   'Wind Speed': 8.79,
#   'Current Description': 'moderate rain',
#   'Country': 'PG',
#   'Rain (inches)': 1.66,
#   'Snow (inches)': '0.0'},
#  {'City': 'Mayo',
#   'Lat': 38.89,
#   'Lng': -76.51,
#   'Max Temp': 87.8,
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.28,
#   'Max Temp': 72.16,
#   'Humidity': 92,
#   'Cloudiness': 5,
#   'Wind Speed': 3.49,
#   'Current Description': 'clear sky',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Abengourou',
#   'Lat': 6.73,
#   'Lng': -3.5,
#   'Max Temp': 73.72,
#   'Humidity': 96,
#   'Cloudiness': 95,
#   'Wind Speed': 5.14,
#   'Current Description': 'light rain',
#   'Country': 'CI',
#   'Rain (inches)': 0.12,
#   'Snow (inches)': '0.0'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 52.11,
#   'Humidity': 46,
#   'Cloudiness': 49,
#   'Wind Speed': 10.54,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 37.96,
#   'Humidity': 87,
#   'Cloudiness': 94,
#   'Wind Speed': 5.37,
#   'Current Description': 'overcast clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Caravelas',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 71.78,
#   'Humidity': 90,
#   'Cloudiness': 4,
#   'Wind Speed': 3.83,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.23,
#   'Snow (inches)': '0.0'},
#  {'City': 'Srandakan',
#   'Lat': -7.94,
#   'Lng': 110.25,
#   'Max Temp': 72.27,
#   'Humidity': 92,
#   'Cloudiness': 6,
#   'Wind Speed': 3.62,
#   'Current Description': 'clear sky',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kudahuvadhoo',
#   'Lat': 2.67,
#   'Lng': 72.89,
#   'Max Temp': 83.03,
#   'Humidity': 76,
#   'Cloudiness': 95,
#   'Wind Speed': 9.8,
#   'Current Description': 'light rain',
#   'Country': 'MV',
#   'Rain (inches)': 0.52,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sabalgarh',
#   'Lat': 26.25,
#   'Lng': 77.4,
#   'Max Temp': 86.86,
#   'Humidity': 61,
#   'Cloudiness': 93,
#   'Wind Speed': 12.35,
#   'Current Description': 'light rain',
#   'Country': 'IN',
#   'Rain (inches)': 0.94,
#   'Snow (inches)': '0.0'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 30.61,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 17.05,
#   'Current Description': 'light snow',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': 0.13},
#  {'City': 'Iranshahr',
#   'Lat': 27.2,
#   'Lng': 60.68,
#   'Max Temp': 96.8,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 1.34,
#   'Current Description': 'clear sky',
#   'Country': 'IR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Voh',
#   'Lat': -20.97,
#   'Lng': 164.7,
#   'Max Temp': 69.93,
#   'Humidity': 56,
#   'Cloudiness': 21,
#   'Wind Speed': 5.23,
#   'Current Description': 'few clouds',
#   'Country': 'NC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Konyshevka',
#   'Lat': 51.84,
#   'Lng': 35.29,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Current Description': 'clear sky',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 60.8,
#   'Humidity': 51,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 67.73,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 9.1,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 51.51,
#   'Humidity': 66,
#   'Cloudiness': 94,
#   'Wind Speed': 11.03,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Stabat',
#   'Lat': 3.76,
#   'Lng': 98.45,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 84.2,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds',
#   'Country': 'OM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 67.82,
#   'Humidity': 57,
#   'Cloudiness': 96,
#   'Wind Speed': 15.12,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'shower rain',
#   'Country': 'MU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 66.54,
#   'Humidity': 95,
#   'Cloudiness': 42,
#   'Wind Speed': 12.75,
#   'Current Description': 'scattered clouds',
#   'Country': 'PT',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Madang',
#   'Lat': -5.22,
#   'Lng': 145.8,
#   'Max Temp': 79.57,
#   'Humidity': 80,
#   'Cloudiness': 51,
#   'Wind Speed': 5.84,
#   'Current Description': 'broken clouds',
#   'Country': 'PG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Akdepe',
#   'Lat': 42.06,
#   'Lng': 59.38,
#   'Max Temp': 66.2,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky',
#   'Country': 'TM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Buchanan',
#   'Lat': 5.88,
#   'Lng': -10.05,
#   'Max Temp': 76.89,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 10.76,
#   'Current Description': 'light rain',
#   'Country': 'LR',
#   'Rain (inches)': 0.16,
#   'Snow (inches)': '0.0'},
#  {'City': 'Ozernovskiy',
#   'Lat': 51.5,
#   'Lng': 156.52,
#   'Max Temp': 49.03,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Current Description': 'overcast clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Russkaya Polyana',
#   'Lat': 49.42,
#   'Lng': 31.92,
#   'Max Temp': 64.42,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 2.66,
# ...
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lumby',
#   'Lat': 50.25,
#   'Lng': -118.97,
#   'Max Temp': 81,
#   'Humidity': 58,
#   'Cloudiness': 83,
#   'Wind Speed': 11.03,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Wanning',
#   'Lat': 18.8,
#   'Lng': 110.4,
#   'Max Temp': 81.45,
#   'Humidity': 88,
#   'Cloudiness': 86,
#   'Wind Speed': 10.65,
#   'Current Description': 'overcast clouds',
#   'Country': 'CN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Taoudenni',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 101.3,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 12.19,
#   'Current Description': 'clear sky',
#   'Country': 'ML',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Lichinga',
#   'Lat': -13.31,
#   'Lng': 35.24,
#   'Max Temp': 54.68,
#   'Humidity': 96,
#   'Cloudiness': 0,
#   'Wind Speed': 5.59,
#   'Current Description': 'clear sky',
#   'Country': 'MZ',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kuzino',
#   'Lat': 57.02,
#   'Lng': 59.44,
#   'Max Temp': 37.06,
#   'Humidity': 96,
#   'Cloudiness': 11,
#   'Wind Speed': 4.09,
#   'Current Description': 'few clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ca Mau',
#   'Lat': 9.18,
#   'Lng': 105.15,
#   'Max Temp': 77.18,
#   'Humidity': 91,
#   'Cloudiness': 94,
#   'Wind Speed': 4.07,
#   'Current Description': 'overcast clouds',
#   'Country': 'VN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Husavik',
#   'Lat': 66.04,
#   'Lng': -17.34,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds',
#   'Country': 'IS',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Houma',
#   'Lat': 29.6,
#   'Lng': -90.72,
#   'Max Temp': 91.99,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Abu Samrah',
#   'Lat': 35.3,
#   'Lng': 37.18,
#   'Max Temp': 72.43,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 10.71,
#   'Current Description': 'clear sky',
#   'Country': 'SY',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mandiana',
#   'Lat': 10.63,
#   'Lng': -8.68,
#   'Max Temp': 79.86,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 6.55,
#   'Current Description': 'clear sky',
#   'Country': 'GN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sonoita',
#   'Lat': 31.85,
#   'Lng': -112.83,
#   'Max Temp': 100.99,
#   'Humidity': 13,
#   'Cloudiness': 37,
#   'Wind Speed': 5.01,
#   'Current Description': 'scattered clouds',
#   'Country': 'MX',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sadao',
#   'Lat': 6.64,
#   'Lng': 100.42,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds',
#   'Country': 'TH',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.62,
#   'Lng': -69.22,
#   'Max Temp': 30.2,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'AR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Salinopolis',
#   'Lat': -0.61,
#   'Lng': -47.36,
#   'Max Temp': 79.54,
#   'Humidity': 84,
#   'Cloudiness': 95,
#   'Wind Speed': 10.8,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.62,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sampit',
#   'Lat': -2.53,
#   'Lng': 112.95,
#   'Max Temp': 72.27,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 1.77,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 68.22,
#   'Humidity': 84,
#   'Cloudiness': 2,
#   'Wind Speed': 3.11,
#   'Current Description': 'clear sky',
#   'Country': 'MG',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kansanshi',
#   'Lat': -12.1,
#   'Lng': 26.43,
#   'Max Temp': 56.1,
#   'Humidity': 68,
#   'Cloudiness': 13,
#   'Wind Speed': 3.09,
#   'Current Description': 'few clouds',
#   'Country': 'ZM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Skala',
#   'Lat': 50.23,
#   'Lng': 19.85,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 82,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Country': 'PL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 64.4,
#   'Humidity': 41,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'moderate rain',
#   'Country': 'US',
#   'Rain (inches)': 3.05,
#   'Snow (inches)': '0.0'},
#  {'City': 'Omsukchan',
#   'Lat': 62.53,
#   'Lng': 155.8,
#   'Max Temp': 69.76,
#   'Humidity': 48,
#   'Cloudiness': 28,
#   'Wind Speed': 4.88,
#   'Current Description': 'scattered clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Epe',
#   'Lat': 6.58,
#   'Lng': 3.98,
#   'Max Temp': 76.59,
#   'Humidity': 92,
#   'Cloudiness': 70,
#   'Wind Speed': 5.53,
#   'Current Description': 'light rain',
#   'Country': 'NG',
#   'Rain (inches)': 0.97,
#   'Snow (inches)': '0.0'},
#  {'City': 'Meridian',
#   'Lat': 43.61,
#   'Lng': -116.39,
#   'Max Temp': 91,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kisumu',
#   'Lat': -0.1,
#   'Lng': 34.76,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 4.43,
#   'Current Description': 'broken clouds',
#   'Country': 'KE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Balkanabat',
#   'Lat': 39.51,
#   'Lng': 54.37,
#   'Max Temp': 74.64,
#   'Humidity': 31,
#   'Cloudiness': 6,
#   'Wind Speed': 8.37,
#   'Current Description': 'clear sky',
#   'Country': 'TM',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Karratha',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 65.55,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 9.33,
#   'Current Description': 'clear sky',
#   'Country': 'AU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Padang',
#   'Lat': -0.95,
#   'Lng': 100.35,
#   'Max Temp': 78.33,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Current Description': 'light rain',
#   'Country': 'ID',
#   'Rain (inches)': 0.19,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sibolga',
#   'Lat': 1.74,
#   'Lng': 98.78,
#   'Max Temp': 77.07,
#   'Humidity': 69,
#   'Cloudiness': 97,
#   'Wind Speed': 3.06,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Trinidad',
#   'Lat': -14.83,
#   'Lng': -64.9,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds',
#   'Country': 'BO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ulaangom',
#   'Lat': 49.98,
#   'Lng': 92.07,
#   'Max Temp': 56.97,
#   'Humidity': 70,
#   'Cloudiness': 19,
#   'Wind Speed': 1.63,
#   'Current Description': 'few clouds',
#   'Country': 'MN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Meulaboh',
#   'Lat': 4.14,
#   'Lng': 96.13,
#   'Max Temp': 76.28,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds',
#   'Country': 'ID',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Coquimbo',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 57.2,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Arauca',
#   'Lat': 7.08,
#   'Lng': -70.76,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds',
#   'Country': 'CO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Mongoumba',
#   'Lat': 3.64,
#   'Lng': 18.59,
#   'Max Temp': 70.29,
#   'Humidity': 90,
#   'Cloudiness': 73,
#   'Wind Speed': 2.19,
#   'Current Description': 'broken clouds',
#   'Country': 'CF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Loreto',
#   'Lat': 22.27,
#   'Lng': -101.97,
#   'Max Temp': 74.73,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 8.34,
#   'Current Description': 'moderate rain',
#   'Country': 'MX',
#   'Rain (inches)': 1.4,
#   'Snow (inches)': '0.0'},
#  {'City': 'Sinop',
#   'Lat': 41.77,
#   'Lng': 34.87,
#   'Max Temp': 61.29,
#   'Humidity': 84,
#   'Cloudiness': 71,
#   'Wind Speed': 3.44,
#   'Current Description': 'broken clouds',
#   'Country': 'TR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ratnagiri',
#   'Lat': 16.98,
#   'Lng': 73.3,
#   'Max Temp': 81.5,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.21,
#   'Current Description': 'overcast clouds',
#   'Country': 'IN',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Anchorage',
#   'Lat': 61.22,
#   'Lng': -149.9,
#   'Max Temp': 57.99,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'light rain',
#   'Country': 'US',
#   'Rain (inches)': 0.25,
#   'Snow (inches)': '0.0'},
#  {'City': 'Billings',
#   'Lat': 45.78,
#   'Lng': -108.5,
#   'Max Temp': 88,
#   'Humidity': 22,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Current Description': 'few clouds',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Taltal',
#   'Lat': -25.4,
#   'Lng': -70.48,
#   'Max Temp': 57.94,
#   'Humidity': 76,
#   'Cloudiness': 19,
#   'Wind Speed': 3.24,
#   'Current Description': 'few clouds',
#   'Country': 'CL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Cabedelo',
#   'Lat': -6.98,
#   'Lng': -34.83,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Acarau',
#   'Lat': -2.89,
#   'Lng': -40.12,
#   'Max Temp': 74.84,
#   'Humidity': 76,
#   'Cloudiness': 85,
#   'Wind Speed': 6.67,
#   'Current Description': 'overcast clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Guaruja',
#   'Lat': -23.99,
#   'Lng': -46.26,
#   'Max Temp': 66.99,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Description': 'moderate rain',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Ibotirama',
#   'Lat': -12.19,
#   'Lng': -43.22,
#   'Max Temp': 75.6,
#   'Humidity': 42,
#   'Cloudiness': 25,
#   'Wind Speed': 2.37,
#   'Current Description': 'scattered clouds',
#   'Country': 'BR',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kitimat',
#   'Lat': 54.05,
#   'Lng': -128.65,
#   'Max Temp': 62.6,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Current Description': 'broken clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Salinas',
#   'Lat': 36.68,
#   'Lng': -121.66,
#   'Max Temp': 78.01,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky',
#   'Country': 'US',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Marystown',
#   'Lat': 47.17,
#   'Lng': -55.15,
#   'Max Temp': 60.62,
#   'Humidity': 79,
#   'Cloudiness': 21,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Lat': -0.41,
#   'Lng': -65.02,
#   'Max Temp': 78.13,
#   'Humidity': 95,
#   'Cloudiness': 93,
#   'Wind Speed': 2.35,
#   'Current Description': 'light rain',
#   'Country': 'BR',
#   'Rain (inches)': 0.53,
#   'Snow (inches)': '0.0'},
#  {'City': 'Miyako',
#   'Lat': 39.64,
#   'Lng': 141.95,
#   'Max Temp': 69.62,
#   'Humidity': 86,
#   'Cloudiness': 81,
#   'Wind Speed': 4,
#   'Current Description': 'broken clouds',
#   'Country': 'JP',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Richards Bay',
#   'Lat': -28.78,
#   'Lng': 32.04,
#   'Max Temp': 62.71,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 4.79,
#   'Current Description': 'clear sky',
#   'Country': 'ZA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Sozimskiy',
#   'Lat': 59.74,
#   'Lng': 52.25,
#   'Max Temp': 46.13,
#   'Humidity': 84,
#   'Cloudiness': 68,
#   'Wind Speed': 5.28,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Stuttgart',
#   'Lat': 48.78,
#   'Lng': 9.18,
#   'Max Temp': 66.99,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 1.12,
#   'Current Description': 'overcast clouds',
#   'Country': 'DE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Pailon',
#   'Lat': -17.65,
#   'Lng': -62.75,
#   'Max Temp': 57.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds',
#   'Country': 'BO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Poum',
#   'Lat': -20.23,
#   'Lng': 164.02,
#   'Max Temp': 70.84,
#   'Humidity': 67,
#   'Cloudiness': 80,
#   'Wind Speed': 12.93,
#   'Current Description': 'broken clouds',
#   'Country': 'NC',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Butembo',
#   'Lat': 0.15,
#   'Lng': 29.28,
#   'Max Temp': 57.51,
#   'Humidity': 100,
#   'Cloudiness': 83,
#   'Wind Speed': 0.83,
#   'Current Description': 'broken clouds',
#   'Country': 'CD',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Agadez',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 86.92,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 5.7,
#   'Current Description': 'clear sky',
#   'Country': 'NE',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Rudbar',
#   'Lat': 30.15,
#   'Lng': 62.6,
#   'Max Temp': 88.23,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 9.75,
#   'Current Description': 'clear sky',
#   'Country': 'AF',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Kieta',
#   'Lat': -6.22,
#   'Lng': 155.63,
#   'Max Temp': 83.1,
#   'Humidity': 72,
#   'Cloudiness': 82,
#   'Wind Speed': 6.58,
#   'Current Description': 'light rain',
#   'Country': 'PG',
#   'Rain (inches)': 0.74,
#   'Snow (inches)': '0.0'},
#  {'City': 'Jishou',
#   'Lat': 28.32,
#   'Lng': 109.72,
#   'Max Temp': 74.66,
#   'Humidity': 92,
#   'Cloudiness': 86,
#   'Wind Speed': 2.46,
#   'Current Description': 'moderate rain',
#   'Country': 'CN',
#   'Rain (inches)': 2.09,
#   'Snow (inches)': '0.0'},
#  {'City': 'Hammerfest',
#   'Lat': 70.66,
#   'Lng': 23.68,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 27.51,
#   'Current Description': 'broken clouds',
#   'Country': 'NO',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Gidole',
#   'Lat': 5.65,
#   'Lng': 37.37,
#   'Max Temp': 58.82,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 1.63,
#   'Current Description': 'overcast clouds',
#   'Country': 'ET',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': 70.95,
#   'Humidity': 44,
#   'Cloudiness': 71,
#   'Wind Speed': 7.11,
#   'Current Description': 'broken clouds',
#   'Country': 'RU',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nipawin',
#   'Lat': 53.37,
#   'Lng': -104,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds',
#   'Country': 'CA',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Nuuk',
#   'Lat': 64.18,
#   'Lng': -51.72,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds',
#   'Country': 'GL',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.06,
#   'Lng': -61.75,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 23.04,
#   'Current Description': 'few clouds',
#   'Country': 'GD',
#   'Rain (inches)': '0.0',
#   'Snow (inches)': '0.0'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Rikitea -23.12 -134.97     73.74        84          79       12.48
# 1          Rocha -34.48  -54.33     43.00        73          73        6.42
# 2        Vegachi   6.76  -74.79     73.89        96          72        1.59
# 3      Busselton -33.65  115.33     57.00        89          11       12.24
# 4    Port-Gentil  -0.72    8.78     73.40        94          40        5.82
# 5  Leningradskiy  69.38  178.42     32.68        94         100       17.43
# 6      Cape Town -33.93   18.42     59.00        71          75       20.80
# 7        Mataura -46.19  168.86     39.00        83          98        3.00
# 8          Avera  33.19  -82.53     89.01        55           1       14.99
# 9           Hilo  19.73 -155.09     84.20        62           1        9.17
#
#   Current Description Country Rain (inches) Snow (inches)
# 0       broken clouds      PF           0.0           0.0
# 1       broken clouds      UY           0.0           0.0
# 2       moderate rain      CO          2.95           0.0
# 3          few clouds      AU           0.0           0.0
# 4    scattered clouds      GA           0.0           0.0
# 5     overcast clouds      RU           0.0           0.0
# 6       broken clouds      ZA           0.0           0.0
# 7     overcast clouds      NZ           0.0           0.0
# 8           clear sky      US           0.0           0.0
# 9           clear sky      US           0.0           0.0

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain (inches)", "Snow (inches)"]

# Assign district summary df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.12 -134.97     73.74        84          79
# 1            Rocha      UY -34.48  -54.33     43.00        73          73
# 2          Vegachi      CO   6.76  -74.79     73.89        96          72
# 3        Busselton      AU -33.65  115.33     57.00        89          11
# 4      Port-Gentil      GA  -0.72    8.78     73.40        94          40
# ..             ...     ...    ...     ...       ...       ...         ...
# 561         Gidole      ET   5.65   37.37     58.82        88          90
# 562       Zhigansk      RU  66.77  123.37     70.95        44          71
# 563        Nipawin      CA  53.37 -104.00     66.20        68          90
# 564           Nuuk      GL  64.18  -51.72     44.60        75          20
# 565  Saint-Georges      GD  12.06  -61.75     86.00        74          20
#
#      Wind Speed Current Description Rain (inches) Snow (inches)
# 0         12.48       broken clouds           0.0           0.0
# 1          6.42       broken clouds           0.0           0.0
# 2          1.59       moderate rain          2.95           0.0
# 3         12.24          few clouds           0.0           0.0
# 4          5.82    scattered clouds           0.0           0.0
# ..          ...                 ...           ...           ...
# 561        1.63     overcast clouds           0.0           0.0
# 562        7.11       broken clouds           0.0           0.0
# 563        3.36     overcast clouds           0.0           0.0
# 564        9.17          few clouds           0.0           0.0
# 565       23.04          few clouds           0.0           0.0
#
# [566 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
